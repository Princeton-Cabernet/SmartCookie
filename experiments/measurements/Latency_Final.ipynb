# %%
# Application Latency Measurements, Baseline, jc4->synflood_assist->jc5 with client jc6 


b_flood_rate_0_1 = 59520
b_curl_list_0_1  = [
"curl latency: 0.000119:0.000260:0.000281 on interface enp3s0f0",
"curl latency: 0.000126:0.000249:0.000271 on interface enp3s0f0",
"curl latency: 0.000116:0.000215:0.000239 on interface enp3s0f0",
"curl latency: 0.000123:0.000251:0.000276 on interface enp3s0f0",
"curl latency: 0.000122:0.000238:0.000263 on interface enp3s0f0",
"curl latency: 0.000119:0.000218:0.000241 on interface enp3s0f0",
"curl latency: 0.000116:0.000215:0.000239 on interface enp3s0f0",
"curl latency: 0.000120:0.000251:0.000273 on interface enp3s0f0",
"curl latency: 0.000119:0.000223:0.000247 on interface enp3s0f0",
"curl latency: 0.000127:0.000230:0.000252 on interface enp3s0f0",
"curl latency: 0.000118:0.000200:0.000225 on interface enp3s0f0",
"curl latency: 0.000123:0.000227:0.000248 on interface enp3s0f0",
"curl latency: 0.000115:0.000215:0.000240 on interface enp3s0f0",
"curl latency: 0.000124:0.000228:0.000250 on interface enp3s0f0",
"curl latency: 0.000119:0.000214:0.000236 on interface enp3s0f0",
"curl latency: 0.000125:0.000311:0.000333 on interface enp3s0f0",
"curl latency: 0.000118:0.000274:0.000295 on interface enp3s0f0",
"curl latency: 0.000160:0.000326:0.000351 on interface enp3s0f0",
"curl latency: 0.000121:0.000268:0.000293 on interface enp3s0f0",
"curl latency: 0.000118:0.000252:0.000272 on interface enp3s0f0",
"curl latency: 0.000122:0.000233:0.000258 on interface enp3s0f0",
"curl latency: 0.000112:0.000266:0.000290 on interface enp3s0f0",
"curl latency: 0.000121:0.000218:0.000240 on interface enp3s0f0",
"curl latency: 0.000126:0.000243:0.000267 on interface enp3s0f0",
"curl latency: 0.000123:0.000270:0.000294 on interface enp3s0f0",
"curl latency: 0.000160:0.000309:0.000330 on interface enp3s0f0",
"curl latency: 0.000131:0.000295:0.000321 on interface enp3s0f0",
"curl latency: 0.000117:0.000265:0.000292 on interface enp3s0f0",
"curl latency: 0.000119:0.000259:0.000281 on interface enp3s0f0",
"curl latency: 0.000123:0.000253:0.000275 on interface enp3s0f0",
"curl latency: 0.000122:0.000262:0.000287 on interface enp3s0f0",
"curl latency: 0.000128:0.000259:0.000281 on interface enp3s0f0",
"curl latency: 0.000120:0.000247:0.000272 on interface enp3s0f0",
"curl latency: 0.000119:0.000258:0.000282 on interface enp3s0f0",
]


b_flood_rate_0_5 = 302273
b_curl_list_0_5  = [

"curl latency: 0.000125:0.000227:0.000254 on interface enp3s0f0",
"curl latency: 0.000157:0.000273:0.000297 on interface enp3s0f0",
"curl latency: 0.000127:0.000222:0.000244 on interface enp3s0f0",
"curl latency: 0.000124:0.000225:0.000247 on interface enp3s0f0",
"curl latency: 0.000119:0.000204:0.000227 on interface enp3s0f0",
"curl latency: 0.000135:0.000227:0.000249 on interface enp3s0f0",
"curl latency: 0.000141:0.000265:0.000291 on interface enp3s0f0",
"curl latency: 0.000129:0.000234:0.000258 on interface enp3s0f0",
"curl latency: 0.000125:0.000235:0.000256 on interface enp3s0f0",
"curl latency: 0.000136:0.000227:0.000249 on interface enp3s0f0",
"curl latency: 0.000131:0.000225:0.000247 on interface enp3s0f0",
"curl latency: 0.000120:0.000252:0.000276 on interface enp3s0f0",
"curl latency: 0.000134:0.000230:0.000255 on interface enp3s0f0",
"curl latency: 0.000119:0.000211:0.000233 on interface enp3s0f0",
"curl latency: 0.000126:0.000236:0.000261 on interface enp3s0f0",
"curl latency: 0.000122:0.000214:0.000238 on interface enp3s0f0",
"curl latency: 0.000118:0.000269:0.000290 on interface enp3s0f0",
"curl latency: 0.000128:0.000238:0.000261 on interface enp3s0f0",
"curl latency: 0.000121:0.000205:0.000234 on interface enp3s0f0",
"curl latency: 0.000156:0.000273:0.000298 on interface enp3s0f0",
"curl latency: 0.000126:0.000228:0.000252 on interface enp3s0f0",
"curl latency: 0.000109:0.000193:0.000216 on interface enp3s0f0",
"curl latency: 0.000124:0.000229:0.000249 on interface enp3s0f0",
"curl latency: 0.000138:0.000231:0.000253 on interface enp3s0f0",
"curl latency: 0.000120:0.000221:0.000241 on interface enp3s0f0",
"curl latency: 0.000124:0.000243:0.000268 on interface enp3s0f0",
"curl latency: 0.000118:0.000217:0.000237 on interface enp3s0f0",
"curl latency: 0.000156:0.000282:0.000303 on interface enp3s0f0",
"curl latency: 0.000127:0.000245:0.000269 on interface enp3s0f0",
"curl latency: 0.000107:0.000208:0.000228 on interface enp3s0f0",
"curl latency: 0.000158:0.000267:0.000289 on interface enp3s0f0",
"curl latency: 0.000114:0.000210:0.000235 on interface enp3s0f0",
"curl latency: 0.000157:0.000282:0.000308 on interface enp3s0f0",
"curl latency: 0.000118:0.000228:0.000252 on interface enp3s0f0",
"curl latency: 0.000156:0.000282:0.000306 on interface enp3s0f0",
"curl latency: 0.000119:0.000231:0.000255 on interface enp3s0f0",
"curl latency: 0.000118:0.000239:0.000265 on interface enp3s0f0",
"curl latency: 0.000122:0.000224:0.000249 on interface enp3s0f0",
"curl latency: 0.000137:0.000233:0.000254 on interface enp3s0f0",
"curl latency: 0.000114:0.000218:0.000241 on interface enp3s0f0",
"curl latency: 0.000157:0.000250:0.000274 on interface enp3s0f0",

]

b_flood_rate_1 = 594990
b_curl_list_1 = [
    
"curl latency: 0.000138:0.000384:0.000408 on interface enp3s0f0",
"curl latency: 0.000121:0.000533:0.000565 on interface enp3s0f0",
"curl latency: 0.000125:0.000574:0.000615 on interface enp3s0f0",
"curl latency: 0.000130:0.000545:0.000567 on interface enp3s0f0",
"curl latency: 0.000127:0.000676:0.000721 on interface enp3s0f0",
"curl latency: 0.000141:0.000690:0.000734 on interface enp3s0f0",
"curl latency: 0.000124:0.000581:0.000607 on interface enp3s0f0",
"curl latency: 0.000143:0.000730:0.000776 on interface enp3s0f0",
"curl latency: 0.000125:0.000567:0.000594 on interface enp3s0f0",
"curl latency: 0.000139:0.000392:0.000416 on interface enp3s0f0",
"curl latency: 0.000134:0.000646:0.000689 on interface enp3s0f0",
"curl latency: 0.000148:0.000455:0.000480 on interface enp3s0f0",
"curl latency: 0.000131:0.000583:0.000635 on interface enp3s0f0",
"curl latency: 0.000152:0.000384:0.000406 on interface enp3s0f0",
"curl latency: 0.000144:0.000400:0.000424 on interface enp3s0f0",
"curl latency: 0.000139:0.000638:0.000683 on interface enp3s0f0",
"curl latency: 0.000126:0.000703:0.000729 on interface enp3s0f0",
"curl latency: 0.000121:0.000658:0.000681 on interface enp3s0f0",
"curl latency: 0.000126:0.000717:0.000740 on interface enp3s0f0",
"curl latency: 0.000166:0.000683:0.000738 on interface enp3s0f0",
"curl latency: 0.000119:0.000491:0.000535 on interface enp3s0f0",
"curl latency: 0.000126:0.000566:0.000592 on interface enp3s0f0",
"curl latency: 0.000123:0.000479:0.000504 on interface enp3s0f0",
"curl latency: 0.000120:0.000540:0.000566 on interface enp3s0f0",
"curl latency: 0.000158:0.000620:0.000666 on interface enp3s0f0",
"curl latency: 0.000116:0.000384:0.000412 on interface enp3s0f0",
"curl latency: 0.000124:0.000608:0.000653 on interface enp3s0f0",
"curl latency: 0.000124:0.000694:0.000740 on interface enp3s0f0",
"curl latency: 0.000177:0.000418:0.000460 on interface enp3s0f0",
"curl latency: 0.000122:0.000550:0.000578 on interface enp3s0f0",
"curl latency: 0.000126:0.000614:0.000661 on interface enp3s0f0",
"curl latency: 0.000153:0.000565:0.000589 on interface enp3s0f0",
"curl latency: 0.000161:0.000483:0.000508 on interface enp3s0f0",
"curl latency: 0.000159:0.000558:0.000598 on interface enp3s0f0",

]


b_flood_rate_1_5 = 892209
b_curl_list_1_5 = [

"curl latency: 0.000178:0.000382:0.000406 on interface enp3s0f0",
"curl latency: 0.000129:0.000362:0.000387 on interface enp3s0f0",
"curl latency: 0.000175:0.000360:0.000384 on interface enp3s0f0",
"curl latency: 0.000165:0.000357:0.000381 on interface enp3s0f0",
"curl latency: 0.000127:0.000307:0.000329 on interface enp3s0f0",
"curl latency: 0.000131:0.000349:0.000405 on interface enp3s0f0",
"curl latency: 0.000131:0.000336:0.000362 on interface enp3s0f0",
"curl latency: 0.000154:0.000374:0.000414 on interface enp3s0f0",
"curl latency: 0.000134:0.000318:0.000342 on interface enp3s0f0",
"curl latency: 0.000138:0.000323:0.000349 on interface enp3s0f0",
"curl latency: 0.000126:0.000391:0.000416 on interface enp3s0f0",
"curl latency: 0.000143:0.000313:0.000335 on interface enp3s0f0",
"curl latency: 0.000158:0.000358:0.000380 on interface enp3s0f0",
"curl latency: 0.000218:0.000439:0.000465 on interface enp3s0f0",
"curl latency: 0.000237:0.000465:0.000508 on interface enp3s0f0",
"curl latency: 0.000147:0.000369:0.000394 on interface enp3s0f0",
"curl latency: 0.000149:0.000327:0.000350 on interface enp3s0f0",
"curl latency: 0.000208:0.000446:0.000488 on interface enp3s0f0",
"curl latency: 0.000145:0.000353:0.000375 on interface enp3s0f0",
"curl latency: 0.000387:0.000656:0.000696 on interface enp3s0f0",
"curl latency: 0.000151:0.000469:0.000490 on interface enp3s0f0",
"curl latency: 0.000130:0.000340:0.000382 on interface enp3s0f0",
"curl latency: 0.000192:0.000370:0.000399 on interface enp3s0f0",
"curl latency: 0.000270:0.000521:0.000544 on interface enp3s0f0",
"curl latency: 0.000207:0.000464:0.000504 on interface enp3s0f0",
"curl latency: 0.000131:0.000312:0.000335 on interface enp3s0f0",
"curl latency: 0.000153:0.000462:0.000505 on interface enp3s0f0",
"curl latency: 0.000190:0.000399:0.000423 on interface enp3s0f0",
"curl latency: 0.000119:0.000302:0.000325 on interface enp3s0f0",
"curl latency: 0.000177:0.000512:0.000557 on interface enp3s0f0",
"curl latency: 0.000118:0.000335:0.000357 on interface enp3s0f0",
"curl latency: 0.000141:0.000309:0.000335 on interface enp3s0f0",
"curl latency: 0.000130:0.000295:0.000324 on interface enp3s0f0",
"curl latency: 0.000156:0.000323:0.000348 on interface enp3s0f0",
"curl latency: 0.000142:0.000355:0.000375 on interface enp3s0f0",
]

b_flood_rate_2 = 1189457
b_curl_list_2 = [
"curl latency: 0.000200:0.000628:0.000654 on interface enp3s0f0",
"curl latency: 0.000201:0.000635:0.000658 on interface enp3s0f0",
"curl latency: 0.000371:0.001250:0.001309 on interface enp3s0f0",
"curl latency: 0.000195:0.000664:0.000691 on interface enp3s0f0",
"curl latency: 0.000586:0.001258:0.001303 on interface enp3s0f0",
"curl latency: 0.000173:0.000410:0.000434 on interface enp3s0f0",
"curl latency: 0.000202:0.000598:0.000642 on interface enp3s0f0",
"curl latency: 0.000245:0.001283:0.001308 on interface enp3s0f0",
"curl latency: 0.000232:0.000643:0.000677 on interface enp3s0f0",
"curl latency: 0.000204:0.000475:0.000519 on interface enp3s0f0",
"curl latency: 0.000192:0.000426:0.000466 on interface enp3s0f0",
"curl latency: 0.000313:0.000659:0.000684 on interface enp3s0f0",
"curl latency: 0.000253:0.001029:0.001073 on interface enp3s0f0",
"curl latency: 0.000235:0.000901:0.000927 on interface enp3s0f0",
"curl latency: 0.000213:0.000819:0.000855 on interface enp3s0f0",
"curl latency: 0.000197:0.000933:0.000979 on interface enp3s0f0",
"curl latency: 0.002029:0.005175:0.005199 on interface enp3s0f0",
"curl latency: 0.006106:0.012865:0.012890 on interface enp3s0f0",
"curl latency: 0.000169:0.000894:0.000920 on interface enp3s0f0",
"curl latency: 0.000219:0.000569:0.000614 on interface enp3s0f0",
"curl latency: 0.000131:0.000294:0.000316 on interface enp3s0f0",
"curl latency: 0.000138:0.000363:0.000407 on interface enp3s0f0",
"curl latency: 0.000198:0.000460:0.000485 on interface enp3s0f0",
"curl latency: 0.000195:0.000541:0.000588 on interface enp3s0f0",
"curl latency: 0.000233:0.000541:0.000564 on interface enp3s0f0",
"curl latency: 0.000127:0.001345:0.001376 on interface enp3s0f0",
"curl latency: 0.000125:0.000907:0.000952 on interface enp3s0f0",
"curl latency: 0.000195:0.000962:0.000988 on interface enp3s0f0",
"curl latency: 0.000188:0.000487:0.000541 on interface enp3s0f0",
"curl latency: 0.000133:0.000289:0.000313 on interface enp3s0f0",
"curl latency: 0.000218:0.000518:0.000562 on interface enp3s0f0",
"curl latency: 0.000116:0.000270:0.000292 on interface enp3s0f0",
"curl latency: 0.000125:0.000264:0.000286 on interface enp3s0f0",
"curl latency: 0.000172:0.000608:0.000655 on interface enp3s0f0",
"curl latency: 0.000140:0.000385:0.000410 on interface enp3s0f0",
]

b_flood_rate_2_1 = 1248651
b_curl_list_2_1 = [

"curl latency: 0.000252:0.001206:0.001251 on interface enp3s0f0",
"curl latency: 0.000143:0.001077:0.001123 on interface enp3s0f0",
"curl latency: 0.000119:0.000849:0.000919 on interface enp3s0f0",
"curl latency: 0.000283:0.001061:0.001096 on interface enp3s0f0",
"curl latency: 0.000159:0.001008:0.001033 on interface enp3s0f0",
"curl latency: 0.000124:0.000952:0.000999 on interface enp3s0f0",
"curl latency: 0.000200:0.000881:0.000932 on interface enp3s0f0",
"curl latency: 0.000228:0.000585:0.000609 on interface enp3s0f0",
"curl latency: 0.000127:0.000481:0.000509 on interface enp3s0f0",
"curl latency: 0.000314:0.000557:0.000615 on interface enp3s0f0",
"curl latency: 0.000248:0.000414:0.000436 on interface enp3s0f0",
"curl latency: 0.000132:0.000521:0.000545 on interface enp3s0f0",
"curl latency: 0.000183:0.000501:0.000524 on interface enp3s0f0",
"curl latency: 0.000304:0.000682:0.000706 on interface enp3s0f0",
"curl latency: 0.000236:0.000517:0.000546 on interface enp3s0f0",
"curl latency: 0.002422:0.014639:0.014684 on interface enp3s0f0",
"curl latency: 0.003735:0.007758:0.007789 on interface enp3s0f0",
"curl latency: 0.008677:0.016312:0.016359 on interface enp3s0f0",
"curl latency: 0.002370:0.004930:0.004975 on interface enp3s0f0",
"curl latency: 0.000188:0.000784:0.000829 on interface enp3s0f0",
"curl latency: 0.000937:0.001958:0.001982 on interface enp3s0f0",
"curl latency: 0.000141:0.000520:0.000543 on interface enp3s0f0",
"curl latency: 0.000143:0.000555:0.000602 on interface enp3s0f0",
"curl latency: 0.000151:0.000518:0.000550 on interface enp3s0f0",
"curl latency: 0.000202:0.000535:0.000558 on interface enp3s0f0",
"curl latency: 0.000192:0.000759:0.000785 on interface enp3s0f0",
"curl latency: 0.000265:0.000747:0.000785 on interface enp3s0f0",
"curl latency: 0.000237:0.000767:0.000792 on interface enp3s0f0",
"curl latency: 0.000126:0.000431:0.000475 on interface enp3s0f0",
"curl latency: 0.000221:0.000957:0.001002 on interface enp3s0f0",
"curl latency: 0.000206:0.001179:0.001236 on interface enp3s0f0",
    
]

b_flood_rate_2_2 = 1307940
b_curl_list_2_2 = [
    
"curl latency: 0.003427:0.007098:0.007143 on interface enp3s0f0",
"curl latency: 0.003662:0.006152:0.006182 on interface enp3s0f0",
"curl latency: 0.002027:0.004022:0.004043 on interface enp3s0f0",
"curl latency: 0.000244:0.000778:0.000824 on interface enp3s0f0",
"curl latency: 0.000135:0.000588:0.000615 on interface enp3s0f0",
"curl latency: 0.000126:0.001524:0.001584 on interface enp3s0f0",
"curl latency: 0.000130:0.000397:0.000422 on interface enp3s0f0",
"curl latency: 0.000144:0.000343:0.000373 on interface enp3s0f0",
"curl latency: 0.000147:0.000753:0.000813 on interface enp3s0f0",
"curl latency: 0.000730:0.001298:0.001324 on interface enp3s0f0",
"curl latency: 0.000143:0.000687:0.000714 on interface enp3s0f0",
"curl latency: 0.000154:0.000475:0.000498 on interface enp3s0f0",
"curl latency: 0.000169:0.003158:0.003186 on interface enp3s0f0",
"curl latency: 0.000200:0.000476:0.000499 on interface enp3s0f0",
"curl latency: 0.000146:0.000564:0.000587 on interface enp3s0f0",
"curl latency: 0.000157:0.000636:0.000660 on interface enp3s0f0",
"curl latency: 0.000177:0.000598:0.000623 on interface enp3s0f0",
"curl latency: 0.000204:0.000545:0.000568 on interface enp3s0f0",
"curl latency: 0.000149:0.000470:0.000494 on interface enp3s0f0",
"curl latency: 0.000590:0.001249:0.001293 on interface enp3s0f0",
"curl latency: 0.000125:0.000607:0.000653 on interface enp3s0f0",
"curl latency: 0.000179:0.001072:0.001117 on interface enp3s0f0",
"curl latency: 0.000211:0.001007:0.001033 on interface enp3s0f0",
"curl latency: 0.000192:0.000926:0.000950 on interface enp3s0f0",
"curl latency: 0.000146:0.000891:0.000920 on interface enp3s0f0",
"curl latency: 0.000223:0.001046:0.001090 on interface enp3s0f0",
"curl latency: 0.000169:0.000975:0.001042 on interface enp3s0f0",
"curl latency: 0.000792:0.001827:0.001850 on interface enp3s0f0",
"curl latency: 0.000196:0.001007:0.001034 on interface enp3s0f0",
"curl latency: 0.000157:0.000901:0.000946 on interface enp3s0f0",
"curl latency: 0.000128:0.000902:0.000935 on interface enp3s0f0",
]

b_flood_rate_2_3 = 1367886
b_curl_list_2_3 = [
    
"curl latency: 0.000169:0.001427:0.001474 on interface enp3s0f0",
"curl latency: 0.000117:0.001298:0.001345 on interface enp3s0f0",
"curl latency: 0.000152:0.000862:0.000885 on interface enp3s0f0",
"curl latency: 0.000177:0.000769:0.000813 on interface enp3s0f0",
"curl latency: 0.000124:0.000921:0.000946 on interface enp3s0f0",
"curl latency: 0.000133:0.001571:0.001614 on interface enp3s0f0",
"curl latency: 0.002266:0.003062:0.003086 on interface enp3s0f0",
"curl latency: 0.000159:0.003218:0.003242 on interface enp3s0f0",
"curl latency: 0.001182:0.002834:0.002858 on interface enp3s0f0",
"curl latency: 0.000221:0.000935:0.000961 on interface enp3s0f0",
"curl latency: 0.000229:0.001211:0.001255 on interface enp3s0f0",
"curl latency: 0.000188:0.000513:0.000534 on interface enp3s0f0",
"curl latency: 0.000116:0.000496:0.000518 on interface enp3s0f0",
"curl latency: 0.001795:0.003900:0.003924 on interface enp3s0f0",
"curl latency: 0.000134:0.000670:0.000696 on interface enp3s0f0",
"curl latency: 0.000149:0.000519:0.000542 on interface enp3s0f0",
"curl latency: 0.003082:0.005831:0.005856 on interface enp3s0f0",
"curl latency: 0.000118:0.002982:0.003000 on interface enp3s0f0",
"curl latency: 0.000195:0.003498:0.003542 on interface enp3s0f0",
"curl latency: 0.000171:0.000552:0.000570 on interface enp3s0f0",
"curl latency: 0.000131:0.000523:0.000549 on interface enp3s0f0",
"curl latency: 0.000210:0.000439:0.000479 on interface enp3s0f0",
"curl latency: 0.000206:0.000592:0.000618 on interface enp3s0f0",
"curl latency: 0.000156:0.000518:0.000537 on interface enp3s0f0",
"curl latency: 0.000181:0.001073:0.001119 on interface enp3s0f0",
"curl latency: 0.000126:0.003010:0.003053 on interface enp3s0f0",
"curl latency: 0.000812:0.003259:0.003283 on interface enp3s0f0",
"curl latency: 0.000149:0.000438:0.000478 on interface enp3s0f0",
"curl latency: 0.000143:0.000475:0.000499 on interface enp3s0f0",
"curl latency: 0.001183:0.002174:0.002204 on interface enp3s0f0",
"curl latency: 0.000565:0.001529:0.001572 on interface enp3s0f0",
"curl latency: 0.000273:0.000698:0.000721 on interface enp3s0f0",
"curl latency: 0.000232:0.000447:0.000489 on interface enp3s0f0",
"curl latency: 0.000126:0.000335:0.000357 on interface enp3s0f0",
"curl latency: 0.000117:0.000380:0.000401 on interface enp3s0f0",
"curl latency: 0.000133:0.000494:0.000516 on interface enp3s0f0",
"curl latency: 0.000136:0.000511:0.000536 on interface enp3s0f0",
"curl latency: 0.000136:0.001156:0.001182 on interface enp3s0f0",
"curl latency: 0.000128:0.000862:0.000905 on interface enp3s0f0",
"curl latency: 0.000123:0.000534:0.000575 on interface enp3s0f0",
"curl latency: 0.000098:0.000396:0.000435 on interface enp3s0f0",
"curl latency: 0.000122:0.000355:0.000380 on interface enp3s0f0",
"curl latency: 0.000968:0.001320:0.001364 on interface enp3s0f0",
"curl latency: 0.000183:0.000403:0.000425 on interface enp3s0f0",
"curl latency: 0.001144:0.002558:0.002582 on interface enp3s0f0",
"curl latency: 0.001169:0.002653:0.002696 on interface enp3s0f0",
"curl latency: 0.000604:0.001344:0.001368 on interface enp3s0f0",
"curl latency: 0.000118:0.000346:0.000369 on interface enp3s0f0",
"curl latency: 0.000118:0.000359:0.000385 on interface enp3s0f0",
"curl latency: 0.000148:0.000447:0.000469 on interface enp3s0f0",
"curl latency: 0.000373:0.001059:0.001091 on interface enp3s0f0",
"curl latency: 0.000126:0.000586:0.000619 on interface enp3s0f0",
"curl latency: 0.000119:0.000406:0.000449 on interface enp3s0f0",
    
]

b_flood_rate_2_35 = 1397906
b_curl_list_2_35 = [
    
"curl latency: 0.000118:0.000388:0.000409 on interface enp3s0f0",
"curl latency: 0.000219:0.000398:0.000419 on interface enp3s0f0",
"curl latency: 0.000136:0.000293:0.000318 on interface enp3s0f0",
"curl latency: 0.000149:0.000495:0.000541 on interface enp3s0f0",
"curl latency: 0.000231:0.000454:0.000482 on interface enp3s0f0",
"curl latency: 0.000151:0.000499:0.000542 on interface enp3s0f0",
"curl latency: 0.000115:0.000260:0.000285 on interface enp3s0f0",
"curl latency: 0.000199:0.000491:0.000534 on interface enp3s0f0",
"curl latency: 0.000133:0.000293:0.000323 on interface enp3s0f0",
"curl latency: 0.000155:0.000333:0.000357 on interface enp3s0f0",
"curl latency: 0.000127:0.000263:0.000288 on interface enp3s0f0",
"curl latency: 0.000110:0.000261:0.000281 on interface enp3s0f0",
"curl latency: 0.000119:0.000271:0.000297 on interface enp3s0f0",
"curl latency: 0.000156:0.000316:0.000338 on interface enp3s0f0",
"curl latency: 0.000108:0.000256:0.000273 on interface enp3s0f0",
"curl latency: 0.000124:0.000229:0.000250 on interface enp3s0f0",
"curl latency: 0.000154:0.000388:0.000410 on interface enp3s0f0",
"curl latency: 0.000153:0.000297:0.000321 on interface enp3s0f0",
"curl latency: 0.000269:0.000559:0.000602 on interface enp3s0f0",
"curl latency: 0.000214:0.000430:0.000455 on interface enp3s0f0",
"curl latency: 0.000134:0.000461:0.000487 on interface enp3s0f0",
"curl latency: 0.000110:0.000269:0.000291 on interface enp3s0f0",
"curl latency: 0.000113:0.000286:0.000308 on interface enp3s0f0",
"curl latency: 0.000159:0.000498:0.000528 on interface enp3s0f0",
"curl latency: 0.000120:0.000269:0.000290 on interface enp3s0f0",
"curl latency: 0.000179:0.000418:0.000442 on interface enp3s0f0",
"curl latency: 0.000130:0.000282:0.000305 on interface enp3s0f0",
"curl latency: 0.000176:0.000327:0.000352 on interface enp3s0f0",
"curl latency: 0.000219:0.000436:0.000457 on interface enp3s0f0",
"curl latency: 0.000113:0.000260:0.000286 on interface enp3s0f0",
"curl latency: 0.000137:0.000402:0.000425 on interface enp3s0f0",
"curl latency: 0.000152:0.000323:0.000343 on interface enp3s0f0",
"curl latency: 0.000133:0.000330:0.000379 on interface enp3s0f0",
"curl latency: 0.000182:0.000321:0.000342 on interface enp3s0f0",
"curl latency: 0.000190:0.000390:0.000431 on interface enp3s0f0",
"curl latency: 0.000236:0.000391:0.000412 on interface enp3s0f0",
"curl latency: 0.000163:0.000352:0.000374 on interface enp3s0f0",
"curl latency: 0.000156:0.000304:0.000327 on interface enp3s0f0",
"curl latency: 0.000113:0.000248:0.000271 on interface enp3s0f0",
"curl latency: 0.000150:0.000303:0.000325 on interface enp3s0f0",
"curl latency: 0.000188:0.000402:0.000431 on interface enp3s0f0",
"curl latency: 0.000184:0.000402:0.000450 on interface enp3s0f0",
"curl latency: 0.000199:0.000522:0.000548 on interface enp3s0f0",
"curl latency: 0.000155:0.000447:0.000485 on interface enp3s0f0",
"curl latency: 0.000177:0.000383:0.000408 on interface enp3s0f0",
"curl latency: 0.000243:0.000537:0.000576 on interface enp3s0f0",
]

b_flood_rate_2_4 = 1426685
b_curl_list_2_4 = [
    
"curl latency: 0.005570:0.011398:0.011425 on interface enp3s0f0",
"curl latency: 0.000885:0.001586:0.001633 on interface enp3s0f0",
"curl latency: 0.000125:0.000303:0.000327 on interface enp3s0f0",
"curl latency: 0.000126:0.000285:0.000314 on interface enp3s0f0",
"curl latency: 0.000217:0.000433:0.000479 on interface enp3s0f0",
"curl latency: 0.000254:0.000429:0.000454 on interface enp3s0f0",
"curl latency: 0.000189:0.000665:0.000711 on interface enp3s0f0",
"curl latency: 0.003066:0.005177:0.005196 on interface enp3s0f0",
"curl latency: 0.002782:0.005822:0.005866 on interface enp3s0f0",
"curl latency: 0.000151:0.000322:0.000349 on interface enp3s0f0",
"curl latency: 0.000117:0.000296:0.000321 on interface enp3s0f0",
"curl latency: 0.000124:0.000321:0.000342 on interface enp3s0f0",
"curl latency: 0.000141:0.000366:0.000387 on interface enp3s0f0",
"curl latency: 0.000218:0.000449:0.000476 on interface enp3s0f0",
"curl latency: 0.000117:0.000258:0.000277 on interface enp3s0f0",
"curl latency: 0.000189:0.000396:0.000420 on interface enp3s0f0",
"curl latency: 0.000172:0.000736:0.000781 on interface enp3s0f0",
"curl latency: 0.000245:0.001797:0.001856 on interface enp3s0f0",
"curl latency: 0.000250:0.001001:0.001027 on interface enp3s0f0",
"curl latency: 0.002114:0.005700:0.005745 on interface enp3s0f0",
"curl latency: 0.000827:0.001984:0.002028 on interface enp3s0f0",
"curl latency: 0.002339:0.004896:0.004940 on interface enp3s0f0",
"curl latency: 0.001604:0.003474:0.003521 on interface enp3s0f0",
"curl latency: 0.000237:0.000781:0.000825 on interface enp3s0f0",
"curl latency: 0.001182:0.002490:0.002517 on interface enp3s0f0",
"curl latency: 0.000160:0.000464:0.000487 on interface enp3s0f0",
"curl latency: 0.000195:0.000639:0.000666 on interface enp3s0f0",
"curl latency: 0.001919:0.004451:0.004495 on interface enp3s0f0",
"curl latency: 0.000155:0.000719:0.000745 on interface enp3s0f0",
"curl latency: 0.003910:0.007708:0.007764 on interface enp3s0f0",
"curl latency: 1.033779:1.036191:1.036218 on interface enp3s0f0",
"curl latency: 0.000710:0.001913:0.001939 on interface enp3s0f0",
]

b_flood_rate_2_5 = 1509650
b_curl_list_2_5 = [
    
"curl latency: 0.000111:0.000252:0.000276 on interface enp3s0f0",
"curl latency: 0.000121:0.000309:0.000332 on interface enp3s0f0",
"curl latency: 0.000120:0.000246:0.000270 on interface enp3s0f0",
"curl latency: 0.000119:0.000429:0.000470 on interface enp3s0f0",
"curl latency: 0.000122:0.000497:0.000544 on interface enp3s0f0",
"curl latency: 0.000123:0.000491:0.000515 on interface enp3s0f0",
"curl latency: 0.000126:0.000362:0.000384 on interface enp3s0f0",
"curl latency: 0.000120:0.000535:0.000556 on interface enp3s0f0",
"curl latency: 0.000128:0.000391:0.000414 on interface enp3s0f0",
"curl latency: 0.000124:0.000359:0.000381 on interface enp3s0f0",
"curl latency: 0.000123:0.000239:0.000264 on interface enp3s0f0",
"curl latency: 0.000121:0.000226:0.000251 on interface enp3s0f0",
"curl latency: 0.000142:0.000484:0.000508 on interface enp3s0f0",
"curl latency: 0.000122:0.000245:0.000268 on interface enp3s0f0",
"curl latency: 0.000122:0.000346:0.000370 on interface enp3s0f0",
"curl latency: 0.002289:0.004613:0.004658 on interface enp3s0f0",
"curl latency: 0.003060:0.210561:0.210608 on interface enp3s0f0",
"curl latency: 0.003399:0.006045:0.006070 on interface enp3s0f0",
"curl latency: 0.000259:0.000586:0.000628 on interface enp3s0f0",
"curl latency: 0.000139:0.000493:0.000517 on interface enp3s0f0",
"curl latency: 0.000235:0.000588:0.000611 on interface enp3s0f0",
"curl latency: 0.000159:0.000464:0.000504 on interface enp3s0f0",
"curl latency: 0.000132:0.000360:0.000387 on interface enp3s0f0",
"curl latency: 0.000184:0.000359:0.000382 on interface enp3s0f0",
"curl latency: 0.000142:0.000373:0.000398 on interface enp3s0f0",
"curl latency: 0.000172:0.000383:0.000406 on interface enp3s0f0",
"curl latency: 0.000199:0.000447:0.000469 on interface enp3s0f0",
"curl latency: 0.000123:0.000342:0.000396 on interface enp3s0f0",
"curl latency: 0.000233:0.000461:0.000504 on interface enp3s0f0",
"curl latency: 0.000243:0.000619:0.000647 on interface enp3s0f0",
"curl latency: 0.000128:0.000392:0.000418 on interface enp3s0f0",
"curl latency: 0.000161:0.000594:0.000641 on interface enp3s0f0",
"curl latency: 0.000117:0.000258:0.000286 on interface enp3s0f0",
"curl latency: 0.000261:0.000661:0.000683 on interface enp3s0f0",
"curl latency: 0.000214:0.000651:0.000700 on interface enp3s0f0",
"curl latency: 0.000210:0.000631:0.000675 on interface enp3s0f0",
"curl latency: 0.000160:0.000678:0.000725 on interface enp3s0f0",
"curl latency: 0.000206:0.000547:0.000588 on interface enp3s0f0",
"curl latency: 1.020509:1.021199:1.021244 on interface enp3s0f0",
]

b_flood_rate_2_75 = 1634362
b_curl_list_2_75 = [
"curl latency: 0.000167:0.000411:0.000440 on interface enp3s0f0",
"curl latency: 0.000185:0.000548:0.000594 on interface enp3s0f0",
"curl latency: 0.000227:0.000546:0.000570 on interface enp3s0f0",
"curl latency: 0.000179:0.000527:0.000566 on interface enp3s0f0",
"curl latency: 0.000167:0.000448:0.000472 on interface enp3s0f0",
"curl latency: 0.000182:0.000406:0.000461 on interface enp3s0f0",
"curl latency: 0.000291:0.000612:0.000637 on interface enp3s0f0",
"curl latency: 0.000186:0.000468:0.000496 on interface enp3s0f0",
"curl latency: 0.001835:0.002191:0.002216 on interface enp3s0f0",
"curl latency: 0.001806:0.003583:0.003614 on interface enp3s0f0",
"curl latency: 0.001474:0.003004:0.003030 on interface enp3s0f0",
"curl latency: 0.006257:0.014456:0.014502 on interface enp3s0f0",
"curl latency: 1.006984:1.014443:1.014492 on interface enp3s0f0",
"curl latency: 0.002047:0.004339:0.004370 on interface enp3s0f0",
"curl latency: 0.007309:0.009661:0.009710 on interface enp3s0f0",
"curl latency: 0.002562:0.004931:0.004977 on interface enp3s0f0",
"curl latency: 0.002278:0.004538:0.004565 on interface enp3s0f0",
"curl latency: 0.001595:0.003080:0.003127 on interface enp3s0f0",
"curl latency: 0.002323:0.004346:0.004394 on interface enp3s0f0",
"curl latency: 0.001855:0.003863:0.003889 on interface enp3s0f0",
"curl latency: 0.002173:0.004831:0.004876 on interface enp3s0f0",
"curl latency: 0.001907:0.003833:0.003862 on interface enp3s0f0",
"curl latency: 0.002227:0.004579:0.004606 on interface enp3s0f0",
"curl latency: 0.004474:0.009200:0.009261 on interface enp3s0f0",
"curl latency: 0.006198:0.012503:0.012552 on interface enp3s0f0",
"curl latency: 0.002121:0.210748:0.210810 on interface enp3s0f0",
"curl latency: 0.002439:0.005304:0.005334 on interface enp3s0f0",
"curl latency: 0.006639:0.009070:0.009096 on interface enp3s0f0",
"curl latency: 0.002354:0.207376:0.207406 on interface enp3s0f0",
"curl latency: 0.000224:0.000458:0.000486 on interface enp3s0f0",
"curl latency: 0.000149:0.000527:0.000569 on interface enp3s0f0",
"curl latency: 0.000135:0.000342:0.000383 on interface enp3s0f0",
"curl latency: 0.000164:0.000445:0.000469 on interface enp3s0f0",
"curl latency: 0.000181:0.000354:0.000381 on interface enp3s0f0",
"curl latency: 0.000134:0.000393:0.000437 on interface enp3s0f0",
"curl latency: 0.000131:0.000326:0.000349 on interface enp3s0f0",
"curl latency: 0.001786:0.004279:0.004324 on interface enp3s0f0",
"curl latency: 0.000160:0.000362:0.000401 on interface enp3s0f0",
"curl latency: 0.008595:0.442690:0.442736 on interface enp3s0f0",

]


b_flood_rate_3 = 1783314
b_curl_list_3 = [
    
"curl latency: 0.002350:0.010858:0.010886 on interface enp3s0f0",
"curl latency: 0.001779:0.003704:0.003753 on interface enp3s0f0",
"curl latency: 0.004035:0.007179:0.007205 on interface enp3s0f0",
"curl latency: 1.024742:1.029737:1.029782 on interface enp3s0f0",
"curl latency: 0.006001:0.012135:0.012164 on interface enp3s0f0",
"curl latency: 1.017075:1.023840:1.023871 on interface enp3s0f0",
"curl latency: 0.002122:0.208948:0.209003 on interface enp3s0f0",
"curl latency: 0.002531:0.009475:0.009503 on interface enp3s0f0",
"curl latency: 1.020792:1.027157:1.027206 on interface enp3s0f0",
"curl latency: 0.004470:0.009112:0.009358 on interface enp3s0f0",
"curl latency: 0.002303:0.004582:0.004611 on interface enp3s0f0",
"curl latency: 0.008284:0.230772:0.230801 on interface enp3s0f0",
"curl latency: 0.005735:0.010154:0.010204 on interface enp3s0f0",
"curl latency: 0.001933:0.004314:0.004364 on interface enp3s0f0",
"curl latency: 0.001741:0.010160:0.010190 on interface enp3s0f0",
"curl latency: 0.002197:0.209799:0.209849 on interface enp3s0f0",
"curl latency: 0.000207:0.000499:0.000543 on interface enp3s0f0",
"curl latency: 0.006100:0.011775:0.011811 on interface enp3s0f0",
"curl latency: 0.005632:0.013628:0.013694 on interface enp3s0f0",
"curl latency: 1.009218:1.011764:1.011825 on interface enp3s0f0",
"curl latency: 0.002368:0.004868:0.004917 on interface enp3s0f0",
"curl latency: 0.006843:0.013107:0.013134 on interface enp3s0f0",
"curl latency: 0.000891:0.001918:0.001949 on interface enp3s0f0",
"curl latency: 0.001896:0.003793:0.003853 on interface enp3s0f0",
"curl latency: 0.001200:0.002709:0.002736 on interface enp3s0f0",
"curl latency: 0.002316:0.004777:0.004825 on interface enp3s0f0",
"curl latency: 0.003702:0.012333:0.012381 on interface enp3s0f0",
"curl latency: 0.002020:0.211712:0.211759 on interface enp3s0f0",
"curl latency: 0.002053:0.004102:0.004149 on interface enp3s0f0",
"curl latency: 0.001927:0.003947:0.003994 on interface enp3s0f0",
"curl latency: 0.002479:0.005879:0.005909 on interface enp3s0f0",
"curl latency: 0.007911:0.220454:0.220504 on interface enp3s0f0",
"curl latency: 0.001357:0.003236:0.003267 on interface enp3s0f0",
"curl latency: 0.000230:0.000635:0.000664 on interface enp3s0f0",
"curl latency: 0.000226:0.000574:0.000602 on interface enp3s0f0",
"curl latency: 0.002023:0.003818:0.003848 on interface enp3s0f0",
"curl latency: 1.024486:1.028324:1.028354 on interface enp3s0f0",
"curl latency: 3.021830:3.023624:3.023671 on interface enp3s0f0",
"curl latency: 0.002569:0.212443:0.212492 on interface enp3s0f0",
"curl latency: 3.028586:3.031211:3.031262 on interface enp3s0f0",
"curl latency: 0.002192:0.010954:0.011019 on interface enp3s0f0",
"curl latency: 0.002293:0.004390:0.004436 on interface enp3s0f0",

]

b_flood_rate_3_5 = 2079810
b_curl_list_3_5 = [
    
"curl latency: 0.001517:0.003151:0.003202 on interface enp3s0f0",
"curl latency: 0.002168:0.004598:0.004649 on interface enp3s0f0",
"curl latency: 0.002287:0.408748:0.408793 on interface enp3s0f0",
"curl latency: 0.001971:0.003802:0.003849 on interface enp3s0f0",
"curl latency: 1.017399:1.020259:1.020306 on interface enp3s0f0",
"curl latency: 0.002514:0.011281:0.011329 on interface enp3s0f0",
"curl latency: 0.002349:0.410551:0.410587 on interface enp3s0f0",
"curl latency: 0.007961:0.015839:0.015888 on interface enp3s0f0",
"curl latency: 0.002378:0.004693:0.004743 on interface enp3s0f0",
"curl latency: 0.002051:0.206589:0.206617 on interface enp3s0f0",
"curl latency: 1.011921:1.840420:1.840470 on interface enp3s0f0",
"curl latency: 1.013641:1.016175:1.016238 on interface enp3s0f0",
"curl latency: 0.002321:0.004031:0.004080 on interface enp3s0f0",
"curl latency: 0.002222:0.210484:0.210533 on interface enp3s0f0",
"curl latency: 0.001564:0.003215:0.003263 on interface enp3s0f0",
"curl latency: 0.002190:0.004565:0.004595 on interface enp3s0f0",
"curl latency: 0.002183:0.210510:0.210560 on interface enp3s0f0",
"curl latency: 0.002017:0.004140:0.004187 on interface enp3s0f0",
"curl latency: 1.015966:1.220080:1.220126 on interface enp3s0f0",
"curl latency: 7.242235:7.248162:7.248212 on interface enp3s0f0",
"curl latency: 1.032117:1.240337:1.240388 on interface enp3s0f0",
"curl latency: 1.027418:1.029780:1.029843 on interface enp3s0f0",
"curl latency: 0.001819:0.848057:0.848106 on interface enp3s0f0",
"curl latency: 0.002047:0.004176:0.004202 on interface enp3s0f0",
"curl latency: 1.027897:1.029796:1.029844 on interface enp3s0f0",
"curl latency: 0.004150:0.215098:0.215147 on interface enp3s0f0",
"curl latency: 3.028000:3.032132:3.032179 on interface enp3s0f0",
"curl latency: 1.002895:1.004897:1.004979 on interface enp3s0f0",
"curl latency: 0.001836:0.003657:0.003703 on interface enp3s0f0",
"curl latency: 0.001607:0.003212:0.003239 on interface enp3s0f0",
"curl latency: 1.014370:1.016198:1.016245 on interface enp3s0f0",
"curl latency: 0.001363:0.002573:0.002601 on interface enp3s0f0",
"curl latency: 0.004707:0.009888:0.009937 on interface enp3s0f0",
"curl latency: 0.003191:0.005613:0.005662 on interface enp3s0f0",
"curl latency: 1.024518:1.026426:1.026475 on interface enp3s0f0",
"curl latency: 0.008309:0.010816:0.010846 on interface enp3s0f0",
"curl latency: 0.001620:0.008191:0.008240 on interface enp3s0f0",
"curl latency: 1.032470:1.454464:1.454513 on interface enp3s0f0",
"curl latency: 0.005005:0.007867:0.007913 on interface enp3s0f0",
"curl latency: 0.002414:0.004981:0.005016 on interface enp3s0f0",
"curl latency: 0.002352:0.211476:0.211526 on interface enp3s0f0",
"curl latency: 1.003694:1.005875:1.005924 on interface enp3s0f0",
"curl latency: 0.002217:0.004251:0.004305 on interface enp3s0f0",
"curl latency: 0.003563:0.008851:0.008897 on interface enp3s0f0",
"curl latency: 1.012657:1.227188:1.227234 on interface enp3s0f0",
"curl latency: 1.017958:1.020146:1.020192 on interface enp3s0f0",

]

b_flood_rate_4 = 2376551
b_curl_list_4 = [
    
"curl latency: 0.002098:0.208433:0.208460 on interface enp3s0f0",
"curl latency: 0.001848:0.003746:0.003794 on interface enp3s0f0",
"curl latency: 0.004333:0.009226:0.009273 on interface enp3s0f0",
"curl latency: 0.002355:0.409938:0.409989 on interface enp3s0f0",
"curl latency: 1.028167:1.030865:1.030915 on interface enp3s0f0",
"curl latency: 1.009199:1.011053:1.011099 on interface enp3s0f0",
"curl latency: 0.002213:0.207682:0.207729 on interface enp3s0f0",
"curl latency: 0.001697:0.204677:0.204708 on interface enp3s0f0",
"curl latency: 0.001606:0.004235:0.004280 on interface enp3s0f0",
"curl latency: 1.006397:1.009384:1.009432 on interface enp3s0f0",
"curl latency: 0.001882:0.004245:0.004293 on interface enp3s0f0",
"curl latency: 1.025487:1.027496:1.027543 on interface enp3s0f0",
"curl latency: 0.002284:0.004637:0.004699 on interface enp3s0f0",
"curl latency: 3.042543:3.044324:3.044373 on interface enp3s0f0",
"curl latency: 0.002424:0.206923:0.206951 on interface enp3s0f0",
"curl latency: 1.016601:1.018931:1.018980 on interface enp3s0f0",
"curl latency: 1.010049:1.012312:1.012359 on interface enp3s0f0",
"curl latency: 0.001940:0.410279:0.410328 on interface enp3s0f0",
"curl latency: 1.003688:1.005898:1.005946 on interface enp3s0f0",
"curl latency: 0.001834:0.003953:0.004003 on interface enp3s0f0",
"curl latency: 0.005350:0.012264:0.012312 on interface enp3s0f0",
"curl latency: 1.005806:1.213363:1.213413 on interface enp3s0f0",
"curl latency: 0.001797:0.003756:0.003806 on interface enp3s0f0",
"curl latency: 3.028379:3.030803:3.030848 on interface enp3s0f0",
"curl latency: 0.005526:0.011761:0.011807 on interface enp3s0f0",
"curl latency: 0.005311:0.212688:0.212738 on interface enp3s0f0",
"curl latency: 0.006706:0.224890:0.224938 on interface enp3s0f0",
"curl latency: 1.003343:1.005755:1.005807 on interface enp3s0f0",
"curl latency: 0.006000:0.010657:0.010683 on interface enp3s0f0",
"curl latency: 0.002786:0.419034:0.419084 on interface enp3s0f0",
"curl latency: 0.002050:0.420444:0.420495 on interface enp3s0f0",
"curl latency: 0.002546:0.005150:0.005179 on interface enp3s0f0",
"curl latency: 0.002029:0.004509:0.004559 on interface enp3s0f0",
"curl latency: 3.036351:3.038393:3.038444 on interface enp3s0f0",
"curl latency: 7.090831:7.506622:7.506659 on interface enp3s0f0",
"curl latency: 0.002577:0.005029:0.005087 on interface enp3s0f0",
"curl latency: 7.236084:7.651033:7.651082 on interface enp3s0f0",
"curl latency: 0.001768:0.003552:0.003601 on interface enp3s0f0",
"curl latency: 0.001979:0.209591:0.209639 on interface enp3s0f0",
"curl latency: 1.031577:1.033307:1.033353 on interface enp3s0f0",
"curl latency: 0.002127:0.004089:0.004120 on interface enp3s0f0",
"curl latency: 0.005689:0.216745:0.216794 on interface enp3s0f0",
"curl latency: 3.047652:3.268617:3.268663 on interface enp3s0f0",
]


#note, modified the format of the next few measurements, adjust string extraction for average calculation in next cell 
b_flood_rate_4_5 = 2682998
b_curl_list_4_5 = [

"curl latency: 01.009363:01.011699:01.011748 on interface enp3s0f0",
"curl latency: 00.001790:00.003483:00.003509 on interface enp3s0f0",
"curl latency: 00.002416:00.211736:00.211767 on interface enp3s0f0",
"curl latency: 00.002506:00.211665:00.211713 on interface enp3s0f0",
"curl latency: 03.047597:03.051409:03.051457 on interface enp3s0f0",
"curl latency: 00.006495:00.219728:00.219755 on interface enp3s0f0",
"curl latency: 00.001678:00.003411:00.003462 on interface enp3s0f0",
"curl latency: 00.001745:00.003565:00.003612 on interface enp3s0f0",
"curl latency: 00.002386:00.004872:00.004896 on interface enp3s0f0",
"curl latency: 00.002423:00.830734:00.830783 on interface enp3s0f0",
"curl latency: 03.030670:03.035605:03.035651 on interface enp3s0f0",
"curl latency: 00.003168:00.215861:00.215886 on interface enp3s0f0",
"curl latency: 00.002358:00.843455:00.843505 on interface enp3s0f0",
"curl latency: 00.008542:00.015814:00.015873 on interface enp3s0f0",
"curl latency: 00.002396:00.212603:00.212652 on interface enp3s0f0",
"curl latency: 01.013188:01.221302:01.221348 on interface enp3s0f0",
"curl latency: 00.008047:00.010228:00.010277 on interface enp3s0f0",
"curl latency: 01.006733:01.214743:01.214794 on interface enp3s0f0",
"curl latency: 00.005236:00.211409:00.211455 on interface enp3s0f0",
"curl latency: 03.043997:06.372026:06.372084 on interface enp3s0f0",
"curl latency: 00.004437:00.008659:00.008696 on interface enp3s0f0",
"curl latency: 00.008012:00.015230:00.015258 on interface enp3s0f0",
"curl latency: 00.001751:00.005977:00.006026 on interface enp3s0f0",
"curl latency: 00.002032:00.419217:00.419262 on interface enp3s0f0",
"curl latency: 00.001753:00.003566:00.003596 on interface enp3s0f0",
"curl latency: 01.018118:01.226196:01.226242 on interface enp3s0f0",
"curl latency: 00.005375:01.731704:01.731753 on interface enp3s0f0",
"curl latency: 00.002001:00.003985:00.004016 on interface enp3s0f0",
"curl latency: 03.048506:03.472134:03.472163 on interface enp3s0f0",
"curl latency: 00.001782:00.003614:00.003642 on interface enp3s0f0",
"curl latency: 00.002206:00.004355:00.004403 on interface enp3s0f0",
"curl latency: 01.005547:01.421664:01.421691 on interface enp3s0f0",
"curl latency: 15.475680:15.679792:15.679841 on interface enp3s0f0",
"curl latency: 03.044938:03.877528:03.877577 on interface enp3s0f0",
"curl latency: 00.003254:00.006382:00.006458 on interface enp3s0f0",
"curl latency: 00.001932:00.003824:00.003874 on interface enp3s0f0",
"curl latency: 00.002421:00.410469:00.410516 on interface enp3s0f0",

]

b_flood_rate_5 = 2969853
b_curl_list_5 = [
    
"curl latency: 00.002700:00.206088:00.206121 on interface enp3s0f0",
"curl latency: 00.001890:00.839666:00.839712 on interface enp3s0f0",
"curl latency: 01.008406:01.416052:01.416112 on interface enp3s0f0",
"curl latency: 00.001975:01.663866:01.663917 on interface enp3s0f0",
"curl latency: 01.006946:01.010120:01.010165 on interface enp3s0f0",
"curl latency: 01.008264:01.010478:01.010526 on interface enp3s0f0",
"curl latency: 03.026610:03.029102:03.029128 on interface enp3s0f0",
"curl latency: 01.012095:01.017325:01.017372 on interface enp3s0f0",
"curl latency: 15.339042:15.547636:15.547684 on interface enp3s0f0",
"curl latency: 00.002264:00.004664:00.004691 on interface enp3s0f0",
"curl latency: 01.011460:01.013524:01.013572 on interface enp3s0f0",
"curl latency: 00.001833:00.206751:00.206800 on interface enp3s0f0",
"curl latency: 03.032291:03.235502:03.235565 on interface enp3s0f0",
"curl latency: 00.002252:00.004494:00.004553 on interface enp3s0f0",
"curl latency: 00.002263:00.210213:00.210262 on interface enp3s0f0",
"curl latency: 00.003006:00.206529:00.206575 on interface enp3s0f0",
"curl latency: 00.001957:00.411975:00.412021 on interface enp3s0f0",
"curl latency: 00.001894:00.409728:00.409778 on interface enp3s0f0",
"curl latency: 01.009525:01.011904:01.011950 on interface enp3s0f0",
"curl latency: 00.002284:00.004763:00.004833 on interface enp3s0f0",
"curl latency: 03.040167:03.044571:03.044631 on interface enp3s0f0",
"curl latency: 00.005809:00.219079:00.219128 on interface enp3s0f0",
"curl latency: 00.005824:00.432448:00.432507 on interface enp3s0f0",
"curl latency: 03.018486:03.020498:03.020546 on interface enp3s0f0",
"curl latency: 00.001766:00.003608:00.003656 on interface enp3s0f0",
"curl latency: 00.001453:00.003170:00.003199 on interface enp3s0f0",
"curl latency: 00.001644:00.003386:00.003415 on interface enp3s0f0",
"curl latency: 00.001852:00.417767:00.417816 on interface enp3s0f0",
"curl latency: 00.001668:00.208381:00.208428 on interface enp3s0f0",
"curl latency: 03.039499:03.453661:03.453710 on interface enp3s0f0",
"curl latency: 00.001928:00.004458:00.004488 on interface enp3s0f0",
"curl latency: 63.910602:63.912516:63.912581 on interface enp3s0f0",
"curl latency: 00.001704:00.003471:00.003503 on interface enp3s0f0",
"curl latency: 07.144647:07.147947:07.147997 on interface enp3s0f0",
"curl latency: 00.002328:00.004430:00.004494 on interface enp3s0f0",
"curl latency: 00.006043:00.012106:00.012137 on interface enp3s0f0",
"curl latency: 07.109122:07.111266:07.111312 on interface enp3s0f0",
"curl latency: 01.010539:01.219331:01.219392 on interface enp3s0f0",
"curl latency: 01.027172:01.031038:01.031089 on interface enp3s0f0",
"curl latency: 03.023489:03.232076:03.232122 on interface enp3s0f0",
"curl latency: 00.002493:00.004875:00.004903 on interface enp3s0f0",
"curl latency: 00.006484:00.224094:00.224144 on interface enp3s0f0",
"curl latency: 00.002131:00.004283:00.004345 on interface enp3s0f0",
"curl latency: 00.001907:00.209876:00.209927 on interface enp3s0f0",
"curl latency: 00.002386:00.214503:00.214552 on interface enp3s0f0",
"curl latency: 01.016548:01.437745:01.437794 on interface enp3s0f0",
"curl latency: 00.007705:00.223703:00.223749 on interface enp3s0f0",
"curl latency: 01.029912:01.036335:01.036398 on interface enp3s0f0",
"curl latency: 01.003424:01.005896:01.005946 on interface enp3s0f0",
"curl latency: 01.008556:01.010801:01.010847 on interface enp3s0f0",
"curl latency: 00.007910:00.221339:00.221385 on interface enp3s0f0",
"curl latency: 01.032788:01.041811:01.041858 on interface enp3s0f0",
"curl latency: 07.144645:07.980315:07.980363 on interface enp3s0f0",
"curl latency: 00.002603:00.419975:00.420025 on interface enp3s0f0",
"curl latency: 00.002508:00.004961:00.004995 on interface enp3s0f0",
"curl latency: 00.008212:00.229672:00.229719 on interface enp3s0f0",
"curl latency: 00.002335:00.209740:00.209790 on interface enp3s0f0",
"curl latency: 03.042873:03.252455:03.252505 on interface enp3s0f0",
"curl latency: 01.027751:01.239370:01.239419 on interface enp3s0f0",
"curl latency: 00.001950:00.213429:00.213479 on interface enp3s0f0",
"curl latency: 01.022732:01.231796:01.231848 on interface enp3s0f0",
"curl latency: 00.002280:00.004520:00.004551 on interface enp3s0f0",
"curl latency: 01.007795:01.011124:01.011188 on interface enp3s0f0",
"curl latency: 00.002344:00.005450:00.005509 on interface enp3s0f0",
"curl latency: 01.030175:01.037796:01.037844 on interface enp3s0f0",

]

b_flood_rate_6 = 3632537
b_curl_list_6 = [
    
"curl latency: 03.041948:03.246502:03.246566 on interface enp3s0f0",
"curl latency: 00.006147:00.008208:00.008255 on interface enp3s0f0",
"curl latency: 01.011708:01.013298:01.013338 on interface enp3s0f0",
"curl latency: 07.253984:08.088578:08.088627 on interface enp3s0f0",
"curl latency: 01.007475:01.424351:01.424378 on interface enp3s0f0",
"curl latency: 01.013617:01.018100:01.018150 on interface enp3s0f0",
"curl latency: 15.378317:15.385729:15.385782 on interface enp3s0f0",
"curl latency: 07.143278:07.146494:07.146541 on interface enp3s0f0",
"curl latency: 00.002170:00.004775:00.004823 on interface enp3s0f0",
"curl latency: 00.002195:06.624464:06.624512 on interface enp3s0f0",
"curl latency: 00.002200:00.211555:00.211603 on interface enp3s0f0",
"curl latency: 07.190469:08.916746:08.916808 on interface enp3s0f0",
"curl latency: 31.538314:31.540852:31.540902 on interface enp3s0f0",
"curl latency: 01.011108:01.418915:01.418965 on interface enp3s0f0",
"curl latency: 15.451108:15.859288:15.859339 on interface enp3s0f0",
"curl latency: 07.259662:07.261694:07.261743 on interface enp3s0f0",
"curl latency: 07.154315:07.359616:07.359664 on interface enp3s0f0",
"curl latency: 15.399169:42.024067:42.024113 on interface enp3s0f0",
"curl latency: 00.002122:00.004242:00.004272 on interface enp3s0f0",
"curl latency: 00.001926:00.208754:00.208803 on interface enp3s0f0",
"curl latency: 15.368599:16.200919:16.200966 on interface enp3s0f0",
"curl latency: 00.001894:00.207417:00.207466 on interface enp3s0f0",
"curl latency: 07.128113:07.332716:07.332766 on interface enp3s0f0",
"curl latency: 03.046874:03.050154:03.050205 on interface enp3s0f0",
"curl latency: 01.007979:02.671964:02.672013 on interface enp3s0f0",
"curl latency: 00.002045:00.211529:00.211578 on interface enp3s0f0",
"curl latency: 00.001796:00.819747:00.819792 on interface enp3s0f0",
"curl latency: 01.012239:01.014647:01.014711 on interface enp3s0f0",
"curl latency: 07.060143:07.068950:07.068997 on interface enp3s0f0",
"curl latency: 03.047048:03.463087:03.463134 on interface enp3s0f0",
"curl latency: 00.001886:01.684395:01.684442 on interface enp3s0f0",
"curl latency: 03.030827:03.036926:03.037004 on interface enp3s0f0",
"curl latency: 00.006808:01.743456:01.743502 on interface enp3s0f0",
"curl latency: 00.002481:00.004543:00.004593 on interface enp3s0f0",
"curl latency: 01.024518:01.231896:01.231945 on interface enp3s0f0",
"curl latency: 07.171756:07.380037:07.380097 on interface enp3s0f0",
"curl latency: 00.001567:00.416128:00.416173 on interface enp3s0f0",
"curl latency: 01.016892:01.850441:01.850490 on interface enp3s0f0",
"curl latency: 00.002043:00.004050:00.004102 on interface enp3s0f0",
"curl latency: 00.001754:00.003527:00.003557 on interface enp3s0f0",
"curl latency: 00.002560:00.211202:00.211231 on interface enp3s0f0",
    
]

b_flood_rate_7 =4212309 
b_curl_list_7 = [
    
"curl latency: 00.006255:00.224989:00.225036 on interface enp3s0f0",
"curl latency: 15.392942:15.395758:15.395808 on interface enp3s0f0",
"curl latency: 01.006711:01.008418:01.008466 on interface enp3s0f0",
"curl latency: 00.001665:00.003639:00.003668 on interface enp3s0f0",
"curl latency: 00.002805:00.004872:00.004905 on interface enp3s0f0",
"curl latency: 01.017217:01.020586:01.020636 on interface enp3s0f0",
"curl latency: 00.002162:00.004575:00.004601 on interface enp3s0f0",
"curl latency: 03.035806:03.872191:03.872239 on interface enp3s0f0",
"curl latency: 01.008249:01.216234:01.216283 on interface enp3s0f0",
"curl latency: 01.033950:01.460158:01.460182 on interface enp3s0f0",
"curl latency: 15.363346:16.195413:16.195461 on interface enp3s0f0",
"curl latency: 00.003045:01.686654:01.686681 on interface enp3s0f0",
"curl latency: 15.377188:17.040688:17.040735 on interface enp3s0f0",
"curl latency: 31.607536:31.616070:31.616099 on interface enp3s0f0",
"curl latency: 01.031189:02.697116:02.697163 on interface enp3s0f0",
"curl latency: 15.442461:15.657041:15.657089 on interface enp3s0f0",
"curl latency: 00.000000:00.000000:130.84271 on interface enp3s0f0",
"curl latency: 01.015262:01.020422:01.020472 on interface enp3s0f0",
"curl latency: 00.002228:00.417084:00.417133 on interface enp3s0f0",
"curl latency: 00.001763:00.211842:00.211892 on interface enp3s0f0",
"curl latency: 00.001820:00.003831:00.003891 on interface enp3s0f0",
"curl latency: 03.025781:03.028644:03.028707 on interface enp3s0f0",
"curl latency: 00.002300:00.848786:00.848833 on interface enp3s0f0",
"curl latency: 07.187999:10.520441:10.520507 on interface enp3s0f0",
"curl latency: 00.002552:00.211669:00.211719 on interface enp3s0f0",
"curl latency: 03.024249:03.441518:03.441564 on interface enp3s0f0",
"curl latency: 03.033616:03.042151:03.042197 on interface enp3s0f0",
"curl latency: 01.030604:01.894293:01.894343 on interface enp3s0f0",
"curl latency: 00.006156:00.854896:00.854942 on interface enp3s0f0",
"curl latency: 00.005529:00.011541:00.011605 on interface enp3s0f0",
"curl latency: 00.001550:01.693430:01.693481 on interface enp3s0f0",
"curl latency: 03.023155:03.025807:03.025857 on interface enp3s0f0",
"curl latency: 00.007621:06.964803:06.964853 on interface enp3s0f0",
"curl latency: 07.157991:07.160478:07.160539 on interface enp3s0f0",
"curl latency: 31.471244:32.298626:32.298677 on interface enp3s0f0",
"curl latency: 01.011412:01.843520:01.843550 on interface enp3s0f0",
"curl latency: 15.475865:16.308636:16.308685 on interface enp3s0f0",
    
]


b_flood_rate_10 = 6022161
b_curl_list_10 = [
"curl latency: 03.041083:03.043786:03.043833 on interface enp3s0f0",
"curl latency: 15.249969:15.460116:15.460163 on interface enp3s0f0",
"curl latency: 64.289293:67.617470:67.617518 on interface enp3s0f0",
"curl latency: 15.347960:18.679651:18.679715 on interface enp3s0f0",
"curl latency: 00.004784:00.848117:00.848166 on interface enp3s0f0",
"curl latency: 07.059834:07.891369:07.891429 on interface enp3s0f0",
"curl latency: 01.012763:01.015304:01.015351 on interface enp3s0f0",
"curl latency: 00.002167:00.004375:00.004403 on interface enp3s0f0",
"curl latency: 03.040748:03.042837:03.042886 on interface enp3s0f0",
"curl latency: 65.462604:67.191489:67.191536 on interface enp3s0f0",
"curl latency: 00.000000:00.000000:129.32463 on interface enp3s0f0",
"curl latency: 00.003853:00.214196:00.214247 on interface enp3s0f0",
"curl latency: 03.027060:03.029031:03.029082 on interface enp3s0f0",
"curl latency: 00.000000:00.000000:129.84093 on interface enp3s0f0",
"curl latency: 01.013639:01.015513:01.015578 on interface enp3s0f0",
"curl latency: 07.154520:07.157255:07.157282 on interface enp3s0f0",
"curl latency: 31.474170:31.890919:31.890966 on interface enp3s0f0",
"curl latency: 07.251610:08.089765:08.089816 on interface enp3s0f0",
"curl latency: 03.025552:06.446136:06.446186 on interface enp3s0f0",
"curl latency: 03.029027:03.444013:03.444063 on interface enp3s0f0",
"curl latency: 15.351894:16.213627:16.213675 on interface enp3s0f0",
"curl latency: 31.380122:32.213984:32.214031 on interface enp3s0f0",
"curl latency: 01.006705:01.424436:01.424483 on interface enp3s0f0",
"curl latency: 07.186974:07.189309:07.189359 on interface enp3s0f0",
"curl latency: 03.029284:03.457434:03.457485 on interface enp3s0f0",
"curl latency: 01.028040:01.035495:01.035545 on interface enp3s0f0",
"curl latency: 00.007966:00.878567:00.878616 on interface enp3s0f0",
"curl latency: 07.122231:07.954604:07.954667 on interface enp3s0f0",
"curl latency: 03.027151:03.235814:03.235860 on interface enp3s0f0",
"curl latency: 00.002222:00.424638:00.424689 on interface enp3s0f0",
"curl latency: 00.006478:00.431369:00.431419 on interface enp3s0f0",
"curl latency: 00.000000:00.000000:129.42544 on interface enp3s0f0",
"curl latency: 01.013999:01.222454:01.222508 on interface enp3s0f0",
"curl latency: 00.002233:00.005923:00.005971 on interface enp3s0f0",
"curl latency: 03.027605:03.030983:03.031034 on interface enp3s0f0",
"curl latency: 03.023948:03.439710:03.439760 on interface enp3s0f0",
"curl latency: 07.091813:07.507461:07.507510 on interface enp3s0f0",
"curl latency: 31.572107:31.987676:31.987723 on interface enp3s0f0",
]

# %%
# Application Latency Measurements 

b_curl_list_name = [b_curl_list_0_1, b_curl_list_0_5, b_curl_list_1, b_curl_list_1_5, b_curl_list_2, 
                    b_curl_list_2_1, b_curl_list_2_2, b_curl_list_2_4,
                    b_curl_list_2_5, b_curl_list_2_75, b_curl_list_3, b_curl_list_3_5, b_curl_list_4]

b_curl_list_name_long = [b_curl_list_4_5, b_curl_list_5, b_curl_list_6, b_curl_list_7, b_curl_list_10]


b_flood_rate = [b_flood_rate_0_1, b_flood_rate_0_5, b_flood_rate_1, b_flood_rate_1_5, b_flood_rate_2, 
                b_flood_rate_2_5, b_flood_rate_2_75, b_flood_rate_3, b_flood_rate_3_5, b_flood_rate_4,
                b_flood_rate_4_5, b_flood_rate_5, b_flood_rate_6, b_flood_rate_7, b_flood_rate_10]
b_curl_latency = [] 

#change name of list to get the average from that list 

for list in b_curl_list_name: 
    sum = 0
    count = 0 
    for i in list:
        time_connect = i[14:22]
        time_start = i[23:31]
        time_total = i[32:40]
        #print(time_connect, time_start, time_total)
        sum += float(time_total)
        count+=1
    avg = sum/count
    b_curl_latency.append(avg)
    #print(sum, count, avg)
    
#need to account for longer latencies in format xx.xxxx  
for list in b_curl_list_name_long: 
    sum = 0
    count = 0 
    for i in list:
        time_connect = i[14:23]
        time_start = i[24:33]
        time_total = i[34:43]
        #print(time_connect, time_start, time_total)
        sum += float(time_total)
        count+=1
    avg = sum/count
    b_curl_latency.append(avg)
    
        
print(b_curl_latency)
# Out:
# [0.0002733823529411764, 0.00025875609756097564, 0.0005961764705882353, 0.00041054285714285714, 0.0011867714285714287, 0.0021222258064516135, 0.0014198387096774191, 0.03451659375, 0.032280717948717945, 0.05116564102564103, 0.3014368571428571, 0.6367257173913045, 0.961680581395349, 1.2757092162162165, 2.3142241692307692, 5.32624263414634, 9.047329972972973, 19.90335671052631]

# %%
#Additional data points for the base line --> this data is no good, it was collected on the cabernet testbed 
b2_data = []

b2_data.append((0.01,"curl latency: 0.000766 on interface enp134s0f0",
"curl latency: 0.000906 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000706 on interface enp134s0f0",
"curl latency: 0.000807 on interface enp134s0f0",
"curl latency: 0.000887 on interface enp134s0f0",
"curl latency: 0.000823 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000721 on interface enp134s0f0",
"curl latency: 0.000730 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000685 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000643 on interface enp134s0f0",
"curl latency: 0.000734 on interface enp134s0f0",
"curl latency: 0.000636 on interface enp134s0f0",
"curl latency: 0.000640 on interface enp134s0f0",
"curl latency: 0.000884 on interface enp134s0f0",
"curl latency: 0.000875 on interface enp134s0f0",
"curl latency: 0.000732 on interface enp134s0f0",
"curl latency: 0.000698 on interface enp134s0f0",
"curl latency: 0.000673 on interface enp134s0f0",
"curl latency: 0.000668 on interface enp134s0f0",))

b2_data.append((0.74,"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000684 on interface enp134s0f0",
"curl latency: 0.000704 on interface enp134s0f0",
"curl latency: 0.000847 on interface enp134s0f0",
"curl latency: 0.000851 on interface enp134s0f0",
"curl latency: 0.000667 on interface enp134s0f0",
"curl latency: 0.000840 on interface enp134s0f0",
"curl latency: 0.000722 on interface enp134s0f0",
"curl latency: 0.000911 on interface enp134s0f0",
"curl latency: 0.000754 on interface enp134s0f0",
"curl latency: 0.000661 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000672 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000699 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.001294 on interface enp134s0f0",
"curl latency: 0.001073 on interface enp134s0f0",
"curl latency: 0.000676 on interface enp134s0f0",
"curl latency: 0.000766 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000716 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000689 on interface enp134s0f0",
"curl latency: 0.000707 on interface enp134s0f0",
"curl latency: 0.000710 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000642 on interface enp134s0f0",
"curl latency: 0.000932 on interface enp134s0f0",
"curl latency: 0.000811 on interface enp134s0f0",))

b2_data.append((1.03,"curl latency: 0.000814 on interface enp134s0f0",
"curl latency: 0.000848 on interface enp134s0f0",
"curl latency: 0.000803 on interface enp134s0f0",
"curl latency: 0.000656 on interface enp134s0f0",
"curl latency: 0.000868 on interface enp134s0f0",
"curl latency: 0.001185 on interface enp134s0f0",
"curl latency: 0.001092 on interface enp134s0f0",
"curl latency: 0.000879 on interface enp134s0f0",
"curl latency: 0.000729 on interface enp134s0f0",
"curl latency: 0.000700 on interface enp134s0f0",
"curl latency: 0.000850 on interface enp134s0f0",
"curl latency: 0.000837 on interface enp134s0f0",
"curl latency: 0.000902 on interface enp134s0f0",
"curl latency: 0.000654 on interface enp134s0f0",
"curl latency: 0.000893 on interface enp134s0f0",
"curl latency: 0.000863 on interface enp134s0f0",
"curl latency: 0.000754 on interface enp134s0f0",
"curl latency: 0.000749 on interface enp134s0f0",
"curl latency: 0.000665 on interface enp134s0f0",
"curl latency: 0.000753 on interface enp134s0f0",
"curl latency: 0.000934 on interface enp134s0f0",
"curl latency: 0.001224 on interface enp134s0f0",
"curl latency: 0.000838 on interface enp134s0f0",
"curl latency: 0.001036 on interface enp134s0f0",
"curl latency: 0.000787 on interface enp134s0f0",
"curl latency: 0.000721 on interface enp134s0f0",
"curl latency: 0.000904 on interface enp134s0f0",
"curl latency: 0.000753 on interface enp134s0f0",
"curl latency: 0.001109 on interface enp134s0f0",
"curl latency: 0.001077 on interface enp134s0f0",
"curl latency: 0.000713 on interface enp134s0f0",
"curl latency: 0.000843 on interface enp134s0f0",
"curl latency: 0.000785 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",))


b2_data.append((1.3,"curl latency: 0.001080 on interface enp134s0f0",
"curl latency: 0.001039 on interface enp134s0f0",
"curl latency: 0.001309 on interface enp134s0f0",
"curl latency: 0.000692 on interface enp134s0f0",
"curl latency: 0.000721 on interface enp134s0f0",
"curl latency: 0.000766 on interface enp134s0f0",
"curl latency: 0.000716 on interface enp134s0f0",
"curl latency: 0.000748 on interface enp134s0f0",
"curl latency: 0.001329 on interface enp134s0f0",
"curl latency: 0.000926 on interface enp134s0f0",
"curl latency: 0.000892 on interface enp134s0f0",
"curl latency: 0.000895 on interface enp134s0f0",
"curl latency: 0.000736 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.001183 on interface enp134s0f0",
"curl latency: 0.001388 on interface enp134s0f0",
"curl latency: 0.000789 on interface enp134s0f0",
"curl latency: 0.000864 on interface enp134s0f0",
"curl latency: 0.001042 on interface enp134s0f0",
"curl latency: 0.000898 on interface enp134s0f0",
"curl latency: 0.000746 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000841 on interface enp134s0f0",
"curl latency: 0.000834 on interface enp134s0f0",
"curl latency: 0.000932 on interface enp134s0f0",
"curl latency: 0.000768 on interface enp134s0f0",
"curl latency: 0.000909 on interface enp134s0f0",))

b2_data.append((1.36,"curl latency: 0.000812 on interface enp134s0f0",
"curl latency: 0.000747 on interface enp134s0f0",
"curl latency: 0.001950 on interface enp134s0f0",
"curl latency: 0.001065 on interface enp134s0f0",
"curl latency: 0.001104 on interface enp134s0f0",
"curl latency: 0.000825 on interface enp134s0f0",
"curl latency: 0.000829 on interface enp134s0f0",
"curl latency: 0.000735 on interface enp134s0f0",
"curl latency: 0.001084 on interface enp134s0f0",
"curl latency: 0.001685 on interface enp134s0f0",
"curl latency: 0.000806 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",
"curl latency: 0.000871 on interface enp134s0f0",
"curl latency: 0.001442 on interface enp134s0f0",
"curl latency: 0.000716 on interface enp134s0f0",
"curl latency: 0.000811 on interface enp134s0f0",
"curl latency: 0.000932 on interface enp134s0f0",
"curl latency: 0.001291 on interface enp134s0f0",
"curl latency: 0.001185 on interface enp134s0f0",
"curl latency: 0.000879 on interface enp134s0f0",
"curl latency: 0.000856 on interface enp134s0f0",
"curl latency: 0.000930 on interface enp134s0f0",
"curl latency: 0.001070 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.001241 on interface enp134s0f0",
"curl latency: 0.001060 on interface enp134s0f0",
"curl latency: 0.001764 on interface enp134s0f0",
"curl latency: 0.001090 on interface enp134s0f0",
"curl latency: 0.000894 on interface enp134s0f0",
"curl latency: 0.001591 on interface enp134s0f0",
"curl latency: 0.000721 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000766 on interface enp134s0f0",
"curl latency: 0.000829 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.001737 on interface enp134s0f0",
"curl latency: 0.000933 on interface enp134s0f0",))

b2_data.append((1.4,"curl latency: 0.000639 on interface enp134s0f0",
"curl latency: 0.000840 on interface enp134s0f0",
"curl latency: 0.001147 on interface enp134s0f0",
"curl latency: 0.001023 on interface enp134s0f0",
"curl latency: 0.000798 on interface enp134s0f0",
"curl latency: 0.000874 on interface enp134s0f0",
"curl latency: 0.000804 on interface enp134s0f0",
"curl latency: 0.000843 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.001026 on interface enp134s0f0",
"curl latency: 0.000797 on interface enp134s0f0",
"curl latency: 0.001152 on interface enp134s0f0",
"curl latency: 0.001734 on interface enp134s0f0",
"curl latency: 0.001550 on interface enp134s0f0",
"curl latency: 0.001644 on interface enp134s0f0",
"curl latency: 0.000910 on interface enp134s0f0",
"curl latency: 0.001013 on interface enp134s0f0",
"curl latency: 0.000850 on interface enp134s0f0",
"curl latency: 0.000949 on interface enp134s0f0",
"curl latency: 0.001037 on interface enp134s0f0",
"curl latency: 0.001074 on interface enp134s0f0",
"curl latency: 0.001089 on interface enp134s0f0",
"curl latency: 0.000919 on interface enp134s0f0",
"curl latency: 0.000779 on interface enp134s0f0",
"curl latency: 0.000897 on interface enp134s0f0",
"curl latency: 0.000804 on interface enp134s0f0",
"curl latency: 0.000756 on interface enp134s0f0",
"curl latency: 0.001409 on interface enp134s0f0",
"curl latency: 0.001119 on interface enp134s0f0",
"curl latency: 0.001036 on interface enp134s0f0",
"curl latency: 0.000718 on interface enp134s0f0",
"curl latency: 0.000801 on interface enp134s0f0",
"curl latency: 0.001042 on interface enp134s0f0",
"curl latency: 0.000856 on interface enp134s0f0",
"curl latency: 0.000824 on interface enp134s0f0",))

b2_data.append((1.45,"curl latency: 0.000826 on interface enp134s0f0",
"curl latency: 0.000974 on interface enp134s0f0",
"curl latency: 0.000867 on interface enp134s0f0",
"curl latency: 0.001068 on interface enp134s0f0",
"curl latency: 0.001036 on interface enp134s0f0",
"curl latency: 0.000935 on interface enp134s0f0",
"curl latency: 0.000930 on interface enp134s0f0",
"curl latency: 0.000787 on interface enp134s0f0",
"curl latency: 0.000909 on interface enp134s0f0",
"curl latency: 0.001211 on interface enp134s0f0",
"curl latency: 0.001031 on interface enp134s0f0",
"curl latency: 0.000832 on interface enp134s0f0",
"curl latency: 0.000897 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000824 on interface enp134s0f0",
"curl latency: 0.001001 on interface enp134s0f0",
"curl latency: 0.000789 on interface enp134s0f0",
"curl latency: 0.000931 on interface enp134s0f0",
"curl latency: 0.000718 on interface enp134s0f0",
"curl latency: 0.000980 on interface enp134s0f0",
"curl latency: 0.001440 on interface enp134s0f0",
"curl latency: 0.000949 on interface enp134s0f0",
"curl latency: 0.000928 on interface enp134s0f0",
"curl latency: 0.000903 on interface enp134s0f0",
"curl latency: 0.000709 on interface enp134s0f0",
"curl latency: 0.000893 on interface enp134s0f0",
"curl latency: 0.000994 on interface enp134s0f0",
"curl latency: 0.000861 on interface enp134s0f0",
"curl latency: 0.000893 on interface enp134s0f0",
"curl latency: 0.001127 on interface enp134s0f0",
"curl latency: 0.000879 on interface enp134s0f0",
"curl latency: 0.000920 on interface enp134s0f0",
"curl latency: 0.000862 on interface enp134s0f0",
"curl latency: 0.000837 on interface enp134s0f0",
"curl latency: 0.001005 on interface enp134s0f0",))

b2_data.append((1.48,"curl latency: 0.000660 on interface enp134s0f0",
"curl latency: 0.000996 on interface enp134s0f0",
"curl latency: 0.001659 on interface enp134s0f0",
"curl latency: 0.000877 on interface enp134s0f0",
"curl latency: 0.000713 on interface enp134s0f0",
"curl latency: 0.001242 on interface enp134s0f0",
"curl latency: 0.001111 on interface enp134s0f0",
"curl latency: 0.000877 on interface enp134s0f0",
"curl latency: 0.000736 on interface enp134s0f0",
"curl latency: 0.000788 on interface enp134s0f0",
"curl latency: 0.000760 on interface enp134s0f0",
"curl latency: 0.000899 on interface enp134s0f0",
"curl latency: 0.001118 on interface enp134s0f0",
"curl latency: 0.000883 on interface enp134s0f0",
"curl latency: 0.000682 on interface enp134s0f0",
"curl latency: 0.000973 on interface enp134s0f0",
"curl latency: 0.002727 on interface enp134s0f0",
"curl latency: 0.000857 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000775 on interface enp134s0f0",
"curl latency: 0.000856 on interface enp134s0f0",
"curl latency: 0.001092 on interface enp134s0f0",
"curl latency: 0.001564 on interface enp134s0f0",
"curl latency: 0.001167 on interface enp134s0f0",
"curl latency: 0.000825 on interface enp134s0f0",
"curl latency: 0.000850 on interface enp134s0f0",
"curl latency: 0.000857 on interface enp134s0f0",
"curl latency: 0.000824 on interface enp134s0f0",
"curl latency: 0.001331 on interface enp134s0f0",
"curl latency: 0.000791 on interface enp134s0f0",))

b2_data.append((1.49,"curl latency: 0.000873 on interface enp134s0f0",
"curl latency: 0.001012 on interface enp134s0f0",
"curl latency: 0.001373 on interface enp134s0f0",
"curl latency: 0.001517 on interface enp134s0f0",
"curl latency: 0.001251 on interface enp134s0f0",
"curl latency: 0.000854 on interface enp134s0f0",
"curl latency: 0.000858 on interface enp134s0f0",
"curl latency: 0.000860 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.001452 on interface enp134s0f0",
"curl latency: 0.001848 on interface enp134s0f0",
"curl latency: 0.000693 on interface enp134s0f0",
"curl latency: 0.001027 on interface enp134s0f0",
"curl latency: 0.000831 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000773 on interface enp134s0f0",
"curl latency: 0.000852 on interface enp134s0f0",
"curl latency: 0.001421 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.001084 on interface enp134s0f0",
"curl latency: 0.000982 on interface enp134s0f0",
"curl latency: 0.000745 on interface enp134s0f0",
"curl latency: 0.000993 on interface enp134s0f0",
"curl latency: 0.001049 on interface enp134s0f0",
"curl latency: 0.001023 on interface enp134s0f0",
"curl latency: 0.001020 on interface enp134s0f0",
"curl latency: 0.000831 on interface enp134s0f0",
"curl latency: 0.001021 on interface enp134s0f0",
"curl latency: 0.000845 on interface enp134s0f0",))

b2_data.append((1.63,"curl latency: 0.001303 on interface enp134s0f0",
"curl latency: 0.000980 on interface enp134s0f0",
"curl latency: 0.001698 on interface enp134s0f0",
"curl latency: 0.001763 on interface enp134s0f0",
"curl latency: 0.001363 on interface enp134s0f0",
"curl latency: 0.001030 on interface enp134s0f0",
"curl latency: 0.000785 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.001018 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.001640 on interface enp134s0f0",
"curl latency: 0.001367 on interface enp134s0f0",
"curl latency: 0.001503 on interface enp134s0f0",
"curl latency: 0.001268 on interface enp134s0f0",
"curl latency: 0.000946 on interface enp134s0f0",
"curl latency: 0.000762 on interface enp134s0f0",
"curl latency: 0.000913 on interface enp134s0f0",
"curl latency: 0.000784 on interface enp134s0f0",
"curl latency: 0.001302 on interface enp134s0f0",
"curl latency: 0.000857 on interface enp134s0f0",
"curl latency: 0.001158 on interface enp134s0f0",
"curl latency: 0.001295 on interface enp134s0f0",
"curl latency: 0.000730 on interface enp134s0f0",
"curl latency: 0.000870 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.001469 on interface enp134s0f0",
"curl latency: 0.001741 on interface enp134s0f0",
"curl latency: 0.001510 on interface enp134s0f0",
"curl latency: 0.000861 on interface enp134s0f0",
"curl latency: 0.001033 on interface enp134s0f0",
"curl latency: 0.000871 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000914 on interface enp134s0f0",
"curl latency: 0.000914 on interface enp134s0f0",
"curl latency: 0.001085 on interface enp134s0f0",
"curl latency: 0.000836 on interface enp134s0f0",))

b2_data.append((1.77,"curl latency: 0.001321 on interface enp134s0f0",
"curl latency: 0.001143 on interface enp134s0f0",
"curl latency: 0.000798 on interface enp134s0f0",
"curl latency: 0.000761 on interface enp134s0f0",
"curl latency: 0.001035 on interface enp134s0f0",
"curl latency: 0.001135 on interface enp134s0f0",
"curl latency: 0.001944 on interface enp134s0f0",
"curl latency: 0.000967 on interface enp134s0f0",
"curl latency: 0.000723 on interface enp134s0f0",
"curl latency: 0.000965 on interface enp134s0f0",
"curl latency: 0.000810 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000811 on interface enp134s0f0",
"curl latency: 0.000888 on interface enp134s0f0",
"curl latency: 0.000900 on interface enp134s0f0",
"curl latency: 0.001189 on interface enp134s0f0",
"curl latency: 0.001063 on interface enp134s0f0",
"curl latency: 0.000856 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000846 on interface enp134s0f0",
"curl latency: 0.000756 on interface enp134s0f0",
"curl latency: 0.000823 on interface enp134s0f0",
"curl latency: 0.001601 on interface enp134s0f0",
"curl latency: 0.001080 on interface enp134s0f0",
"curl latency: 0.002412 on interface enp134s0f0",
"curl latency: 0.001094 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000894 on interface enp134s0f0",))


b2_data.append((2.22,"curl latency: 0.001012 on interface enp134s0f0",
"curl latency: 0.001298 on interface enp134s0f0",
"curl latency: 0.001482 on interface enp134s0f0",
"curl latency: 0.001491 on interface enp134s0f0",
"curl latency: 0.001376 on interface enp134s0f0",
"curl latency: 0.000854 on interface enp134s0f0",
"curl latency: 0.001606 on interface enp134s0f0",
"curl latency: 0.001193 on interface enp134s0f0",
"curl latency: 0.001696 on interface enp134s0f0",
"curl latency: 0.001887 on interface enp134s0f0",
"curl latency: 0.000915 on interface enp134s0f0",
"curl latency: 0.000998 on interface enp134s0f0",
"curl latency: 0.001030 on interface enp134s0f0",
"curl latency: 0.001069 on interface enp134s0f0",
"curl latency: 0.001831 on interface enp134s0f0",
"curl latency: 0.001582 on interface enp134s0f0",
"curl latency: 0.001713 on interface enp134s0f0",
"curl latency: 0.001494 on interface enp134s0f0",
"curl latency: 0.001352 on interface enp134s0f0",
"curl latency: 0.001434 on interface enp134s0f0",
"curl latency: 0.001482 on interface enp134s0f0",
"curl latency: 0.001726 on interface enp134s0f0",
"curl latency: 0.000904 on interface enp134s0f0",
"curl latency: 0.000996 on interface enp134s0f0",
"curl latency: 0.000755 on interface enp134s0f0",
"curl latency: 0.001013 on interface enp134s0f0",
"curl latency: 0.001383 on interface enp134s0f0",
"curl latency: 0.001452 on interface enp134s0f0",
"curl latency: 0.001180 on interface enp134s0f0",
"curl latency: 0.001231 on interface enp134s0f0",
"curl latency: 0.000894 on interface enp134s0f0",))

b2_data.append((2.96,"curl latency: 0.002261 on interface enp134s0f0",
"curl latency: 0.002200 on interface enp134s0f0",
"curl latency: 0.024377 on interface enp134s0f0",
"curl latency: 0.004295 on interface enp134s0f0",
"curl latency: 0.002169 on interface enp134s0f0",
"curl latency: 0.002865 on interface enp134s0f0",
"curl latency: 0.001581 on interface enp134s0f0",
"curl latency: 0.002367 on interface enp134s0f0",
"curl latency: 0.003272 on interface enp134s0f0",
"curl latency: 0.007221 on interface enp134s0f0",
"curl latency: 0.241924 on interface enp134s0f0",
"curl latency: 0.001932 on interface enp134s0f0",
"curl latency: 0.003299 on interface enp134s0f0",
"curl latency: 0.002465 on interface enp134s0f0",
"curl latency: 0.001829 on interface enp134s0f0",
"curl latency: 0.002486 on interface enp134s0f0",
"curl latency: 0.003430 on interface enp134s0f0",
"curl latency: 0.000853 on interface enp134s0f0",
"curl latency: 0.002080 on interface enp134s0f0",
"curl latency: 0.001679 on interface enp134s0f0",
"curl latency: 0.001025 on interface enp134s0f0",
"curl latency: 0.001297 on interface enp134s0f0",
"curl latency: 0.002547 on interface enp134s0f0",
"curl latency: 0.015887 on interface enp134s0f0",
"curl latency: 0.002463 on interface enp134s0f0",
"curl latency: 0.003520 on interface enp134s0f0",
"curl latency: 0.001842 on interface enp134s0f0",
"curl latency: 0.001965 on interface enp134s0f0",
"curl latency: 0.001791 on interface enp134s0f0",
"curl latency: 0.004242 on interface enp134s0f0",
"curl latency: 0.001945 on interface enp134s0f0",
"curl latency: 0.002255 on interface enp134s0f0",
"curl latency: 0.002079 on interface enp134s0f0",
"curl latency: 0.002098 on interface enp134s0f0",
"curl latency: 0.001651 on interface enp134s0f0",
"curl latency: 0.001218 on interface enp134s0f0",
"curl latency: 0.003590 on interface enp134s0f0",
"curl latency: 0.001189 on interface enp134s0f0",
"curl latency: 0.001008 on interface enp134s0f0",
"curl latency: 0.001709 on interface enp134s0f0",
"curl latency: 0.001889 on interface enp134s0f0",
"curl latency: 0.001760 on interface enp134s0f0",
"curl latency: 0.001856 on interface enp134s0f0",
"curl latency: 0.001581 on interface enp134s0f0",
"curl latency: 0.002103 on interface enp134s0f0",
"curl latency: 0.004216 on interface enp134s0f0",))

b2_data.append((3.03,"curl latency: 0.001531 on interface enp134s0f0",
"curl latency: 0.015949 on interface enp134s0f0",
"curl latency: 0.004583 on interface enp134s0f0",
"curl latency: 0.000887 on interface enp134s0f0",
"curl latency: 0.001121 on interface enp134s0f0",
"curl latency: 0.002229 on interface enp134s0f0",
"curl latency: 0.001480 on interface enp134s0f0",
"curl latency: 0.001352 on interface enp134s0f0",
"curl latency: 0.015627 on interface enp134s0f0",
"curl latency: 0.004397 on interface enp134s0f0",
"curl latency: 0.002390 on interface enp134s0f0",
"curl latency: 0.002125 on interface enp134s0f0",
"curl latency: 0.002078 on interface enp134s0f0",
"curl latency: 0.001613 on interface enp134s0f0",
"curl latency: 0.000860 on interface enp134s0f0",
"curl latency: 0.006304 on interface enp134s0f0",
"curl latency: 0.002723 on interface enp134s0f0",
"curl latency: 0.003098 on interface enp134s0f0",
"curl latency: 0.000931 on interface enp134s0f0",
"curl latency: 0.023791 on interface enp134s0f0",
"curl latency: 0.002835 on interface enp134s0f0",
"curl latency: 0.003519 on interface enp134s0f0",
"curl latency: 0.001181 on interface enp134s0f0",
"curl latency: 0.001279 on interface enp134s0f0",
"curl latency: 0.003582 on interface enp134s0f0",
"curl latency: 0.002297 on interface enp134s0f0",
"curl latency: 0.002094 on interface enp134s0f0",
"curl latency: 0.025217 on interface enp134s0f0",
"curl latency: 0.002018 on interface enp134s0f0",
"curl latency: 0.018004 on interface enp134s0f0",
"curl latency: 0.015024 on interface enp134s0f0",
"curl latency: 0.001803 on interface enp134s0f0",
"curl latency: 0.002778 on interface enp134s0f0",
"curl latency: 0.001986 on interface enp134s0f0",
"curl latency: 0.001509 on interface enp134s0f0",
"curl latency: 0.001565 on interface enp134s0f0",
"curl latency: 1.056993 on interface enp134s0f0",
"curl latency: 0.002353 on interface enp134s0f0",
"curl latency: 0.002267 on interface enp134s0f0",
"curl latency: 0.002633 on interface enp134s0f0",
"curl latency: 0.001820 on interface enp134s0f0",
"curl latency: 0.001571 on interface enp134s0f0",
"curl latency: 0.002067 on interface enp134s0f0",
"curl latency: 0.005152 on interface enp134s0f0",
"curl latency: 0.001852 on interface enp134s0f0",
"curl latency: 0.001620 on interface enp134s0f0",
"curl latency: 0.001869 on interface enp134s0f0",
"curl latency: 0.015567 on interface enp134s0f0",
"curl latency: 0.001574 on interface enp134s0f0",
"curl latency: 0.001897 on interface enp134s0f0",
"curl latency: 0.001146 on interface enp134s0f0",
"curl latency: 0.002137 on interface enp134s0f0",
"curl latency: 0.001850 on interface enp134s0f0",
"curl latency: 0.001880 on interface enp134s0f0",
"curl latency: 0.003635 on interface enp134s0f0",
"curl latency: 0.003988 on interface enp134s0f0",
"curl latency: 0.001534 on interface enp134s0f0",))

b2_data.append((3.06,"curl latency: 0.105248 on interface enp134s0f0",
"curl latency: 0.249452 on interface enp134s0f0",
"curl latency: 0.001806 on interface enp134s0f0",
"curl latency: 0.015980 on interface enp134s0f0",
"curl latency: 0.015754 on interface enp134s0f0",
"curl latency: 0.001569 on interface enp134s0f0",
"curl latency: 0.157059 on interface enp134s0f0",
"curl latency: 0.002060 on interface enp134s0f0",
"curl latency: 0.002036 on interface enp134s0f0",
"curl latency: 0.003006 on interface enp134s0f0",
"curl latency: 0.247393 on interface enp134s0f0",
"curl latency: 0.002797 on interface enp134s0f0",
"curl latency: 0.002418 on interface enp134s0f0",
"curl latency: 0.002755 on interface enp134s0f0",
"curl latency: 0.008529 on interface enp134s0f0",
"curl latency: 0.002551 on interface enp134s0f0",
"curl latency: 0.001479 on interface enp134s0f0",
"curl latency: 0.002088 on interface enp134s0f0",
"curl latency: 0.002166 on interface enp134s0f0",
"curl latency: 0.094311 on interface enp134s0f0",
"curl latency: 0.001950 on interface enp134s0f0",
"curl latency: 0.001917 on interface enp134s0f0",
"curl latency: 0.004461 on interface enp134s0f0",
"curl latency: 0.002650 on interface enp134s0f0",
"curl latency: 0.001933 on interface enp134s0f0",
"curl latency: 0.002143 on interface enp134s0f0",
"curl latency: 0.002354 on interface enp134s0f0",
"curl latency: 0.002301 on interface enp134s0f0",
"curl latency: 0.001861 on interface enp134s0f0",
"curl latency: 0.015117 on interface enp134s0f0",
"curl latency: 0.224813 on interface enp134s0f0",
"curl latency: 0.001764 on interface enp134s0f0",
"curl latency: 0.000974 on interface enp134s0f0",
"curl latency: 0.002092 on interface enp134s0f0",
"curl latency: 0.002855 on interface enp134s0f0",
"curl latency: 0.009020 on interface enp134s0f0",
"curl latency: 0.226818 on interface enp134s0f0",
"curl latency: 0.002535 on interface enp134s0f0",
"curl latency: 0.002947 on interface enp134s0f0",
"curl latency: 0.002586 on interface enp134s0f0",
"curl latency: 0.015535 on interface enp134s0f0",
"curl latency: 0.004583 on interface enp134s0f0",
"curl latency: 0.002619 on interface enp134s0f0",
"curl latency: 0.001884 on interface enp134s0f0",
"curl latency: 0.001898 on interface enp134s0f0",
"curl latency: 0.015077 on interface enp134s0f0",
"curl latency: 0.001551 on interface enp134s0f0",))
b2_data.append((3.09,"curl latency: 0.015482 on interface enp134s0f0",
"curl latency: 0.001532 on interface enp134s0f0",
"curl latency: 0.002160 on interface enp134s0f0",
"curl latency: 0.001348 on interface enp134s0f0",
"curl latency: 0.001967 on interface enp134s0f0",
"curl latency: 0.003205 on interface enp134s0f0",
"curl latency: 0.016085 on interface enp134s0f0",
"curl latency: 0.005865 on interface enp134s0f0",
"curl latency: 0.042279 on interface enp134s0f0",
"curl latency: 0.001643 on interface enp134s0f0",
"curl latency: 0.002252 on interface enp134s0f0",
"curl latency: 0.001783 on interface enp134s0f0",
"curl latency: 0.003889 on interface enp134s0f0",
"curl latency: 0.001689 on interface enp134s0f0",
"curl latency: 0.233182 on interface enp134s0f0",
"curl latency: 0.252636 on interface enp134s0f0",
"curl latency: 0.233347 on interface enp134s0f0",
"curl latency: 0.001606 on interface enp134s0f0",
"curl latency: 0.002587 on interface enp134s0f0",
"curl latency: 0.232016 on interface enp134s0f0",
"curl latency: 0.002962 on interface enp134s0f0",
"curl latency: 0.001271 on interface enp134s0f0",
"curl latency: 0.004645 on interface enp134s0f0",
"curl latency: 0.233190 on interface enp134s0f0",
"curl latency: 0.024901 on interface enp134s0f0",
"curl latency: 0.017342 on interface enp134s0f0",
"curl latency: 0.017112 on interface enp134s0f0",
"curl latency: 0.001662 on interface enp134s0f0",
"curl latency: 0.002841 on interface enp134s0f0",
"curl latency: 0.003527 on interface enp134s0f0",
"curl latency: 0.001434 on interface enp134s0f0",
"curl latency: 0.001778 on interface enp134s0f0",
"curl latency: 0.254213 on interface enp134s0f0",
"curl latency: 0.232861 on interface enp134s0f0",
"curl latency: 0.001712 on interface enp134s0f0",
"curl latency: 0.233000 on interface enp134s0f0",
"curl latency: 0.233687 on interface enp134s0f0",
"curl latency: 0.002003 on interface enp134s0f0",
"curl latency: 0.003622 on interface enp134s0f0",
"curl latency: 0.001353 on interface enp134s0f0",
"curl latency: 0.238954 on interface enp134s0f0",))

b2_data.append((3.11,"curl latency: 0.006602 on interface enp134s0f0",
"curl latency: 0.001614 on interface enp134s0f0",
"curl latency: 0.001029 on interface enp134s0f0",
"curl latency: 0.025472 on interface enp134s0f0",
"curl latency: 0.001422 on interface enp134s0f0",
"curl latency: 0.228215 on interface enp134s0f0",
"curl latency: 0.002691 on interface enp134s0f0",
"curl latency: 0.003206 on interface enp134s0f0",
"curl latency: 0.000994 on interface enp134s0f0",
"curl latency: 0.012069 on interface enp134s0f0",
"curl latency: 0.004119 on interface enp134s0f0",
"curl latency: 0.023866 on interface enp134s0f0",
"curl latency: 0.017172 on interface enp134s0f0",
"curl latency: 0.015317 on interface enp134s0f0",
"curl latency: 0.001655 on interface enp134s0f0",
"curl latency: 0.659405 on interface enp134s0f0",
"curl latency: 0.001965 on interface enp134s0f0",
"curl latency: 0.002035 on interface enp134s0f0",
"curl latency: 0.225446 on interface enp134s0f0",
"curl latency: 1.042149 on interface enp134s0f0",
"curl latency: 0.001875 on interface enp134s0f0",
"curl latency: 0.002406 on interface enp134s0f0",))

b2_data.append((3.14,
"curl latency: 0.013887 on interface enp134s0f0",
"curl latency: 0.230687 on interface enp134s0f0",
"curl latency: 0.253967 on interface enp134s0f0",
"curl latency: 0.001993 on interface enp134s0f0",
"curl latency: 0.002475 on interface enp134s0f0",
"curl latency: 0.232951 on interface enp134s0f0",
"curl latency: 0.002321 on interface enp134s0f0",
"curl latency: 0.018565 on interface enp134s0f0",
"curl latency: 0.003044 on interface enp134s0f0",
"curl latency: 0.231798 on interface enp134s0f0",
"curl latency: 0.228727 on interface enp134s0f0",
"curl latency: 0.001798 on interface enp134s0f0",
"curl latency: 0.233186 on interface enp134s0f0",
"curl latency: 0.002252 on interface enp134s0f0",
"curl latency: 0.003750 on interface enp134s0f0",
"curl latency: 0.001904 on interface enp134s0f0",
"curl latency: 0.002632 on interface enp134s0f0",
"curl latency: 0.003693 on interface enp134s0f0",
"curl latency: 0.227730 on interface enp134s0f0",
"curl latency: 0.233417 on interface enp134s0f0",
"curl latency: 0.001955 on interface enp134s0f0",
"curl latency: 0.017146 on interface enp134s0f0",
"curl latency: 0.001495 on interface enp134s0f0",
"curl latency: 0.002054 on interface enp134s0f0",
"curl latency: 0.003045 on interface enp134s0f0",
"curl latency: 0.229800 on interface enp134s0f0",
"curl latency: 0.235371 on interface enp134s0f0",
"curl latency: 0.001429 on interface enp134s0f0",
"curl latency: 0.016737 on interface enp134s0f0",
"curl latency: 0.003848 on interface enp134s0f0",
"curl latency: 0.001401 on interface enp134s0f0",
"curl latency: 0.002783 on interface enp134s0f0",
"curl latency: 0.234124 on interface enp134s0f0",
"curl latency: 0.002105 on interface enp134s0f0",
"curl latency: 0.002343 on interface enp134s0f0",
"curl latency: 0.002340 on interface enp134s0f0",
"curl latency: 0.001653 on interface enp134s0f0",
"curl latency: 0.249457 on interface enp134s0f0",
"curl latency: 0.228621 on interface enp134s0f0",
"curl latency: 0.233464 on interface enp134s0f0",
"curl latency: 0.002427 on interface enp134s0f0",
"curl latency: 0.001418 on interface enp134s0f0",
"curl latency: 0.000903 on interface enp134s0f0",
"curl latency: 0.002260 on interface enp134s0f0",
"curl latency: 0.016550 on interface enp134s0f0",))
b2_data.append((3.17,"curl latency: 0.016691 on interface enp134s0f0",
"curl latency: 0.227862 on interface enp134s0f0",
"curl latency: 0.013474 on interface enp134s0f0",
"curl latency: 0.225732 on interface enp134s0f0",
"curl latency: 0.003718 on interface enp134s0f0",
"curl latency: 0.235647 on interface enp134s0f0",
"curl latency: 0.239297 on interface enp134s0f0",
"curl latency: 0.015542 on interface enp134s0f0",
"curl latency: 0.002948 on interface enp134s0f0",
"curl latency: 0.016514 on interface enp134s0f0",
"curl latency: 0.239807 on interface enp134s0f0",
"curl latency: 0.003147 on interface enp134s0f0",
"curl latency: 0.002031 on interface enp134s0f0",
"curl latency: 0.239696 on interface enp134s0f0",
"curl latency: 0.240709 on interface enp134s0f0",
"curl latency: 0.002466 on interface enp134s0f0",
"curl latency: 0.242919 on interface enp134s0f0",
"curl latency: 0.003232 on interface enp134s0f0",
"curl latency: 0.014868 on interface enp134s0f0",
"curl latency: 0.002722 on interface enp134s0f0",
"curl latency: 0.002889 on interface enp134s0f0",
"curl latency: 0.026819 on interface enp134s0f0",
"curl latency: 0.240349 on interface enp134s0f0",
"curl latency: 0.017347 on interface enp134s0f0",
"curl latency: 0.232469 on interface enp134s0f0",
"curl latency: 0.252272 on interface enp134s0f0",
"curl latency: 0.239144 on interface enp134s0f0",
"curl latency: 0.001653 on interface enp134s0f0",
"curl latency: 0.240911 on interface enp134s0f0",
"curl latency: 0.238138 on interface enp134s0f0",
"curl latency: 0.002681 on interface enp134s0f0",
"curl latency: 0.001542 on interface enp134s0f0",
"curl latency: 0.016217 on interface enp134s0f0",
"curl latency: 0.002071 on interface enp134s0f0",
"curl latency: 0.254514 on interface enp134s0f0",
"curl latency: 0.236289 on interface enp134s0f0",))
b2_data.append((3.21,"curl latency: 0.234062 on interface enp134s0f0",
"curl latency: 0.002957 on interface enp134s0f0",
"curl latency: 0.002999 on interface enp134s0f0",
"curl latency: 0.002822 on interface enp134s0f0",
"curl latency: 0.025895 on interface enp134s0f0",
"curl latency: 0.001565 on interface enp134s0f0",
"curl latency: 0.001925 on interface enp134s0f0",
"curl latency: 0.244800 on interface enp134s0f0",
"curl latency: 0.025299 on interface enp134s0f0",
"curl latency: 0.256590 on interface enp134s0f0",
"curl latency: 0.260864 on interface enp134s0f0",
"curl latency: 0.002936 on interface enp134s0f0",
"curl latency: 0.013570 on interface enp134s0f0",
"curl latency: 0.002600 on interface enp134s0f0",
"curl latency: 0.015305 on interface enp134s0f0",
"curl latency: 0.243530 on interface enp134s0f0",
"curl latency: 1.030319 on interface enp134s0f0",
"curl latency: 0.242191 on interface enp134s0f0",
"curl latency: 0.003484 on interface enp134s0f0",
"curl latency: 0.004870 on interface enp134s0f0",
"curl latency: 0.002082 on interface enp134s0f0",
"curl latency: 0.016789 on interface enp134s0f0",
"curl latency: 0.016575 on interface enp134s0f0",
"curl latency: 0.014871 on interface enp134s0f0",
"curl latency: 0.247113 on interface enp134s0f0",
"curl latency: 0.247972 on interface enp134s0f0",
"curl latency: 0.243362 on interface enp134s0f0",
"curl latency: 0.001812 on interface enp134s0f0",
"curl latency: 0.002916 on interface enp134s0f0",
"curl latency: 0.243781 on interface enp134s0f0",
"curl latency: 0.262103 on interface enp134s0f0",
"curl latency: 0.002634 on interface enp134s0f0",
"curl latency: 0.016971 on interface enp134s0f0",
"curl latency: 0.002362 on interface enp134s0f0",
"curl latency: 0.001633 on interface enp134s0f0",
"curl latency: 0.003091 on interface enp134s0f0",
"curl latency: 0.231211 on interface enp134s0f0",
"curl latency: 0.018658 on interface enp134s0f0",))

b2_data.append((3.23,"curl latency: 0.001339 on interface enp134s0f0",
"curl latency: 0.014787 on interface enp134s0f0",
"curl latency: 0.000972 on interface enp134s0f0",
"curl latency: 0.026394 on interface enp134s0f0",
"curl latency: 0.001057 on interface enp134s0f0",
"curl latency: 0.247013 on interface enp134s0f0",
"curl latency: 0.245996 on interface enp134s0f0",
"curl latency: 0.001286 on interface enp134s0f0",
"curl latency: 0.239613 on interface enp134s0f0",
"curl latency: 0.001771 on interface enp134s0f0",
"curl latency: 0.002916 on interface enp134s0f0",
"curl latency: 0.003133 on interface enp134s0f0",
"curl latency: 0.001331 on interface enp134s0f0",
"curl latency: 0.227020 on interface enp134s0f0",
"curl latency: 0.001241 on interface enp134s0f0",
"curl latency: 0.232928 on interface enp134s0f0",
"curl latency: 0.231168 on interface enp134s0f0",
"curl latency: 0.001802 on interface enp134s0f0",
"curl latency: 0.002790 on interface enp134s0f0",
"curl latency: 0.016128 on interface enp134s0f0",
"curl latency: 0.242496 on interface enp134s0f0",
"curl latency: 0.002121 on interface enp134s0f0",
"curl latency: 0.001772 on interface enp134s0f0",
"curl latency: 0.255528 on interface enp134s0f0",
"curl latency: 0.001491 on interface enp134s0f0",
"curl latency: 0.002248 on interface enp134s0f0",
"curl latency: 0.002528 on interface enp134s0f0",
"curl latency: 0.001637 on interface enp134s0f0",
"curl latency: 0.229733 on interface enp134s0f0",
"curl latency: 0.001458 on interface enp134s0f0",
"curl latency: 0.002385 on interface enp134s0f0",
"curl latency: 1.022033 on interface enp134s0f0",
"curl latency: 0.231572 on interface enp134s0f0",
"curl latency: 0.002731 on interface enp134s0f0",
"curl latency: 0.001272 on interface enp134s0f0",
"curl latency: 0.015824 on interface enp134s0f0",
"curl latency: 0.243609 on interface enp134s0f0",
"curl latency: 0.001896 on interface enp134s0f0",
"curl latency: 0.002248 on interface enp134s0f0",
"curl latency: 0.229844 on interface enp134s0f0",
"curl latency: 0.001546 on interface enp134s0f0",
"curl latency: 0.015918 on interface enp134s0f0",
"curl latency: 0.242474 on interface enp134s0f0",))
b2_data.append((3.24,"curl latency: 0.002482 on interface enp134s0f0",
"curl latency: 0.229258 on interface enp134s0f0",
"curl latency: 0.001857 on interface enp134s0f0",
"curl latency: 0.001702 on interface enp134s0f0",
"curl latency: 0.017495 on interface enp134s0f0",
"curl latency: 0.013513 on interface enp134s0f0",
"curl latency: 0.014478 on interface enp134s0f0",
"curl latency: 0.232838 on interface enp134s0f0",
"curl latency: 0.002466 on interface enp134s0f0",
"curl latency: 0.001928 on interface enp134s0f0",
"curl latency: 0.002392 on interface enp134s0f0",
"curl latency: 0.232592 on interface enp134s0f0",
"curl latency: 0.230916 on interface enp134s0f0",
"curl latency: 0.017078 on interface enp134s0f0",
"curl latency: 0.001331 on interface enp134s0f0",
"curl latency: 0.015511 on interface enp134s0f0",
"curl latency: 0.001576 on interface enp134s0f0",
"curl latency: 0.001962 on interface enp134s0f0",
"curl latency: 0.138278 on interface enp134s0f0",
"curl latency: 0.027023 on interface enp134s0f0",
"curl latency: 0.778468 on interface enp134s0f0",
"curl latency: 0.244361 on interface enp134s0f0",
"curl latency: 0.014963 on interface enp134s0f0",
"curl latency: 0.002986 on interface enp134s0f0",
"curl latency: 0.001581 on interface enp134s0f0",
"curl latency: 0.002498 on interface enp134s0f0",
"curl latency: 0.233928 on interface enp134s0f0",
"curl latency: 0.234456 on interface enp134s0f0",
"curl latency: 0.014363 on interface enp134s0f0",
"curl latency: 0.017637 on interface enp134s0f0",
"curl latency: 0.233518 on interface enp134s0f0",
"curl latency: 0.014271 on interface enp134s0f0",
"curl latency: 0.004245 on interface enp134s0f0",
"curl latency: 0.002759 on interface enp134s0f0",
"curl latency: 0.234216 on interface enp134s0f0",
"curl latency: 0.230658 on interface enp134s0f0",
"curl latency: 0.014377 on interface enp134s0f0",
"curl latency: 0.232162 on interface enp134s0f0",
"curl latency: 0.236379 on interface enp134s0f0",
"curl latency: 0.003644 on interface enp134s0f0",
"curl latency: 0.233103 on interface enp134s0f0",
"curl latency: 0.001822 on interface enp134s0f0",
"curl latency: 0.025302 on interface enp134s0f0",))

b2_data.append((3.25,"curl latency: 0.013743 on interface enp134s0f0",
"curl latency: 0.002720 on interface enp134s0f0",
"curl latency: 0.008973 on interface enp134s0f0",
"curl latency: 0.002312 on interface enp134s0f0",
"curl latency: 0.660410 on interface enp134s0f0",
"curl latency: 0.003458 on interface enp134s0f0",
"curl latency: 0.002027 on interface enp134s0f0",
"curl latency: 0.024613 on interface enp134s0f0",
"curl latency: 0.263828 on interface enp134s0f0",
"curl latency: 0.001818 on interface enp134s0f0",
"curl latency: 0.004026 on interface enp134s0f0",
"curl latency: 0.025146 on interface enp134s0f0",
"curl latency: 1.723422 on interface enp134s0f0",
"curl latency: 0.240212 on interface enp134s0f0",
"curl latency: 0.016546 on interface enp134s0f0",
"curl latency: 0.256388 on interface enp134s0f0",
"curl latency: 0.013116 on interface enp134s0f0",
"curl latency: 0.250169 on interface enp134s0f0",
"curl latency: 0.003190 on interface enp134s0f0",
"curl latency: 0.239933 on interface enp134s0f0",
"curl latency: 0.002430 on interface enp134s0f0",
"curl latency: 0.231057 on interface enp134s0f0",
"curl latency: 0.006739 on interface enp134s0f0",))

b2_data.append((3.26,"curl latency: 0.001722 on interface enp134s0f0",
"curl latency: 0.234199 on interface enp134s0f0",
"curl latency: 0.001121 on interface enp134s0f0",
"curl latency: 0.695416 on interface enp134s0f0",
"curl latency: 0.001945 on interface enp134s0f0",
"curl latency: 0.216525 on interface enp134s0f0",
"curl latency: 0.016301 on interface enp134s0f0",
"curl latency: 0.231291 on interface enp134s0f0",
"curl latency: 0.247126 on interface enp134s0f0",
"curl latency: 0.003740 on interface enp134s0f0",
"curl latency: 0.002058 on interface enp134s0f0",
"curl latency: 0.002100 on interface enp134s0f0",
"curl latency: 1.237464 on interface enp134s0f0",
"curl latency: 0.017489 on interface enp134s0f0",
"curl latency: 0.014115 on interface enp134s0f0",
"curl latency: 0.248074 on interface enp134s0f0",
"curl latency: 0.234081 on interface enp134s0f0",
"curl latency: 0.004163 on interface enp134s0f0",
"curl latency: 0.002131 on interface enp134s0f0",
"curl latency: 0.231905 on interface enp134s0f0",
"curl latency: 0.003084 on interface enp134s0f0",
"curl latency: 0.232159 on interface enp134s0f0",
"curl latency: 0.001072 on interface enp134s0f0",
"curl latency: 1.044771 on interface enp134s0f0",
"curl latency: 0.014915 on interface enp134s0f0",
"curl latency: 0.001737 on interface enp134s0f0",
"curl latency: 0.001963 on interface enp134s0f0",
"curl latency: 0.257311 on interface enp134s0f0",
"curl latency: 0.232114 on interface enp134s0f0",
"curl latency: 1.027359 on interface enp134s0f0",
"curl latency: 0.637420 on interface enp134s0f0",
"curl latency: 0.013553 on interface enp134s0f0",
"curl latency: 0.013562 on interface enp134s0f0",
"curl latency: 0.001205 on interface enp134s0f0",
"curl latency: 0.219558 on interface enp134s0f0",
"curl latency: 0.003787 on interface enp134s0f0",
"curl latency: 1.253362 on interface enp134s0f0",
"curl latency: 0.001402 on interface enp134s0f0",
"curl latency: 0.001317 on interface enp134s0f0",))

# %%
import numpy as np
b2_flood_rate = []
b2_curl_latency = []
for lines in b2_data:
    rate=lines[0]
    proc_lines=[float(l.strip().split()[2]) for l in lines[1:] if l.strip()!=""]
    avg=np.mean(proc_lines)
    b2_flood_rate.append(rate)
    b2_curl_latency.append(avg)
    print(rate,avg)
# Out:
# 0.01 0.0007500384615384616
# 0.74 0.0007771666666666666
# 1.03 0.0008511176470588235
# 1.3 0.0009095555555555556
# 1.36 0.0010350810810810815
# 1.4 0.0009799444444444445
# 1.45 0.0009298857142857142
# 1.48 0.0009993548387096775
# 1.49 0.0010172758620689655
# 1.63 0.0010988333333333334
# 1.77 0.0010375357142857144
# 2.22 0.001300935483870968
# 2.96 0.008332847826086958
# 3.03 0.02275728070175438
# 3.06 0.031419042553191494
# 3.09 0.06269812195121952
# 3.11 0.10366927272727273
# 3.14 0.07612235555555556
# 3.17 0.11095352777777778
# 3.21 0.11038207894736841
# 3.23 0.09895462790697673
# 3.24 0.09763658139534884
# 3.25 0.1737511304347826
# 3.26 0.22063120512820517

# %%
data=[]
data.append((0.01, "curl latency: 0.000706 on interface enp134s0f0",
"curl latency: 0.000707 on interface enp134s0f0",
"curl latency: 0.000793 on interface enp134s0f0",
"curl latency: 0.000763 on interface enp134s0f0",
"curl latency: 0.000735 on interface enp134s0f0",
"curl latency: 0.000706 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000909 on interface enp134s0f0",
"curl latency: 0.000705 on interface enp134s0f0",
"curl latency: 0.000694 on interface enp134s0f0",
"curl latency: 0.000785 on interface enp134s0f0",
"curl latency: 0.000690 on interface enp134s0f0",
"curl latency: 0.000749 on interface enp134s0f0",
"curl latency: 0.000653 on interface enp134s0f0",
"curl latency: 0.000719 on interface enp134s0f0",
"curl latency: 0.000723 on interface enp134s0f0",
"curl latency: 0.000671 on interface enp134s0f0",
"curl latency: 0.000759 on interface enp134s0f0",
"curl latency: 0.000630 on interface enp134s0f0",
"curl latency: 0.000699 on interface enp134s0f0",
"curl latency: 0.000740 on interface enp134s0f0",
"curl latency: 0.000708 on interface enp134s0f0",
"curl latency: 0.000795 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000821 on interface enp134s0f0",
"curl latency: 0.000702 on interface enp134s0f0",))
data.append((0.3, "curl latency: 0.000766 on interface enp134s0f0",
"curl latency: 0.000819 on interface enp134s0f0",
"curl latency: 0.000710 on interface enp134s0f0",
"curl latency: 0.000711 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000814 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000682 on interface enp134s0f0",
"curl latency: 0.000761 on interface enp134s0f0",
"curl latency: 0.000698 on interface enp134s0f0",
"curl latency: 0.000755 on interface enp134s0f0",
"curl latency: 0.000892 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000806 on interface enp134s0f0",
"curl latency: 0.000768 on interface enp134s0f0",
"curl latency: 0.000839 on interface enp134s0f0",
"curl latency: 0.000754 on interface enp134s0f0",
"curl latency: 0.000870 on interface enp134s0f0",
"curl latency: 0.000709 on interface enp134s0f0",))
data.append((0.66,"curl latency: 0.000759 on interface enp134s0f0",
"curl latency: 0.000737 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000746 on interface enp134s0f0",
"curl latency: 0.000795 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",
"curl latency: 0.000711 on interface enp134s0f0",
"curl latency: 0.000685 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.000762 on interface enp134s0f0",
"curl latency: 0.000746 on interface enp134s0f0",
"curl latency: 0.000692 on interface enp134s0f0",
"curl latency: 0.000650 on interface enp134s0f0",
"curl latency: 0.000730 on interface enp134s0f0",
"curl latency: 0.000702 on interface enp134s0f0",
"curl latency: 0.000665 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000780 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000758 on interface enp134s0f0",
"curl latency: 0.000635 on interface enp134s0f0",
"curl latency: 0.000699 on interface enp134s0f0",
"curl latency: 0.000775 on interface enp134s0f0",
"curl latency: 0.000741 on interface enp134s0f0",
"curl latency: 0.000756 on interface enp134s0f0",
"curl latency: 0.000745 on interface enp134s0f0",
"curl latency: 0.000777 on interface enp134s0f0",
"curl latency: 0.000648 on interface enp134s0f0",
"curl latency: 0.000687 on interface enp134s0f0",
"curl latency: 0.000715 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000711 on interface enp134s0f0",))
data.append((1.22,"curl latency: 0.000817 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000689 on interface enp134s0f0",
"curl latency: 0.000759 on interface enp134s0f0",
"curl latency: 0.000830 on interface enp134s0f0",
"curl latency: 0.000715 on interface enp134s0f0",
"curl latency: 0.000719 on interface enp134s0f0",
"curl latency: 0.000748 on interface enp134s0f0",
"curl latency: 0.000838 on interface enp134s0f0",
"curl latency: 0.000762 on interface enp134s0f0",
"curl latency: 0.000843 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000698 on interface enp134s0f0",
"curl latency: 0.000784 on interface enp134s0f0",
"curl latency: 0.000683 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.000781 on interface enp134s0f0",
"curl latency: 0.000672 on interface enp134s0f0",
"curl latency: 0.000687 on interface enp134s0f0",
"curl latency: 0.000740 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000661 on interface enp134s0f0",
"curl latency: 0.000772 on interface enp134s0f0",
"curl latency: 0.000722 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000780 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000719 on interface enp134s0f0",))
data.append((1.78,"curl latency: 0.000727 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000753 on interface enp134s0f0",
"curl latency: 0.000736 on interface enp134s0f0",
"curl latency: 0.000912 on interface enp134s0f0",
"curl latency: 0.000784 on interface enp134s0f0",
"curl latency: 0.000817 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000689 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000770 on interface enp134s0f0",
"curl latency: 0.000764 on interface enp134s0f0",
"curl latency: 0.000814 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000723 on interface enp134s0f0",
"curl latency: 0.000847 on interface enp134s0f0",
"curl latency: 0.000799 on interface enp134s0f0",
"curl latency: 0.000711 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000788 on interface enp134s0f0",
"curl latency: 0.000708 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000828 on interface enp134s0f0",
"curl latency: 0.000856 on interface enp134s0f0",
"curl latency: 0.000709 on interface enp134s0f0",
"curl latency: 0.000801 on interface enp134s0f0",
"curl latency: 0.000779 on interface enp134s0f0",
"curl latency: 0.000870 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000781 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",))
data.append((2.75, "curl latency: 0.000682 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000686 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000796 on interface enp134s0f0",
"curl latency: 0.000804 on interface enp134s0f0",
"curl latency: 0.000732 on interface enp134s0f0",
"curl latency: 0.000888 on interface enp134s0f0",
"curl latency: 0.000694 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000796 on interface enp134s0f0",
"curl latency: 0.000879 on interface enp134s0f0",
"curl latency: 0.000913 on interface enp134s0f0",
"curl latency: 0.000839 on interface enp134s0f0",
"curl latency: 0.000688 on interface enp134s0f0",
"curl latency: 0.000685 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000705 on interface enp134s0f0",
"curl latency: 0.000911 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000844 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.000762 on interface enp134s0f0",))
data.append((89.68, "curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000847 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.000673 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000824 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000676 on interface enp134s0f0",
"curl latency: 0.000858 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",
"curl latency: 0.000663 on interface enp134s0f0",
"curl latency: 0.000799 on interface enp134s0f0",
"curl latency: 0.000803 on interface enp134s0f0",
"curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000651 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000727 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",))
data.append((127.64, "curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000847 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.000673 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000824 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000676 on interface enp134s0f0",
"curl latency: 0.000858 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",
"curl latency: 0.000663 on interface enp134s0f0",
"curl latency: 0.000799 on interface enp134s0f0",
"curl latency: 0.000803 on interface enp134s0f0",
"curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000651 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000727 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",))
data.append((130.35,"curl latency: 0.000833 on interface enp134s0f0",
"curl latency: 0.000683 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000694 on interface enp134s0f0",
"curl latency: 0.000743 on interface enp134s0f0",
"curl latency: 0.000688 on interface enp134s0f0",
"curl latency: 0.000829 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000669 on interface enp134s0f0",
"curl latency: 0.000814 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000693 on interface enp134s0f0",
"curl latency: 0.000741 on interface enp134s0f0",
"curl latency: 0.000745 on interface enp134s0f0",
"curl latency: 0.000806 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000807 on interface enp134s0f0",
"curl latency: 0.000827 on interface enp134s0f0",
"curl latency: 0.000763 on interface enp134s0f0",
"curl latency: 0.000793 on interface enp134s0f0",
"curl latency: 0.000693 on interface enp134s0f0",
"curl latency: 0.000660 on interface enp134s0f0",
"curl latency: 0.000790 on interface enp134s0f0",
"curl latency: 0.000703 on interface enp134s0f0",
"curl latency: 0.000741 on interface enp134s0f0",
"curl latency: 0.000693 on interface enp134s0f0",
"curl latency: 0.000692 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000857 on interface enp134s0f0",))
data.append((133,"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000671 on interface enp134s0f0",
"curl latency: 0.000681 on interface enp134s0f0",
"curl latency: 0.000669 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.000760 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000719 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.000687 on interface enp134s0f0",
"curl latency: 0.000838 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000773 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000696 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000597 on interface enp134s0f0",
"curl latency: 0.000588 on interface enp134s0f0",
"curl latency: 0.000727 on interface enp134s0f0",
"curl latency: 0.000713 on interface enp134s0f0",
"curl latency: 0.000787 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",))
data.append((133.5,"curl latency: 0.000703 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000779 on interface enp134s0f0",
"curl latency: 0.000678 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000754 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000707 on interface enp134s0f0",
"curl latency: 0.000696 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000798 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000718 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.000707 on interface enp134s0f0",
"curl latency: 0.000670 on interface enp134s0f0",
"curl latency: 0.000836 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000760 on interface enp134s0f0",
"curl latency: 0.000692 on interface enp134s0f0",
"curl latency: 0.000805 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000720 on interface enp134s0f0",
"curl latency: 0.000901 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000736 on interface enp134s0f0",
"curl latency: 0.000729 on interface enp134s0f0",))
data.append((134,"curl latency: 0.000707 on interface enp134s0f0",
"curl latency: 0.000710 on interface enp134s0f0",
"curl latency: 0.000792 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000746 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000844 on interface enp134s0f0",
"curl latency: 0.000875 on interface enp134s0f0",
"curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000677 on interface enp134s0f0",
"curl latency: 0.000632 on interface enp134s0f0",
"curl latency: 0.000785 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000689 on interface enp134s0f0",
"curl latency: 0.000779 on interface enp134s0f0",
"curl latency: 0.000732 on interface enp134s0f0",
"curl latency: 0.000865 on interface enp134s0f0",
"curl latency: 0.000910 on interface enp134s0f0",
"curl latency: 0.000753 on interface enp134s0f0",
"curl latency: 0.000773 on interface enp134s0f0",
"curl latency: 0.000798 on interface enp134s0f0",
"curl latency: 0.000675 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000750 on interface enp134s0f0",))
# data.append((134.1,"curl latency: 0.000679 on interface enp134s0f0",
# "curl latency: 0.000689 on interface enp134s0f0",
# "curl latency: 0.000680 on interface enp134s0f0",
# "curl latency: 0.000773 on interface enp134s0f0",
# "curl latency: 0.000872 on interface enp134s0f0",
# "curl latency: 0.000801 on interface enp134s0f0",
# "curl latency: 0.000728 on interface enp134s0f0",
# "curl latency: 0.000773 on interface enp134s0f0",
# "curl latency: 0.000770 on interface enp134s0f0",
# "curl latency: 0.000665 on interface enp134s0f0",
# "curl latency: 0.000682 on interface enp134s0f0",
# "curl latency: 0.000804 on interface enp134s0f0",
# "curl latency: 0.000713 on interface enp134s0f0",
# "curl latency: 0.000693 on interface enp134s0f0",
# "curl latency: 0.000802 on interface enp134s0f0",
# "curl latency: 0.000678 on interface enp134s0f0",
# "curl latency: 0.000706 on interface enp134s0f0",
# "curl latency: 0.000865 on interface enp134s0f0",
# "curl latency: 0.000776 on interface enp134s0f0",
# "curl latency: 0.000684 on interface enp134s0f0",
# "curl latency: 0.000844 on interface enp134s0f0",
# "curl latency: 0.000743 on interface enp134s0f0",
# "curl latency: 0.000713 on interface enp134s0f0",
# "curl latency: 0.000784 on interface enp134s0f0",
# "curl latency: 0.000684 on interface enp134s0f0",
# "curl latency: 0.000802 on interface enp134s0f0",))
# data.append((134.2,"curl latency: 0.000688 on interface enp134s0f0",
# "curl latency: 0.000794 on interface enp134s0f0",
# "curl latency: 0.000693 on interface enp134s0f0",
# "curl latency: 0.000738 on interface enp134s0f0",
# "curl latency: 0.000765 on interface enp134s0f0",
# "curl latency: 0.000764 on interface enp134s0f0",
# "curl latency: 0.000698 on interface enp134s0f0",
# "curl latency: 0.000711 on interface enp134s0f0",
# "curl latency: 0.000668 on interface enp134s0f0",
# "curl latency: 0.000670 on interface enp134s0f0",
# "curl latency: 0.000672 on interface enp134s0f0",
# "curl latency: 0.000676 on interface enp134s0f0",
# "curl latency: 0.000680 on interface enp134s0f0",
# "curl latency: 0.000734 on interface enp134s0f0",
# "curl latency: 0.000724 on interface enp134s0f0",
# "curl latency: 0.000685 on interface enp134s0f0",
# "curl latency: 0.000768 on interface enp134s0f0",
# "curl latency: 0.000798 on interface enp134s0f0",
# "curl latency: 0.000704 on interface enp134s0f0",
# "curl latency: 0.000833 on interface enp134s0f0",))
# data.append((134.3,"asdfadfa"))
# data.append((134.4,"asdfadfa"))
# data.append((134.5,"asdfadfa"))
# data.append((134.6,"curl latency: 0.000839 on interface enp134s0f0",
# "curl latency: 0.000822 on interface enp134s0f0",
# "curl latency: 0.000717 on interface enp134s0f0",
# "curl latency: 0.000792 on interface enp134s0f0",
# "curl latency: 0.000871 on interface enp134s0f0",
# "curl latency: 0.000672 on interface enp134s0f0",
# "curl latency: 0.000707 on interface enp134s0f0",
# "curl latency: 0.000730 on interface enp134s0f0",
# "curl latency: 0.000809 on interface enp134s0f0",
# "curl latency: 0.000792 on interface enp134s0f0",
# "curl latency: 0.000695 on interface enp134s0f0",
# "curl latency: 0.000902 on interface enp134s0f0",
# "curl latency: 0.000893 on interface enp134s0f0",
# "curl latency: 0.000793 on interface enp134s0f0",
# "curl latency: 0.000803 on interface enp134s0f0",
# "curl latency: 0.000717 on interface enp134s0f0",
# "curl latency: 0.000706 on interface enp134s0f0",
# "curl latency: 0.000807 on interface enp134s0f0",
# "curl latency: 0.000831 on interface enp134s0f0",
# "curl latency: 0.000770 on interface enp134s0f0",
# "curl latency: 0.000686 on interface enp134s0f0",
# "curl latency: 0.000792 on interface enp134s0f0",
# "curl latency: 0.000765 on interface enp134s0f0",
# "curl latency: 0.000721 on interface enp134s0f0",
# "curl latency: 0.000885 on interface enp134s0f0",))
# data.append((134.7,"curl latency: 0.000815 on interface enp134s0f0",
# "curl latency: 0.000698 on interface enp134s0f0",
# "curl latency: 0.000681 on interface enp134s0f0",
# "curl latency: 0.000700 on interface enp134s0f0",
# "curl latency: 0.000749 on interface enp134s0f0",
# "curl latency: 0.000679 on interface enp134s0f0",
# "curl latency: 0.000727 on interface enp134s0f0",
# "curl latency: 0.000669 on interface enp134s0f0",
# "curl latency: 0.000713 on interface enp134s0f0",
# "curl latency: 0.000783 on interface enp134s0f0",
# "curl latency: 0.000902 on interface enp134s0f0",
# "curl latency: 0.000707 on interface enp134s0f0",
# "curl latency: 0.000814 on interface enp134s0f0",
# "curl latency: 0.000817 on interface enp134s0f0",
# "curl latency: 0.000795 on interface enp134s0f0",
# "curl latency: 0.000711 on interface enp134s0f0",
# "curl latency: 0.000831 on interface enp134s0f0",
# "curl latency: 0.000879 on interface enp134s0f0",
# "curl latency: 0.000729 on interface enp134s0f0",
# "curl latency: 0.000724 on interface enp134s0f0",
# "curl latency: 0.000860 on interface enp134s0f0",
# "curl latency: 0.000738 on interface enp134s0f0",
# "curl latency: 0.000725 on interface enp134s0f0",
# "curl latency: 0.000757 on interface enp134s0f0",
# "curl latency: 0.000839 on interface enp134s0f0",
# "curl latency: 0.000765 on interface enp134s0f0",
# "curl latency: 0.000711 on interface enp134s0f0",
# "curl latency: 0.000697 on interface enp134s0f0",
# "curl latency: 0.000642 on interface enp134s0f0",))
# data.append((134.8,"curl latency: 0.000756 on interface enp134s0f0",
# "curl latency: 0.000739 on interface enp134s0f0",
# "curl latency: 0.000628 on interface enp134s0f0",
# "curl latency: 0.000605 on interface enp134s0f0",
# "curl latency: 0.000644 on interface enp134s0f0",
# "curl latency: 0.000743 on interface enp134s0f0",
# "curl latency: 0.000916 on interface enp134s0f0",
# "curl latency: 0.000865 on interface enp134s0f0",
# "curl latency: 0.000675 on interface enp134s0f0",
# "curl latency: 0.000683 on interface enp134s0f0",
# "curl latency: 0.000701 on interface enp134s0f0",
# "curl latency: 0.000713 on interface enp134s0f0",
# "curl latency: 0.000750 on interface enp134s0f0",
# "curl latency: 0.000733 on interface enp134s0f0",
# "curl latency: 0.000833 on interface enp134s0f0",
# "curl latency: 0.000839 on interface enp134s0f0",
# "curl latency: 0.000707 on interface enp134s0f0",
# "curl latency: 0.000668 on interface enp134s0f0",
# "curl latency: 0.000748 on interface enp134s0f0",
# "curl latency: 0.000762 on interface enp134s0f0",
# "curl latency: 0.000671 on interface enp134s0f0",
# "curl latency: 0.000754 on interface enp134s0f0",
# "curl latency: 0.000794 on interface enp134s0f0",
# "curl latency: 0.000761 on interface enp134s0f0",
# "curl latency: 0.000735 on interface enp134s0f0",
# "curl latency: 0.000753 on interface enp134s0f0",
# "curl latency: 0.000765 on interface enp134s0f0",
# "curl latency: 0.000800 on interface enp134s0f0",
# "curl latency: 0.000765 on interface enp134s0f0",
# "curl latency: 0.000678 on interface enp134s0f0",))

data.append((135,"curl latency: 0.000723 on interface enp134s0f0",
"curl latency: 0.000665 on interface enp134s0f0",
"curl latency: 0.000639 on interface enp134s0f0",
"curl latency: 0.000836 on interface enp134s0f0",
"curl latency: 0.000731 on interface enp134s0f0",
"curl latency: 0.000811 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000722 on interface enp134s0f0",
"curl latency: 0.000702 on interface enp134s0f0",
"curl latency: 0.000730 on interface enp134s0f0",
"curl latency: 0.000894 on interface enp134s0f0",
"curl latency: 0.000757 on interface enp134s0f0",
"curl latency: 0.000875 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000860 on interface enp134s0f0",
"curl latency: 0.000785 on interface enp134s0f0",
"curl latency: 0.000728 on interface enp134s0f0",
"curl latency: 0.000904 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000758 on interface enp134s0f0",
"curl latency: 0.000705 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000677 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000689 on interface enp134s0f0",
"curl latency: 0.000667 on interface enp134s0f0",
"curl latency: 0.000688 on interface enp134s0f0",
"curl latency: 0.000685 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000812 on interface enp134s0f0",
"curl latency: 0.000651 on interface enp134s0f0",
))
data.append((135.5,"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000808 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000717 on interface enp134s0f0",
"curl latency: 0.000848 on interface enp134s0f0",
"curl latency: 0.000912 on interface enp134s0f0",
"curl latency: 0.201965 on interface enp134s0f0",
"curl latency: 0.000777 on interface enp134s0f0",
"curl latency: 0.000836 on interface enp134s0f0",
"curl latency: 0.000884 on interface enp134s0f0",
"curl latency: 0.000851 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000708 on interface enp134s0f0",
"curl latency: 0.000836 on interface enp134s0f0",
"curl latency: 0.000768 on interface enp134s0f0",
"curl latency: 0.000828 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000690 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000796 on interface enp134s0f0",
"curl latency: 0.000670 on interface enp134s0f0",
"curl latency: 0.000701 on interface enp134s0f0",))
data.append((136.8,"curl latency: 0.001036 on interface enp134s0f0",
"curl latency: 0.000812 on interface enp134s0f0",
"curl latency: 0.000963 on interface enp134s0f0",
"curl latency: 0.000888 on interface enp134s0f0",
"curl latency: 0.000845 on interface enp134s0f0",
"curl latency: 0.000790 on interface enp134s0f0",
"curl latency: 0.207292 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000760 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.000806 on interface enp134s0f0",
"curl latency: 0.000705 on interface enp134s0f0",
"curl latency: 0.000702 on interface enp134s0f0",
"curl latency: 0.000749 on interface enp134s0f0",
"curl latency: 0.000755 on interface enp134s0f0",
"curl latency: 0.000692 on interface enp134s0f0",
"curl latency: 0.000790 on interface enp134s0f0",
"curl latency: 0.000802 on interface enp134s0f0",
"curl latency: 0.000625 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000791 on interface enp134s0f0",
"curl latency: 0.000749 on interface enp134s0f0",
"curl latency: 0.000709 on interface enp134s0f0",
"curl latency: 0.000828 on interface enp134s0f0",
"curl latency: 0.000744 on interface enp134s0f0",
"curl latency: 0.000726 on interface enp134s0f0",
"curl latency: 0.000667 on interface enp134s0f0",))

data.append((136.88, "curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000816 on interface enp134s0f0",
"curl latency: 0.000740 on interface enp134s0f0",
"curl latency: 0.000681 on interface enp134s0f0",
"curl latency: 0.000712 on interface enp134s0f0",
"curl latency: 0.000741 on interface enp134s0f0",
"curl latency: 0.000799 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000668 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000770 on interface enp134s0f0",
"curl latency: 0.000811 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000758 on interface enp134s0f0",
"curl latency: 0.000844 on interface enp134s0f0",
"curl latency: 0.000767 on interface enp134s0f0",
"curl latency: 0.000653 on interface enp134s0f0",
"curl latency: 0.000723 on interface enp134s0f0",
"curl latency: 0.000734 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000727 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000732 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000765 on interface enp134s0f0",
"curl latency: 0.000687 on interface enp134s0f0",
"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000845 on interface enp134s0f0",
"curl latency: 0.000691 on interface enp134s0f0",
"curl latency: 0.000688 on interface enp134s0f0",
"curl latency: 0.000742 on interface enp134s0f0",
"curl latency: 0.000666 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 1.205875 on interface enp134s0f0",
"curl latency: 0.000663 on interface enp134s0f0",
"curl latency: 0.000694 on interface enp134s0f0",
"curl latency: 0.000677 on interface enp134s0f0",
"curl latency: 0.000667 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000699 on interface enp134s0f0",
"curl latency: 0.000705 on interface enp134s0f0",
"curl latency: 0.000746 on interface enp134s0f0",
"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000758 on interface enp134s0f0",
"curl latency: 0.000725 on interface enp134s0f0",
"curl latency: 0.000616 on interface enp134s0f0",
"curl latency: 0.000828 on interface enp134s0f0",
"curl latency: 0.000778 on interface enp134s0f0",
"curl latency: 0.000809 on interface enp134s0f0",
"curl latency: 0.000698 on interface enp134s0f0",
"curl latency: 0.000715 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000807 on interface enp134s0f0",
"curl latency: 0.000694 on interface enp134s0f0",
"curl latency: 0.203017 on interface enp134s0f0",
"curl latency: 0.000770 on interface enp134s0f0",
"curl latency: 0.000823 on interface enp134s0f0",))

data.append((136.9,"curl latency: 0.201467 on interface enp134s0f0",
"curl latency: 0.000713 on interface enp134s0f0",
"curl latency: 0.000768 on interface enp134s0f0",
"curl latency: 0.000719 on interface enp134s0f0",
"curl latency: 0.000797 on interface enp134s0f0",
"curl latency: 0.000708 on interface enp134s0f0",
"curl latency: 0.000695 on interface enp134s0f0",
"curl latency: 0.000791 on interface enp134s0f0",
"curl latency: 0.000779 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000837 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000873 on interface enp134s0f0",
"curl latency: 0.000663 on interface enp134s0f0",
"curl latency: 1.019191 on interface enp134s0f0",
"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.000781 on interface enp134s0f0",
"curl latency: 0.000717 on interface enp134s0f0",
"curl latency: 0.000772 on interface enp134s0f0",
"curl latency: 0.000751 on interface enp134s0f0",
"curl latency: 0.000739 on interface enp134s0f0",
"curl latency: 0.000820 on interface enp134s0f0",
"curl latency: 0.000748 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000670 on interface enp134s0f0",
"curl latency: 0.000806 on interface enp134s0f0",
"curl latency: 0.000738 on interface enp134s0f0",
"curl latency: 0.000752 on interface enp134s0f0",
"curl latency: 0.000828 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000749 on interface enp134s0f0",
"curl latency: 0.000711 on interface enp134s0f0",
"curl latency: 0.000734 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000818 on interface enp134s0f0",
"curl latency: 0.000788 on interface enp134s0f0",
"curl latency: 0.000786 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000781 on interface enp134s0f0",))

data.append((137.2,"curl latency: 0.000853 on interface enp134s0f0",
"curl latency: 0.000771 on interface enp134s0f0",
"curl latency: 0.000774 on interface enp134s0f0",
"curl latency: 0.000788 on interface enp134s0f0",
"curl latency: 0.000700 on interface enp134s0f0",
"curl latency: 0.000865 on interface enp134s0f0",
"curl latency: 1.009360 on interface enp134s0f0",
"curl latency: 0.000685 on interface enp134s0f0",
"curl latency: 0.000794 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000700 on interface enp134s0f0",
"curl latency: 0.000737 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000745 on interface enp134s0f0",
"curl latency: 0.000770 on interface enp134s0f0",
"curl latency: 0.000737 on interface enp134s0f0",
"curl latency: 0.000703 on interface enp134s0f0",
"curl latency: 0.000680 on interface enp134s0f0",
"curl latency: 0.000800 on interface enp134s0f0",
"curl latency: 0.000769 on interface enp134s0f0",
"curl latency: 0.000670 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000782 on interface enp134s0f0",
"curl latency: 0.000659 on interface enp134s0f0",
"curl latency: 0.202089 on interface enp134s0f0",
"curl latency: 0.000682 on interface enp134s0f0",
"curl latency: 0.000773 on interface enp134s0f0",
"curl latency: 0.000814 on interface enp134s0f0",
"curl latency: 0.000724 on interface enp134s0f0",
"curl latency: 0.000714 on interface enp134s0f0",
"curl latency: 0.000697 on interface enp134s0f0",
"curl latency: 0.202079 on interface enp134s0f0",
"curl latency: 0.000804 on interface enp134s0f0",
"curl latency: 0.000733 on interface enp134s0f0",
"curl latency: 0.000744 on interface enp134s0f0",
"curl latency: 0.000773 on interface enp134s0f0",
"curl latency: 0.000642 on interface enp134s0f0",
"curl latency: 0.000776 on interface enp134s0f0",
"curl latency: 0.000781 on interface enp134s0f0",
"curl latency: 0.000645 on interface enp134s0f0",
"curl latency: 0.000669 on interface enp134s0f0",
"curl latency: 0.000748 on interface enp134s0f0",))

#data.append((136.8,"curl latency: 0.001036 on interface enp134s0f0",))
#data.append((136.8,"curl latency: 0.001036 on interface enp134s0f0",))
#data.append((136.8,"curl latency: 0.001036 on interface enp134s0f0",))

# %%
import numpy as np
sc_flood_rate = []
sc_curl_latency = []
for lines in data:
    rate=lines[0]
    proc_lines=[float(l.strip().split()[2]) for l in lines[1:] if l.strip()!=""]
    avg=np.mean(proc_lines)
    sc_flood_rate.append(rate)
    sc_curl_latency.append(avg)
    print(rate,avg)
# Out:
# 0.01 0.0007337692307692307
# 0.3 0.0007697368421052632
# 0.66 0.0007317714285714287
# 1.22 0.0007457272727272728
# 1.78 0.00077725
# 2.75 0.0007756666666666667
# 89.68 0.0007554285714285716
# 127.64 0.0007554285714285716
# 130.35 0.0007458333333333333
# 133 0.0007281851851851851
# 133.5 0.0007529032258064515
# 134 0.0007612962962962963
# 135 0.0007473939393939393
# 135.5 0.009166583333333334
# 136.8 0.008150535714285714
# 136.88 0.02459649152542373
# 136.9 0.031241050000000003
# 137.2 0.03434395238095237

# %%
#Plot DDoS Attack Rate versus Application Latency

from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np

f,(ax,ax2) = plt.subplots(1,2, facecolor='w', figsize=(6, 5), dpi=200)

#x-axis
b_send_rate_scaled = np.true_divide(b_flood_rate,1e6)

#y-axis 
b_latency_ms = np.multiply(b_curl_latency, 1e3) #show latency in ms 
sc_latency_ms = np.multiply(sc_curl_latency, 1e3) #show latency in ms 

x_base = b_send_rate_scaled[0:10]
#x_base = b2_flood_rate
y_base = b_latency_ms[0:10]

#x_sc = sc_send_rate_scaled[0:7]
x_sc = sc_flood_rate
y_sc = sc_latency_ms

# plot the same data on both axes
#use dashes/dots
ax.plot(x_base,y_base, "r", marker='.', label="Vanilla Kernel")
ax.plot(x_sc, y_sc, "g",  marker='.', label="SmartCookie")

ax2.plot(x_sc, y_sc,"g",  marker='.', label="SmartCookie")

ax.set_xlim(0,2)
ax2.set_xlim(125,140)

ax.set_ylim(0,10)
ax2.set_ylim(0, 10)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
#ax.yaxis.tick_left()
ax2.yaxis.tick_right()
ax2.tick_params(labelright=False)


# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax.tick_params(labelbottom=True) 
ax.xaxis.tick_bottom()
ax2.xaxis.tick_bottom()


d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)


d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
#ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
#ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
#ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
#ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

#x-axis
f.text(0.50, 0.04, 'SYN Flood Attack Rate (Mpps)', ha='center', fontsize='large')
#y-axis
f.text(0.04, 0.55, 'Application Latency (ms)', va='center', rotation='vertical', fontsize='large')
plt.subplots_adjust(left=0.14, bottom=0.14)

handles_1, labels_1 = ax.get_legend_handles_labels()
f.legend(handles_1, labels_1, loc=(0.15, 0.75))
#handles_2, labels_2 = ax2.get_legend_handles_labels()
#f.legend(handles_2, labels_2, loc=(0.65, 0.865))

#add reference lines 
#l1=ax.axhline(0.5,color='black',ls=':')
#l1.set_label('l1')
#l1=ax2.axhline(0.5,color='black',ls=':')
#l1.set_label('l1')

plt.savefig('latency_total.pdf')  

plt.show()
