# %%
# Application Latency Measurements, Baseline, jc4->synflood_assist->jc5 with client jc6 


b_flood_rate_0_1 = 59520
b_curl_list_0_1  = [

"curl latency: 0.000123:0.000500:0.000527 on interface enp3s0f0",
"curl latency: 0.000120:0.000587:0.000636 on interface enp3s0f0",
"curl latency: 0.000131:0.000490:0.000515 on interface enp3s0f0",
"curl latency: 0.000122:0.000466:0.000494 on interface enp3s0f0",
"curl latency: 0.000126:0.000540:0.000566 on interface enp3s0f0",
"curl latency: 0.000111:0.000469:0.000515 on interface enp3s0f0",
"curl latency: 0.000121:0.000472:0.000513 on interface enp3s0f0",
"curl latency: 0.000126:0.000597:0.000642 on interface enp3s0f0",
"curl latency: 0.000122:0.000524:0.000551 on interface enp3s0f0",
"curl latency: 0.000123:0.000441:0.000466 on interface enp3s0f0",
"curl latency: 0.000132:0.000512:0.000539 on interface enp3s0f0",
"curl latency: 0.000121:0.000588:0.000615 on interface enp3s0f0",
"curl latency: 0.000183:0.000620:0.000646 on interface enp3s0f0",
"curl latency: 0.000122:0.000535:0.000579 on interface enp3s0f0",
"curl latency: 0.000129:0.000640:0.000689 on interface enp3s0f0",
"curl latency: 0.000119:0.000580:0.000628 on interface enp3s0f0",
"curl latency: 0.000127:0.000475:0.000520 on interface enp3s0f0",
"curl latency: 0.000116:0.000486:0.000514 on interface enp3s0f0",
"curl latency: 0.000158:0.000641:0.000672 on interface enp3s0f0",
"curl latency: 0.000117:0.000515:0.000544 on interface enp3s0f0",
"curl latency: 0.000113:0.000440:0.000465 on interface enp3s0f0",
"curl latency: 0.000120:0.000483:0.000508 on interface enp3s0f0",
"curl latency: 0.000127:0.000627:0.000672 on interface enp3s0f0",
"curl latency: 0.000121:0.000522:0.000547 on interface enp3s0f0",
"curl latency: 0.000147:0.000540:0.000566 on interface enp3s0f0",
"curl latency: 0.000117:0.000553:0.000600 on interface enp3s0f0",
"curl latency: 0.000130:0.000681:0.000729 on interface enp3s0f0",
"curl latency: 0.000161:0.000496:0.000521 on interface enp3s0f0",
"curl latency: 0.000122:0.000648:0.000694 on interface enp3s0f0",
"curl latency: 0.000124:0.000519:0.000544 on interface enp3s0f0",
"curl latency: 0.000120:0.000540:0.000564 on interface enp3s0f0",
"curl latency: 0.000125:0.000489:0.000515 on interface enp3s0f0",
"curl latency: 0.000123:0.000615:0.000642 on interface enp3s0f0",
"curl latency: 0.000125:0.000483:0.000540 on interface enp3s0f0",
"curl latency: 0.000124:0.000491:0.000516 on interface enp3s0f0",
"curl latency: 0.000127:0.000654:0.000699 on interface enp3s0f0",
"curl latency: 0.000123:0.000449:0.000474 on interface enp3s0f0",
"curl latency: 0.000123:0.000452:0.000480 on interface enp3s0f0",
"curl latency: 0.000131:0.000561:0.000589 on interface enp3s0f0",
"curl latency: 0.000126:0.000607:0.000653 on interface enp3s0f0",
]


b_flood_rate_0_5 = 299082
b_curl_list_0_5  = [

"curl latency: 0.000114:0.000638:0.000684 on interface enp3s0f0",
"curl latency: 0.000121:0.000635:0.000682 on interface enp3s0f0",
"curl latency: 0.000163:0.000669:0.000722 on interface enp3s0f0",
"curl latency: 0.000128:0.000574:0.000607 on interface enp3s0f0",
"curl latency: 0.000131:0.000589:0.000613 on interface enp3s0f0",
"curl latency: 0.000124:0.000773:0.000802 on interface enp3s0f0",
"curl latency: 0.000126:0.000598:0.000648 on interface enp3s0f0",
"curl latency: 0.000155:0.000793:0.000842 on interface enp3s0f0",
"curl latency: 0.000130:0.000677:0.000723 on interface enp3s0f0",
"curl latency: 0.000137:0.000807:0.000855 on interface enp3s0f0",
"curl latency: 0.000123:0.000792:0.000817 on interface enp3s0f0",
"curl latency: 0.000156:0.000672:0.000721 on interface enp3s0f0",
"curl latency: 0.000132:0.000547:0.000575 on interface enp3s0f0",
"curl latency: 0.000128:0.000613:0.000640 on interface enp3s0f0",
"curl latency: 0.000136:0.000753:0.000801 on interface enp3s0f0",
"curl latency: 0.000225:0.000767:0.000794 on interface enp3s0f0",
"curl latency: 0.000122:0.000827:0.000875 on interface enp3s0f0",
"curl latency: 0.000140:0.000626:0.000650 on interface enp3s0f0",
"curl latency: 0.000120:0.000786:0.000849 on interface enp3s0f0",
"curl latency: 0.000126:0.000753:0.000813 on interface enp3s0f0",
"curl latency: 0.000121:0.000536:0.000561 on interface enp3s0f0",
"curl latency: 0.000166:0.000885:0.000912 on interface enp3s0f0",
"curl latency: 0.000120:0.000729:0.000762 on interface enp3s0f0",
"curl latency: 0.000139:0.000627:0.000650 on interface enp3s0f0",
"curl latency: 0.000136:0.000696:0.000721 on interface enp3s0f0",
"curl latency: 0.000135:0.000782:0.000842 on interface enp3s0f0",
"curl latency: 0.000122:0.000734:0.000780 on interface enp3s0f0",
"curl latency: 0.000114:0.000814:0.000842 on interface enp3s0f0",
"curl latency: 0.000125:0.000747:0.000795 on interface enp3s0f0",
"curl latency: 0.000120:0.000648:0.000719 on interface enp3s0f0",
"curl latency: 0.000118:0.000754:0.000802 on interface enp3s0f0",
"curl latency: 0.000136:0.000591:0.000616 on interface enp3s0f0",
"curl latency: 0.000115:0.000556:0.000605 on interface enp3s0f0",
"curl latency: 0.000131:0.000721:0.000747 on interface enp3s0f0",
"curl latency: 0.000119:0.000661:0.000709 on interface enp3s0f0",
"curl latency: 0.000123:0.000591:0.000634 on interface enp3s0f0",
"curl latency: 0.000117:0.000680:0.000726 on interface enp3s0f0",
"curl latency: 0.000135:0.000773:0.000824 on interface enp3s0f0",
"curl latency: 0.000122:0.000748:0.000797 on interface enp3s0f0",

]

b_flood_rate_1 = 595000
b_curl_list_1 = [
    
"curl latency: 0.000120:0.000290:0.000313 on interface enp3s0f0",
"curl latency: 0.000128:0.000358:0.000385 on interface enp3s0f0",
"curl latency: 0.000124:0.000354:0.000398 on interface enp3s0f0",
"curl latency: 0.000152:0.000321:0.000344 on interface enp3s0f0",
"curl latency: 0.000132:0.000300:0.000324 on interface enp3s0f0",
"curl latency: 0.000124:0.000334:0.000359 on interface enp3s0f0",
"curl latency: 0.000130:0.000309:0.000331 on interface enp3s0f0",
"curl latency: 0.000127:0.000285:0.000310 on interface enp3s0f0",
"curl latency: 0.000122:0.000284:0.000306 on interface enp3s0f0",
"curl latency: 0.000139:0.000305:0.000327 on interface enp3s0f0",
"curl latency: 0.000185:0.000363:0.000387 on interface enp3s0f0",
"curl latency: 0.000122:0.000291:0.000317 on interface enp3s0f0",
"curl latency: 0.000121:0.000323:0.000348 on interface enp3s0f0",
"curl latency: 0.000124:0.000334:0.000357 on interface enp3s0f0",
"curl latency: 0.000133:0.000312:0.000335 on interface enp3s0f0",
"curl latency: 0.000123:0.000290:0.000314 on interface enp3s0f0",
"curl latency: 0.000124:0.000305:0.000329 on interface enp3s0f0",
"curl latency: 0.000132:0.000299:0.000324 on interface enp3s0f0",
"curl latency: 0.000134:0.000357:0.000401 on interface enp3s0f0",
"curl latency: 0.000122:0.000296:0.000328 on interface enp3s0f0",
"curl latency: 0.000125:0.000322:0.000346 on interface enp3s0f0",
"curl latency: 0.000120:0.000267:0.000292 on interface enp3s0f0",
"curl latency: 0.000123:0.000321:0.000344 on interface enp3s0f0",
"curl latency: 0.000127:0.000314:0.000337 on interface enp3s0f0",
"curl latency: 0.000118:0.000296:0.000319 on interface enp3s0f0",
"curl latency: 0.000118:0.000350:0.000382 on interface enp3s0f0",
"curl latency: 0.000122:0.000412:0.000456 on interface enp3s0f0",
"curl latency: 0.000120:0.000433:0.000458 on interface enp3s0f0",
"curl latency: 0.000111:0.000295:0.000323 on interface enp3s0f0",
"curl latency: 0.000139:0.000335:0.000358 on interface enp3s0f0",
"curl latency: 0.000125:0.000353:0.000378 on interface enp3s0f0",
"curl latency: 0.000125:0.000304:0.000330 on interface enp3s0f0",
"curl latency: 0.000121:0.000382:0.000405 on interface enp3s0f0",
"curl latency: 0.000146:0.000318:0.000344 on interface enp3s0f0",
"curl latency: 0.000123:0.000331:0.000356 on interface enp3s0f0",
"curl latency: 0.000124:0.000334:0.000357 on interface enp3s0f0",
"curl latency: 0.000135:0.000485:0.000510 on interface enp3s0f0",
"curl latency: 0.000135:0.000393:0.000416 on interface enp3s0f0",
"curl latency: 0.000120:0.000353:0.000377 on interface enp3s0f0",
"curl latency: 0.000126:0.000430:0.000457 on interface enp3s0f0",

]


b_flood_rate_1_5 = 899168
b_curl_list_1_5 = [

"curl latency: 0.000124:0.000400:0.000441 on interface enp3s0f0",
"curl latency: 0.000150:0.000389:0.000430 on interface enp3s0f0",
"curl latency: 0.000182:0.000413:0.000438 on interface enp3s0f0",
"curl latency: 0.000151:0.000358:0.000383 on interface enp3s0f0",
"curl latency: 0.000123:0.000363:0.000388 on interface enp3s0f0",
"curl latency: 0.000153:0.000417:0.000441 on interface enp3s0f0",
"curl latency: 0.000156:0.000408:0.000434 on interface enp3s0f0",
"curl latency: 0.000132:0.000329:0.000351 on interface enp3s0f0",
"curl latency: 0.000138:0.000424:0.000468 on interface enp3s0f0",
"curl latency: 0.000127:0.000370:0.000412 on interface enp3s0f0",
"curl latency: 0.001386:0.001735:0.001782 on interface enp3s0f0",
"curl latency: 0.000125:0.000307:0.000329 on interface enp3s0f0",
"curl latency: 0.000314:0.000643:0.000688 on interface enp3s0f0",
"curl latency: 0.000121:0.000409:0.000436 on interface enp3s0f0",
"curl latency: 0.000110:0.000354:0.000380 on interface enp3s0f0",
"curl latency: 0.000196:0.000541:0.000569 on interface enp3s0f0",
"curl latency: 0.000286:0.000548:0.000571 on interface enp3s0f0",
"curl latency: 0.000112:0.000351:0.000376 on interface enp3s0f0",
"curl latency: 0.000222:0.000502:0.000525 on interface enp3s0f0",
"curl latency: 0.007124:0.007331:0.007357 on interface enp3s0f0",
"curl latency: 0.000104:0.000317:0.000342 on interface enp3s0f0",
"curl latency: 0.007420:0.007821:0.007871 on interface enp3s0f0",
"curl latency: 0.002156:0.002540:0.002565 on interface enp3s0f0",
"curl latency: 0.000143:0.000504:0.000546 on interface enp3s0f0",
"curl latency: 0.000173:0.000470:0.000492 on interface enp3s0f0",
"curl latency: 0.000220:0.000621:0.000647 on interface enp3s0f0",
"curl latency: 0.000152:0.000349:0.000371 on interface enp3s0f0",
"curl latency: 0.000143:0.000390:0.000418 on interface enp3s0f0",
"curl latency: 0.000189:0.000455:0.000479 on interface enp3s0f0",
"curl latency: 0.000123:0.000448:0.000475 on interface enp3s0f0",
"curl latency: 0.000123:0.000412:0.000435 on interface enp3s0f0",
"curl latency: 0.000127:0.000357:0.000380 on interface enp3s0f0",
"curl latency: 0.000167:0.000432:0.000457 on interface enp3s0f0",
"curl latency: 0.000214:0.000481:0.000512 on interface enp3s0f0",
"curl latency: 0.000173:0.000547:0.000590 on interface enp3s0f0",
"curl latency: 0.000164:0.000401:0.000425 on interface enp3s0f0",
"curl latency: 0.000142:0.000373:0.000395 on interface enp3s0f0",
"curl latency: 0.000154:0.000510:0.000536 on interface enp3s0f0",
"curl latency: 0.000166:0.000450:0.000492 on interface enp3s0f0",
"curl latency: 0.000134:0.000338:0.000363 on interface enp3s0f0",
]

b_flood_rate_2 = 1189457
b_curl_list_2 = [
"curl latency: 0.000213:0.000854:0.000916 on interface enp3s0f0",
"curl latency: 0.000292:0.000837:0.000883 on interface enp3s0f0",
"curl latency: 0.000183:0.000653:0.000681 on interface enp3s0f0",
"curl latency: 0.000272:0.000719:0.000745 on interface enp3s0f0",
"curl latency: 0.000245:0.000702:0.000730 on interface enp3s0f0",
"curl latency: 0.000260:0.000622:0.000666 on interface enp3s0f0",
"curl latency: 0.000229:0.000753:0.000778 on interface enp3s0f0",
"curl latency: 0.000201:0.000720:0.000797 on interface enp3s0f0",
"curl latency: 0.000204:0.001212:0.001274 on interface enp3s0f0",
"curl latency: 0.000237:0.001884:0.001911 on interface enp3s0f0",
"curl latency: 0.000228:0.001886:0.001914 on interface enp3s0f0",
"curl latency: 0.000208:0.001769:0.001824 on interface enp3s0f0",
"curl latency: 0.000241:0.001747:0.001776 on interface enp3s0f0",
"curl latency: 0.000339:0.001721:0.001769 on interface enp3s0f0",
"curl latency: 0.000216:0.001696:0.001743 on interface enp3s0f0",
"curl latency: 0.000218:0.001632:0.001658 on interface enp3s0f0",
"curl latency: 0.000184:0.001597:0.001644 on interface enp3s0f0",
"curl latency: 0.000177:0.000875:0.000923 on interface enp3s0f0",
"curl latency: 0.000181:0.000621:0.000649 on interface enp3s0f0",
"curl latency: 0.000248:0.000743:0.000767 on interface enp3s0f0",
"curl latency: 0.000202:0.000643:0.000902 on interface enp3s0f0",
"curl latency: 0.000187:0.000579:0.000605 on interface enp3s0f0",
"curl latency: 0.007757:0.019081:0.019129 on interface enp3s0f0",
"curl latency: 0.002524:0.005457:0.005502 on interface enp3s0f0",
"curl latency: 0.002190:0.004435:0.004480 on interface enp3s0f0",
"curl latency: 0.004491:0.008446:0.008496 on interface enp3s0f0",
"curl latency: 0.000378:0.001059:0.001084 on interface enp3s0f0",
"curl latency: 0.000448:0.001340:0.001366 on interface enp3s0f0",
"curl latency: 0.000746:0.001720:0.001744 on interface enp3s0f0",
"curl latency: 0.000168:0.000580:0.000605 on interface enp3s0f0",
"curl latency: 0.000148:0.000598:0.000647 on interface enp3s0f0",
"curl latency: 0.000271:0.000733:0.000754 on interface enp3s0f0",
"curl latency: 0.000242:0.000703:0.000730 on interface enp3s0f0",
]

b_flood_rate_2_5 = 1486216
b_curl_list_2_5 = [
    
"curl latency: 0.000170:0.001099:0.001151 on interface enp3s0f0",
"curl latency: 0.005601:0.013919:0.013966 on interface enp3s0f0",
"curl latency: 0.007107:0.013985:0.014038 on interface enp3s0f0",
"curl latency: 0.000206:0.001196:0.001246 on interface enp3s0f0",
"curl latency: 0.000137:0.000971:0.001021 on interface enp3s0f0",
"curl latency: 0.000184:0.001141:0.001190 on interface enp3s0f0",
"curl latency: 0.000178:0.001162:0.001225 on interface enp3s0f0",
"curl latency: 0.000345:0.001062:0.001111 on interface enp3s0f0",
"curl latency: 0.000181:0.000668:0.000717 on interface enp3s0f0",
"curl latency: 0.000164:0.000540:0.000590 on interface enp3s0f0",
"curl latency: 0.000136:0.000448:0.000474 on interface enp3s0f0",
"curl latency: 0.000953:0.002059:0.002110 on interface enp3s0f0",
"curl latency: 0.001478:0.002768:0.002797 on interface enp3s0f0",
"curl latency: 0.009263:0.225352:0.225403 on interface enp3s0f0",
"curl latency: 0.000201:0.000811:0.000859 on interface enp3s0f0",
"curl latency: 0.000165:0.000397:0.000424 on interface enp3s0f0",
"curl latency: 0.000204:0.000633:0.000659 on interface enp3s0f0",
"curl latency: 0.000163:0.000649:0.000684 on interface enp3s0f0",
"curl latency: 0.000127:0.000535:0.000579 on interface enp3s0f0",
"curl latency: 0.000239:0.000809:0.000857 on interface enp3s0f0",
"curl latency: 0.000131:0.000540:0.000584 on interface enp3s0f0",
"curl latency: 0.000247:0.000965:0.001013 on interface enp3s0f0",
"curl latency: 0.000187:0.001019:0.001045 on interface enp3s0f0",
"curl latency: 0.000130:0.000702:0.000750 on interface enp3s0f0",
"curl latency: 0.000134:0.001495:0.001547 on interface enp3s0f0",
"curl latency: 0.000224:0.001499:0.001551 on interface enp3s0f0",
"curl latency: 0.000253:0.001304:0.001354 on interface enp3s0f0",
"curl latency: 0.000138:0.001681:0.001729 on interface enp3s0f0",
"curl latency: 0.000239:0.001486:0.001544 on interface enp3s0f0",
"curl latency: 0.000127:0.001271:0.001317 on interface enp3s0f0",
"curl latency: 0.001258:0.003629:0.003662 on interface enp3s0f0",
"curl latency: 0.000159:0.001074:0.001104 on interface enp3s0f0",
"curl latency: 0.000250:0.001550:0.001580 on interface enp3s0f0",
"curl latency: 0.001274:0.002995:0.003020 on interface enp3s0f0",
"curl latency: 0.001251:0.002838:0.002885 on interface enp3s0f0",
"curl latency: 1.026062:1.028728:1.028776 on interface enp3s0f0",
]

b_flood_rate_2_75 = 1658779
b_curl_list_2_75 = [
"curl latency: 0.000217:0.001148:0.001174 on interface enp3s0f0",
"curl latency: 0.000161:0.001062:0.001109 on interface enp3s0f0",
"curl latency: 0.000254:0.002992:0.003018 on interface enp3s0f0",
"curl latency: 0.000209:0.000895:0.000959 on interface enp3s0f0",
"curl latency: 0.000159:0.001010:0.001057 on interface enp3s0f0",
"curl latency: 0.000178:0.001095:0.001142 on interface enp3s0f0",
"curl latency: 0.001174:0.002695:0.002746 on interface enp3s0f0",
"curl latency: 3.040175:3.041515:3.041565 on interface enp3s0f0",
"curl latency: 0.000133:0.001403:0.001430 on interface enp3s0f0",
"curl latency: 0.000159:0.001177:0.001227 on interface enp3s0f0",
"curl latency: 0.000199:0.001270:0.001322 on interface enp3s0f0",
"curl latency: 0.000212:0.001208:0.001258 on interface enp3s0f0",
"curl latency: 0.000251:0.001135:0.001161 on interface enp3s0f0",
"curl latency: 0.000208:0.001196:0.001221 on interface enp3s0f0",
"curl latency: 0.000225:0.001230:0.001283 on interface enp3s0f0",
"curl latency: 0.000144:0.000967:0.001022 on interface enp3s0f0",
"curl latency: 0.000172:0.001192:0.001221 on interface enp3s0f0",
"curl latency: 0.000137:0.000947:0.000971 on interface enp3s0f0",
"curl latency: 0.000252:0.001058:0.001108 on interface enp3s0f0",
"curl latency: 0.000144:0.001195:0.001245 on interface enp3s0f0",
"curl latency: 0.000159:0.001069:0.001116 on interface enp3s0f0",
"curl latency: 0.000218:0.000736:0.000779 on interface enp3s0f0",
"curl latency: 0.000198:0.000805:0.000867 on interface enp3s0f0",
"curl latency: 0.000140:0.000790:0.000817 on interface enp3s0f0",
"curl latency: 0.000173:0.001037:0.001091 on interface enp3s0f0",
"curl latency: 0.000152:0.000697:0.000723 on interface enp3s0f0",
"curl latency: 0.000169:0.001300:0.001347 on interface enp3s0f0",
"curl latency: 0.000196:0.001161:0.001208 on interface enp3s0f0",
"curl latency: 0.000157:0.000825:0.000853 on interface enp3s0f0",
"curl latency: 0.000156:0.000938:0.001000 on interface enp3s0f0",
"curl latency: 0.000155:0.000899:0.000949 on interface enp3s0f0",
"curl latency: 0.006920:0.015364:0.015414 on interface enp3s0f0",
"curl latency: 0.005828:0.010846:0.010895 on interface enp3s0f0",
"curl latency: 1.014853:1.056344:1.056393 on interface enp3s0f0",
"curl latency: 0.000134:0.001314:0.001366 on interface enp3s0f0",
"curl latency: 0.000164:0.001205:0.001261 on interface enp3s0f0",
"curl latency: 0.000135:0.001105:0.001156 on interface enp3s0f0",
"curl latency: 0.001656:0.002584:0.002634 on interface enp3s0f0",
"curl latency: 1.020565:1.023515:1.023565 on interface enp3s0f0",
"curl latency: 1.011164:1.016067:1.016117 on interface enp3s0f0",
"curl latency: 1.001671:1.002258:1.002321 on interface enp3s0f0",

]


b_flood_rate_3 = 1783576
b_curl_list_3 = [
    
"curl latency: 0.007913:0.014998:0.015051 on interface enp3s0f0",
"curl latency: 0.004210:0.006152:0.006189 on interface enp3s0f0",
"curl latency: 3.039149:3.249183:3.249232 on interface enp3s0f0",
"curl latency: 0.002257:0.004530:0.004580 on interface enp3s0f0",
"curl latency: 0.001947:0.004529:0.004571 on interface enp3s0f0",
"curl latency: 0.001698:0.208582:0.208629 on interface enp3s0f0",
"curl latency: 0.001857:0.004425:0.004473 on interface enp3s0f0",
"curl latency: 0.002622:0.004918:0.004945 on interface enp3s0f0",
"curl latency: 0.001832:0.003794:0.003844 on interface enp3s0f0",
"curl latency: 0.001733:0.003568:0.003596 on interface enp3s0f0",
"curl latency: 0.008690:0.017080:0.017132 on interface enp3s0f0",
"curl latency: 0.006216:0.012027:0.012075 on interface enp3s0f0",
"curl latency: 0.001842:0.215050:0.215100 on interface enp3s0f0",
"curl latency: 0.001736:0.003880:0.003910 on interface enp3s0f0",
"curl latency: 0.004834:0.009038:0.009065 on interface enp3s0f0",
"curl latency: 0.000176:0.000614:0.000663 on interface enp3s0f0",
"curl latency: 0.000154:0.000584:0.000617 on interface enp3s0f0",
"curl latency: 0.000207:0.000613:0.000639 on interface enp3s0f0",
"curl latency: 0.000162:0.000698:0.000751 on interface enp3s0f0",
"curl latency: 0.000240:0.000615:0.000643 on interface enp3s0f0",
"curl latency: 0.000214:0.000677:0.000707 on interface enp3s0f0",
"curl latency: 0.000263:0.000618:0.000645 on interface enp3s0f0",
"curl latency: 0.000175:0.000593:0.000622 on interface enp3s0f0",
"curl latency: 0.000228:0.000666:0.000691 on interface enp3s0f0",
"curl latency: 0.001067:0.002371:0.002421 on interface enp3s0f0",
"curl latency: 0.001382:0.002965:0.002992 on interface enp3s0f0",
"curl latency: 0.000189:0.001815:0.001861 on interface enp3s0f0",
"curl latency: 0.002083:0.003827:0.003854 on interface enp3s0f0",
"curl latency: 0.003404:0.210488:0.210536 on interface enp3s0f0",
"curl latency: 0.002153:0.004710:0.004775 on interface enp3s0f0",
"curl latency: 0.002231:0.004965:0.004995 on interface enp3s0f0",
"curl latency: 0.002067:0.004408:0.004440 on interface enp3s0f0",
"curl latency: 0.002541:0.207418:0.207481 on interface enp3s0f0",
"curl latency: 0.006493:0.012560:0.012608 on interface enp3s0f0",

]

b_flood_rate_3_5 = 2079892
b_curl_list_3_5 = [
    
"curl latency: 0.009234:0.231025:0.231073 on interface enp3s0f0",
"curl latency: 1.033614:1.245559:1.245607 on interface enp3s0f0",
"curl latency: 0.005283:0.213002:0.213052 on interface enp3s0f0",
"curl latency: 0.005167:0.216222:0.216274 on interface enp3s0f0",
"curl latency: 0.001812:0.004664:0.004712 on interface enp3s0f0",
"curl latency: 0.006536:0.431104:0.431138 on interface enp3s0f0",
"curl latency: 0.005439:0.011827:0.011859 on interface enp3s0f0",
"curl latency: 0.001657:0.003394:0.003422 on interface enp3s0f0",
"curl latency: 0.001941:0.004515:0.004562 on interface enp3s0f0",
"curl latency: 0.005722:0.015590:0.015617 on interface enp3s0f0",
"curl latency: 3.047861:3.050247:3.050311 on interface enp3s0f0",
"curl latency: 3.026916:3.029340:3.029391 on interface enp3s0f0",
"curl latency: 0.004970:0.010853:0.010906 on interface enp3s0f0",
"curl latency: 0.001617:0.003566:0.003607 on interface enp3s0f0",
"curl latency: 0.002244:0.005360:0.005396 on interface enp3s0f0",
"curl latency: 0.002134:0.418173:0.418237 on interface enp3s0f0",
"curl latency: 0.002032:0.004184:0.004212 on interface enp3s0f0",
"curl latency: 0.005118:0.010932:0.010960 on interface enp3s0f0",
"curl latency: 0.006386:0.013941:0.013971 on interface enp3s0f0",
"curl latency: 1.016707:1.019318:1.019367 on interface enp3s0f0",
"curl latency: 0.005773:0.014217:0.014248 on interface enp3s0f0",
"curl latency: 1.016726:1.435324:1.435373 on interface enp3s0f0",
"curl latency: 1.008334:1.012211:1.012259 on interface enp3s0f0",
"curl latency: 0.002252:0.004543:0.004573 on interface enp3s0f0",
"curl latency: 0.001848:0.211853:0.211902 on interface enp3s0f0",
"curl latency: 0.006418:0.011391:0.011442 on interface enp3s0f0",
"curl latency: 1.004042:1.010853:1.010917 on interface enp3s0f0",
"curl latency: 1.004608:1.011528:1.011561 on interface enp3s0f0",
"curl latency: 0.002463:0.211462:0.211511 on interface enp3s0f0",
"curl latency: 0.006352:0.012097:0.012133 on interface enp3s0f0",
"curl latency: 0.002468:0.214306:0.214354 on interface enp3s0f0",
"curl latency: 0.002411:0.004795:0.004843 on interface enp3s0f0",
"curl latency: 0.002191:0.214674:0.214722 on interface enp3s0f0",
"curl latency: 3.044496:3.047202:3.047265 on interface enp3s0f0",
"curl latency: 1.007997:1.216429:1.216460 on interface enp3s0f0",
]

b_flood_rate_4 = 2376161
b_curl_list_4 = [
    
"curl latency: 0.006284:0.434793:0.434860 on interface enp3s0f0",
"curl latency: 3.027234:3.033052:3.033103 on interface enp3s0f0",
"curl latency: 0.002161:0.004614:0.004646 on interface enp3s0f0",
"curl latency: 0.001799:0.831132:0.831161 on interface enp3s0f0",
"curl latency: 1.011904:1.223132:1.223183 on interface enp3s0f0",
"curl latency: 1.022295:1.025018:1.025069 on interface enp3s0f0",
"curl latency: 3.024509:3.247816:3.247864 on interface enp3s0f0",
"curl latency: 0.005273:0.221749:0.221801 on interface enp3s0f0",
"curl latency: 0.002820:0.211248:0.211300 on interface enp3s0f0",
"curl latency: 1.007293:1.014681:1.014730 on interface enp3s0f0",
"curl latency: 1.036236:1.042560:1.042611 on interface enp3s0f0",
"curl latency: 0.008767:0.875848:0.875896 on interface enp3s0f0",
"curl latency: 3.023699:3.026385:3.026436 on interface enp3s0f0",
"curl latency: 0.002372:0.214040:0.214105 on interface enp3s0f0",
"curl latency: 0.001969:0.004547:0.004597 on interface enp3s0f0",
"curl latency: 0.005783:0.216092:0.216143 on interface enp3s0f0",
"curl latency: 0.002014:0.212167:0.212218 on interface enp3s0f0",
"curl latency: 0.001620:0.004391:0.004438 on interface enp3s0f0",
"curl latency: 0.003224:0.005724:0.005789 on interface enp3s0f0",
"curl latency: 0.005489:0.013027:0.013078 on interface enp3s0f0",
"curl latency: 0.004253:0.006794:0.006821 on interface enp3s0f0",
"curl latency: 0.002336:0.215274:0.215304 on interface enp3s0f0",
"curl latency: 0.001641:1.684008:1.684061 on interface enp3s0f0",
"curl latency: 1.010711:1.016426:1.016475 on interface enp3s0f0",
"curl latency: 0.003486:0.211992:0.212045 on interface enp3s0f0",
"curl latency: 1.007123:1.009938:1.009987 on interface enp3s0f0",
"curl latency: 7.184043:7.187123:7.187178 on interface enp3s0f0",
"curl latency: 0.001751:0.003805:0.003856 on interface enp3s0f0",
"curl latency: 1.023495:1.231479:1.231543 on interface enp3s0f0",
"curl latency: 0.001613:0.003690:0.003739 on interface enp3s0f0",
"curl latency: 0.005802:0.013035:0.013096 on interface enp3s0f0",
"curl latency: 0.006580:0.429945:0.429997 on interface enp3s0f0",
"curl latency: 0.002012:0.419173:0.419223 on interface enp3s0f0",
"curl latency: 0.004729:0.010740:0.010791 on interface enp3s0f0",
"curl latency: 3.045257:3.054497:3.054548 on interface enp3s0f0",
]


#note, modified the format of the next few measurements, adjust string extraction for average calculation in next cell 
b_flood_rate_4_5 = 2715376
b_curl_list_4_5 = [
    
"curl latency: 01.012627:01.017125:01.017176 on interface enp3s0f0",
"curl latency: 00.002991:00.006963:00.007029 on interface enp3s0f0",
"curl latency: 15.419943:18.748697:18.748746 on interface enp3s0f0",
"curl latency: 00.001603:00.003501:00.003533 on interface enp3s0f0",
"curl latency: 00.004043:01.670884:01.670933 on interface enp3s0f0",
"curl latency: 00.001705:00.003651:00.003698 on interface enp3s0f0",
"curl latency: 15.429690:15.432179:15.432231 on interface enp3s0f0",
"curl latency: 00.001751:00.003663:00.003695 on interface enp3s0f0",
"curl latency: 01.027444:01.029410:01.029459 on interface enp3s0f0",
"curl latency: 00.002152:00.411193:00.411245 on interface enp3s0f0",
"curl latency: 01.004275:01.412332:01.412383 on interface enp3s0f0",
"curl latency: 00.001865:00.005840:00.005870 on interface enp3s0f0",
"curl latency: 15.243400:15.246042:15.246090 on interface enp3s0f0",
"curl latency: 01.008772:01.212577:01.212628 on interface enp3s0f0",
"curl latency: 01.031334:01.235804:01.235855 on interface enp3s0f0",
"curl latency: 01.032722:01.240387:01.240438 on interface enp3s0f0",
"curl latency: 01.027234:01.030569:01.030617 on interface enp3s0f0",
"curl latency: 00.007651:00.010189:00.010220 on interface enp3s0f0",
"curl latency: 00.002465:00.004835:00.004887 on interface enp3s0f0",
"curl latency: 00.001861:01.645326:01.645374 on interface enp3s0f0",
"curl latency: 00.002141:00.210246:00.210277 on interface enp3s0f0",
"curl latency: 00.002196:00.004940:00.004993 on interface enp3s0f0",
"curl latency: 03.046600:03.254600:03.254651 on interface enp3s0f0",
"curl latency: 01.028161:01.236568:01.236634 on interface enp3s0f0",
"curl latency: 01.026818:01.234914:01.234963 on interface enp3s0f0",
"curl latency: 00.003517:00.837786:00.837835 on interface enp3s0f0",
"curl latency: 03.027024:03.235648:03.235700 on interface enp3s0f0",
"curl latency: 00.002030:00.211424:00.211476 on interface enp3s0f0",
"curl latency: 00.001973:00.005822:00.005873 on interface enp3s0f0",
"curl latency: 00.001766:00.416812:00.416861 on interface enp3s0f0",
"curl latency: 00.002466:00.005379:00.005406 on interface enp3s0f0",
"curl latency: 01.017436:01.222235:01.222286 on interface enp3s0f0",
"curl latency: 00.002006:00.207451:00.207502 on interface enp3s0f0",
"curl latency: 00.003302:00.219149:00.219200 on interface enp3s0f0",
"curl latency: 00.002246:00.005219:00.005285 on interface enp3s0f0",
"curl latency: 00.001817:00.821013:00.821076 on interface enp3s0f0",
"curl latency: 07.091671:07.094707:07.094759 on interface enp3s0f0",
"curl latency: 00.002647:00.005356:00.005386 on interface enp3s0f0",
"curl latency: 00.001767:00.836690:00.836742 on interface enp3s0f0",
"curl latency: 01.007551:01.420912:01.420964 on interface enp3s0f0",
"curl latency: 00.002328:00.004754:00.004789 on interface enp3s0f0",
"curl latency: 00.001780:00.003853:00.003903 on interface enp3s0f0",
"curl latency: 00.002340:00.005094:00.005123 on interface enp3s0f0",
"curl latency: 00.001648:00.003593:00.003623 on interface enp3s0f0",
"curl latency: 00.003298:00.006300:00.006367 on interface enp3s0f0",
"curl latency: 01.011041:01.013624:01.013709 on interface enp3s0f0",
"curl latency: 00.006492:00.009028:00.009076 on interface enp3s0f0",
"curl latency: 01.022860:01.234772:01.234823 on interface enp3s0f0",
"curl latency: 15.296267:17.020560:17.020611 on interface enp3s0f0",
]

b_flood_rate_5 = 3016674
b_curl_list_5 = [
    
"curl latency: 01.008185:02.681316:02.681369 on interface enp3s0f0",
"curl latency: 00.002481:00.846641:00.846691 on interface enp3s0f0",
"curl latency: 01.007449:01.009922:01.009974 on interface enp3s0f0",
"curl latency: 01.014717:01.226919:01.226992 on interface enp3s0f0",
"curl latency: 00.009270:00.012304:00.012355 on interface enp3s0f0",
"curl latency: 01.030155:01.033341:01.033393 on interface enp3s0f0",
"curl latency: 00.001845:00.004207:00.004255 on interface enp3s0f0",
"curl latency: 00.005808:00.216587:00.216638 on interface enp3s0f0",
"curl latency: 01.023913:01.031338:01.031388 on interface enp3s0f0",
"curl latency: 01.034374:01.040091:01.040139 on interface enp3s0f0",
"curl latency: 01.009915:01.018909:01.018957 on interface enp3s0f0",
"curl latency: 00.002097:00.427171:00.427220 on interface enp3s0f0",
"curl latency: 00.007627:00.217387:00.217438 on interface enp3s0f0",
"curl latency: 00.004092:00.010868:00.010937 on interface enp3s0f0",
"curl latency: 01.009516:01.217509:01.217574 on interface enp3s0f0",
"curl latency: 00.004925:00.213182:00.213231 on interface enp3s0f0",
"curl latency: 00.002242:01.670638:01.670687 on interface enp3s0f0",
"curl latency: 00.007220:00.223044:00.223095 on interface enp3s0f0",
"curl latency: 00.001618:00.215656:00.215705 on interface enp3s0f0",
"curl latency: 15.296482:15.504397:15.504444 on interface enp3s0f0",
"curl latency: 00.002111:00.216031:00.216080 on interface enp3s0f0",
"curl latency: 00.002090:00.420703:00.420754 on interface enp3s0f0",
"curl latency: 00.001636:00.010322:00.010349 on interface enp3s0f0",
"curl latency: 15.483080:15.486428:15.486477 on interface enp3s0f0",
"curl latency: 01.008505:01.011180:01.011242 on interface enp3s0f0",
"curl latency: 15.343808:15.347160:15.347211 on interface enp3s0f0",
"curl latency: 00.007594:00.222987:00.223038 on interface enp3s0f0",
"curl latency: 00.003678:00.007684:00.007732 on interface enp3s0f0",
"curl latency: 01.008654:01.011152:01.011200 on interface enp3s0f0",
"curl latency: 03.024253:03.233383:03.233447 on interface enp3s0f0",
"curl latency: 07.235134:07.242479:07.242528 on interface enp3s0f0",
"curl latency: 01.004118:01.007080:01.007131 on interface enp3s0f0",
"curl latency: 01.008884:01.012404:01.012456 on interface enp3s0f0",
"curl latency: 01.011891:01.428596:01.428645 on interface enp3s0f0",
"curl latency: 31.567410:31.984397:31.984451 on interface enp3s0f0",
"curl latency: 01.010015:01.845107:01.845159 on interface enp3s0f0",
"curl latency: 01.010410:01.220814:01.220865 on interface enp3s0f0",
]


b_flood_rate_10 = 5927462
b_curl_list_10 = [
    
"curl latency: 031.454153:031.456929:031.456984 on interface enp3s0f0",
"curl latency: 001.012088:001.442408:001.442474 on interface enp3s0f0",
"curl latency: 000.007590:001.736999:001.737065 on interface enp3s0f0",
"curl latency: 007.277956:007.695044:007.695095 on interface enp3s0f0",
"curl latency: 015.442978:015.447109:015.447174 on interface enp3s0f0",
"curl latency: 000.008526:111.348986:111.349042 on interface enp3s0f0",
"curl latency: 000.001997:000.847248:000.847300 on interface enp3s0f0",
"curl latency: 007.058599:007.061647:007.061698 on interface enp3s0f0",
"curl latency: 007.151847:007.361780:007.361833 on interface enp3s0f0",
"curl latency: 000.000000:000.000000:130.080936 on interface enp3s0f0",
"curl latency: 000.008908:000.227315:000.227366 on interface enp3s0f0",
"curl latency: 000.000000:000.000000:130.821283 on interface enp3s0f0",
"curl latency: 001.012021:001.428581:001.428646 on interface enp3s0f0",
"curl latency: 000.000000:000.000000:129.617489 on interface enp3s0f0",
"curl latency: 001.013333:014.324858:014.324912 on interface enp3s0f0",
"curl latency: 065.522690:078.835233:078.835285 on interface enp3s0f0",
"curl latency: 001.010658:001.220248:001.220298 on interface enp3s0f0",
"curl latency: 000.002129:001.666561:001.666610 on interface enp3s0f0",
"curl latency: 003.027631:003.236598:003.236651 on interface enp3s0f0",
"curl latency: 015.330682:015.539329:015.539381 on interface enp3s0f0",
"curl latency: 003.043013:003.459829:003.459879 on interface enp3s0f0",
"curl latency: 000.005004:000.010493:000.010544 on interface enp3s0f0",
"curl latency: 001.020131:004.348410:004.348460 on interface enp3s0f0",
"curl latency: 001.011318:001.428095:001.428160 on interface enp3s0f0",
"curl latency: 000.000000:000.000000:129.745671 on interface enp3s0f0",
"curl latency: 031.477209:031.682267:031.682318 on interface enp3s0f0",
"curl latency: 000.002343:000.005278:000.005340 on interface enp3s0f0",
"curl latency: 001.014698:001.847574:001.847623 on interface enp3s0f0",
"curl latency: 001.011662:001.014881:001.014932 on interface enp3s0f0",
    
]

# %%
    for i in b_curl_list_10:
        time_connect = i[14:24]
        time_start = i[25:35]
        time_total = i[36:46]
        print(time_connect, time_start, time_total)
# Out:
# 031.454153 031.456929 031.456984
# 001.012088 001.442408 001.442474
# 000.007590 001.736999 001.737065
# 007.277956 007.695044 007.695095
# 015.442978 015.447109 015.447174
# 000.008526 111.348986 111.349042
# 000.001997 000.847248 000.847300
# 007.058599 007.061647 007.061698
# 007.151847 007.361780 007.361833
# 000.000000 000.000000 130.080936
# 000.008908 000.227315 000.227366
# 000.000000 000.000000 130.821283
# 001.012021 001.428581 001.428646
# 000.000000 000.000000 129.617489
# 001.013333 014.324858 014.324912
# 065.522690 078.835233 078.835285
# 001.010658 001.220248 001.220298
# 000.002129 001.666561 001.666610
# 003.027631 003.236598 003.236651
# 015.330682 015.539329 015.539381
# 003.043013 003.459829 003.459879
# 000.005004 000.010493 000.010544
# 001.020131 004.348410 004.348460
# 001.011318 001.428095 001.428160
# 000.000000 000.000000 129.745671
# 031.477209 031.682267 031.682318
# 000.002343 000.005278 000.005340
# 001.014698 001.847574 001.847623
# ...

# %%
# Application Latency Measurements 

b_curl_list_name = [b_curl_list_0_1, b_curl_list_0_5, b_curl_list_1, b_curl_list_1_5, b_curl_list_2, 
                    b_curl_list_2_5, b_curl_list_2_75, b_curl_list_3, b_curl_list_3_5, b_curl_list_4]

b_curl_list_name_long = [b_curl_list_4_5, b_curl_list_5]


b_flood_rate = [b_flood_rate_0_1, b_flood_rate_0_5, b_flood_rate_1, b_flood_rate_1_5, b_flood_rate_2, 
                b_flood_rate_2_5, b_flood_rate_2_75, b_flood_rate_3, b_flood_rate_3_5, b_flood_rate_4,
                b_flood_rate_4_5, b_flood_rate_5, b_flood_rate_10]
b_curl_latency = [] 

#change name of list to get the average from that list 

for list in b_curl_list_name: 
    sum = 0
    count = 0 
    for i in list:
        time_connect = i[14:22]
        time_start = i[23:31]
        time_total = i[32:40]
        #print(time_connect, time_start, time_total)
        sum += float(time_total)
        count+=1
    avg = sum/count
    b_curl_latency.append(avg)
    #print(sum, count, avg)
    
#need to account for longer latencies in format xx.xxxx  
for list in b_curl_list_name_long: 
    sum = 0
    count = 0 
    for i in list:
        time_connect = i[14:23]
        time_start = i[24:33]
        time_total = i[34:43]
        #print(time_connect, time_start, time_total)
        sum += float(time_total)
        count+=1
    avg = sum/count
    b_curl_latency.append(avg)
    
#need to account for longer latencies in format xxx.xxxx
sum = 0
count = 0 
for i in b_curl_list_10:
    time_connect = i[14:24]
    time_start = i[25:35]
    time_total = i[36:46]
    #print(time_connect, time_start, time_total)
    sum += float(time_total)
    count+=1
avg = sum/count
b_curl_latency.append(avg)
        
print(b_curl_latency)
# Out:
# [0.0005722250000000001, 0.0007373589743589743, 0.0003595500000000001, 0.00089975, 0.0021239999999999996, 0.03679338888888889, 0.1758319756097561, 0.12424508823529411, 0.5593496285714287, 0.9531911999999997, 2.1053469387755097, 3.041385054054054, 29.82553272413794]

# %%
#Plot DDoS Attack Rate versus Application Latency

from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np

#x-axis
b_send_rate_scaled = np.true_divide(b_flood_rate,1e6)
#sc_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

#y-axis 
b_latency_ms = np.multiply(b_curl_latency, 1e3) #show latency in ms 
#sc_return_ratio = np.divide(sc_return_rate, sc_send_rate)

x_base = b_send_rate_scaled
y_base = b_latency_ms

#x_sc = sc_send_rate_scaled
#y_sc = sc_return_ratio

figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("Application Latency (ms)")

plt.plot(x_base, y_base, "-b", label="vanilla kernel")
#plt.plot(x_xdp, y_xdp, "-g", label="smart cookie")

plt.legend(loc="upper left")

plt.show()
