# %%
### CPU Resources, Baseline SYN Flood against Vanilla Server with SYN cookies enabled, jc4->synflood_assist on tofino->jc5 
# plot as ratio 

#x-axis: syn packets per second (million) 
#y-axis: cpu resources 

rate_0_01 = 5952
list_0_01 = [
    
"CPU0               24,904,410      cycles                    #    0.025 GHz",
"CPU1               31,771,437      cycles                    #    0.032 GHz",
"CPU2               37,529,879      cycles                    #    0.037 GHz",
"CPU3               40,292,055      cycles                    #    0.040 GHz",
"CPU4               37,627,261      cycles                    #    0.038 GHz",
"CPU5               36,583,004      cycles                    #    0.037 GHz",
"CPU6               37,376,776      cycles                    #    0.037 GHz",
"CPU7               38,407,440      cycles                    #    0.038 GHz",
"CPU8               27,183,549      cycles                    #    0.027 GHz",
"CPU9               32,795,128      cycles                    #    0.033 GHz",
"CPU10              30,239,344      cycles                    #    0.030 GHz",
"CPU11              44,724,132      cycles                    #    0.045 GHz",
"CPU12              31,115,874      cycles                    #    0.031 GHz",
"CPU13              29,847,662      cycles                    #    0.030 GHz",
"CPU14              31,464,144      cycles                    #    0.031 GHz",
"CPU15              31,410,999      cycles                    #    0.031 GHz",


]

rate_0_5 = 297530
list_0_5 = [
    
"CPU0               38,266,997      cycles                    #    0.038 GHz",
"CPU1               98,612,555      cycles                    #    0.098 GHz",
"CPU2              110,732,699      cycles                    #    0.111 GHz",
"CPU3               96,634,651      cycles                    #    0.097 GHz",
"CPU4              116,044,261      cycles                    #    0.116 GHz",
"CPU5              107,988,924      cycles                    #    0.108 GHz",
"CPU6              137,110,902      cycles                    #    0.137 GHz",
"CPU7              139,735,871      cycles                    #    0.140 GHz",
"CPU8              101,852,267      cycles                    #    0.102 GHz",
"CPU9              111,297,565      cycles                    #    0.111 GHz",
"CPU10              91,411,238      cycles                    #    0.091 GHz",
"CPU11             123,134,247      cycles                    #    0.123 GHz",
"CPU12              97,031,393      cycles                    #    0.097 GHz",
"CPU13              89,658,671      cycles                    #    0.090 GHz",
"CPU14             104,613,795      cycles                    #    0.104 GHz",
"CPU15             121,564,682      cycles                    #    0.121 GHz",
    
]

rate_1 = 599717
list_1 = [
"CPU0               20,565,591      cycles                    #    0.021 GHz",
"CPU1              544,849,841      cycles                    #    0.544 GHz",
"CPU2              653,045,000      cycles                    #    0.652 GHz",
"CPU3              690,667,747      cycles                    #    0.690 GHz",
"CPU4              710,663,238      cycles                    #    0.709 GHz",
"CPU5              644,343,956      cycles                    #    0.643 GHz",
"CPU6              741,057,687      cycles                    #    0.740 GHz",
"CPU7              713,925,277      cycles                    #    0.713 GHz",
"CPU8              604,325,962      cycles                    #    0.603 GHz",
"CPU9              876,732,848      cycles                    #    0.875 GHz",
"CPU10             651,893,849      cycles                    #    0.651 GHz",
"CPU11             800,628,261      cycles                    #    0.799 GHz",
"CPU12             760,501,320      cycles                    #    0.759 GHz",
"CPU13             637,093,315      cycles                    #    0.636 GHz",
"CPU14             695,645,652      cycles                    #    0.695 GHz",
"CPU15             709,265,006      cycles                    #    0.708 GHz",

    
]

rate_1_5 = 892063

list_1_5 = [
"CPU0               21,974,638      cycles                    #    0.022 GHz",
"CPU1              693,154,643      cycles                    #    0.692 GHz",
"CPU2            1,046,402,822      cycles                    #    1.044 GHz",
"CPU3            1,029,153,673      cycles                    #    1.028 GHz",
"CPU4              818,318,099      cycles                    #    0.817 GHz",
"CPU5              765,053,519      cycles                    #    0.764 GHz",
"CPU6            1,088,732,175      cycles                    #    1.086 GHz",
"CPU7            1,063,239,870      cycles                    #    1.061 GHz",
"CPU8              671,162,581      cycles                    #    0.670 GHz",
"CPU9              604,612,935      cycles                    #    0.603 GHz",
"CPU10           1,051,955,171      cycles                    #    1.050 GHz",
"CPU11           1,246,730,245      cycles                    #    1.245 GHz",
"CPU12             709,345,033      cycles                    #    0.708 GHz",
"CPU13             767,632,633      cycles                    #    0.766 GHz",
"CPU14           1,055,390,008      cycles                    #    1.054 GHz",
"CPU15           1,023,597,295      cycles                    #    1.022 GHz",

    
]



rate_2 = 1189709

list_2 = [
    
"CPU0               37,698,676      cycles                    #    0.038 GHz",
"CPU1              813,635,552      cycles                    #    0.812 GHz",
"CPU2              834,576,202      cycles                    #    0.832 GHz",
"CPU3            1,132,796,754      cycles                    #    1.130 GHz",
"CPU4              766,548,837      cycles                    #    0.764 GHz",
"CPU5              776,940,278      cycles                    #    0.775 GHz",
"CPU6              779,911,073      cycles                    #    0.776 GHz",
"CPU7              889,289,661      cycles                    #    0.884 GHz",
"CPU8              664,784,083      cycles                    #    0.661 GHz",
"CPU9              811,422,739      cycles                    #    0.807 GHz",
"CPU10             854,884,474      cycles                    #    0.849 GHz",
"CPU11           1,455,479,645      cycles                    #    1.445 GHz",
"CPU12             802,118,071      cycles                    #    0.796 GHz",
"CPU13             778,303,163      cycles                    #    0.772 GHz",
"CPU14             780,357,663      cycles                    #    0.773 GHz",
"CPU15             798,511,859      cycles                    #    0.791 GHz",

]


rate_2_5 = 1485973 

list_2_5 = [ 
"CPU0               31,561,430      cycles                    #    0.031 GHz",
"CPU1              903,244,892      cycles                    #    0.867 GHz",
"CPU2              901,947,445      cycles                    #    0.900 GHz",
"CPU3            1,014,170,328      cycles                    #    1.012 GHz",
"CPU4              953,866,378      cycles                    #    0.952 GHz",
"CPU5              937,672,388      cycles                    #    0.935 GHz",
"CPU6              932,515,891      cycles                    #    0.930 GHz",
"CPU7              876,151,199      cycles                    #    0.874 GHz",
"CPU8              590,199,223      cycles                    #    0.589 GHz",
"CPU9              895,873,340      cycles                    #    0.893 GHz",
"CPU10             905,014,717      cycles                    #    0.905 GHz",
"CPU11           1,553,366,271      cycles                    #    1.553 GHz",
"CPU12             946,954,197      cycles                    #    0.947 GHz",
"CPU13             928,999,633      cycles                    #    0.929 GHz",
"CPU14             905,539,977      cycles                    #    0.906 GHz",
"CPU15             876,059,498      cycles                    #    0.876 GHz",




]



rate_2_75 = 1634483


list_2_75 = [
"CPU0               41,372,030      cycles                    #    0.041 GHz",
"CPU1              903,519,098      cycles                    #    0.901 GHz",
"CPU2              895,551,698      cycles                    #    0.893 GHz",
"CPU3              989,593,853      cycles                    #    0.987 GHz",
"CPU4              899,485,998      cycles                    #    0.896 GHz",
"CPU5              865,189,901      cycles                    #    0.862 GHz",
"CPU6              899,553,674      cycles                    #    0.896 GHz",
"CPU7              885,393,403      cycles                    #    0.882 GHz",
"CPU8              678,741,821      cycles                    #    0.676 GHz",
"CPU9              935,093,950      cycles                    #    0.931 GHz",
"CPU10             897,324,856      cycles                    #    0.893 GHz",
"CPU11           1,580,188,029      cycles                    #    1.573 GHz",
"CPU12             887,190,294      cycles                    #    0.884 GHz",
"CPU13             871,588,671      cycles                    #    0.867 GHz",
"CPU14             906,647,265      cycles                    #    0.903 GHz",
"CPU15             886,642,702      cycles                    #    0.882 GHz",


]


rate_3 = 1790658

list_3 = [
"CPU0               49,771,768      cycles                    #    0.050 GHz",
"CPU1              945,619,893      cycles                    #    0.942 GHz",
"CPU2            1,008,221,877      cycles                    #    1.006 GHz",
"CPU3            1,116,155,073      cycles                    #    1.114 GHz",
"CPU4            1,020,801,056      cycles                    #    1.019 GHz",
"CPU5              972,626,382      cycles                    #    0.970 GHz",
"CPU6              981,322,464      cycles                    #    0.979 GHz",
"CPU7              992,939,547      cycles                    #    0.991 GHz",
"CPU8              623,759,358      cycles                    #    0.622 GHz",
"CPU9              972,842,716      cycles                    #    0.970 GHz",
"CPU10             967,134,961      cycles                    #    0.965 GHz",
"CPU11           1,714,402,987      cycles                    #    1.711 GHz",
"CPU12             961,836,425      cycles                    #    0.960 GHz",
"CPU13           1,006,053,580      cycles                    #    1.005 GHz",
"CPU14           1,013,149,674      cycles                    #    1.012 GHz",
"CPU15             997,226,731      cycles                    #    0.999 GHz",

    
]


rate_3_5 = 2079866

list_3_5 = [
"CPU0               45,853,161      cycles                    #    0.045 GHz",
"CPU1              889,069,950      cycles                    #    0.887 GHz",
"CPU2              927,225,151      cycles                    #    0.924 GHz",
"CPU3            1,049,564,834      cycles                    #    1.046 GHz",
"CPU4              933,117,225      cycles                    #    0.930 GHz",
"CPU5              933,075,104      cycles                    #    0.930 GHz",
"CPU6              929,096,750      cycles                    #    0.926 GHz",
"CPU7              926,362,938      cycles                    #    0.924 GHz",
"CPU8              616,308,553      cycles                    #    0.614 GHz",
"CPU9              954,413,727      cycles                    #    0.952 GHz",
"CPU10             928,011,353      cycles                    #    0.925 GHz",
"CPU11           1,651,960,210      cycles                    #    1.646 GHz",
"CPU12             931,993,504      cycles                    #    0.929 GHz",
"CPU13             933,777,064      cycles                    #    0.930 GHz",
"CPU14             927,723,378      cycles                    #    0.924 GHz",
"CPU15             931,761,603      cycles                    #    0.928 GHz",

    
]



rate_4 = 2375988

list_4 = [
    
"CPU0               40,190,308      cycles                    #    0.040 GHz",
"CPU1              906,353,338      cycles                    #    0.905 GHz",
"CPU2              959,782,999      cycles                    #    0.957 GHz",
"CPU3            1,077,742,616      cycles                    #    1.074 GHz",
"CPU4              961,606,319      cycles                    #    0.958 GHz",
"CPU5              956,877,888      cycles                    #    0.953 GHz",
"CPU6              958,785,774      cycles                    #    0.955 GHz",
"CPU7              945,554,131      cycles                    #    0.942 GHz",
"CPU8              621,901,555      cycles                    #    0.619 GHz",
"CPU9              978,523,640      cycles                    #    0.974 GHz",
"CPU10             965,016,076      cycles                    #    0.961 GHz",
"CPU11           1,688,956,496      cycles                    #    1.681 GHz",
"CPU12             959,520,013      cycles                    #    0.955 GHz",
"CPU13             956,372,216      cycles                    #    0.952 GHz",
"CPU14             959,083,798      cycles                    #    0.955 GHz",
"CPU15             950,391,692      cycles                    #    0.946 GHz",

]



rate_4_5 = 2672588

list_4_5 = [
    
"CPU0               37,106,217      cycles                    #    0.037 GHz",
"CPU1              914,088,208      cycles                    #    0.912 GHz",
"CPU2              942,625,717      cycles                    #    0.940 GHz",
"CPU3            1,073,164,700      cycles                    #    1.071 GHz",
"CPU4              913,635,775      cycles                    #    0.912 GHz",
"CPU5              967,749,782      cycles                    #    0.966 GHz",
"CPU6              960,769,241      cycles                    #    0.958 GHz",
"CPU7              943,431,641      cycles                    #    0.940 GHz",
"CPU8              626,522,765      cycles                    #    0.624 GHz",
"CPU9              977,782,653      cycles                    #    0.974 GHz",
"CPU10             943,762,788      cycles                    #    0.940 GHz",
"CPU11           1,675,998,105      cycles                    #    1.670 GHz",
"CPU12             911,614,105      cycles                    #    0.909 GHz",
"CPU13             962,907,503      cycles                    #    0.960 GHz",
"CPU14             956,119,847      cycles                    #    0.953 GHz",
"CPU15             947,671,812      cycles                    #    0.945 GHz",

]


rate_5 = 2969918

list_5 = [

"CPU0               27,758,050      cycles                    #    0.028 GHz",
"CPU1              892,826,578      cycles                    #    0.890 GHz",
"CPU2              944,535,850      cycles                    #    0.942 GHz",
"CPU3            1,059,513,612      cycles                    #    1.057 GHz",
"CPU4              937,830,699      cycles                    #    0.935 GHz",
"CPU5              929,181,503      cycles                    #    0.927 GHz",
"CPU6              949,409,057      cycles                    #    0.947 GHz",
"CPU7              948,214,142      cycles                    #    0.945 GHz",
"CPU8              616,091,698      cycles                    #    0.614 GHz",
"CPU9              959,497,718      cycles                    #    0.956 GHz",
"CPU10             945,516,419      cycles                    #    0.943 GHz",
"CPU11           1,665,812,424      cycles                    #    1.660 GHz",
"CPU12             936,965,821      cycles                    #    0.935 GHz",
"CPU13             930,437,518      cycles                    #    0.928 GHz",
"CPU14             948,644,529      cycles                    #    0.946 GHz",
"CPU15             952,016,114      cycles                    #    0.949 GHz",


]

rate_10 = 5927608

list_10 = [
    
"CPU0               26,163,026      cycles                    #    0.026 GHz",
"CPU1              917,436,918      cycles                    #    0.915 GHz",
"CPU2              955,680,254      cycles                    #    0.952 GHz",
"CPU3            1,076,756,623      cycles                    #    1.073 GHz",
"CPU4              951,014,769      cycles                    #    0.948 GHz",
"CPU5              958,190,424      cycles                    #    0.955 GHz",
"CPU6              965,642,888      cycles                    #    0.963 GHz",
"CPU7              961,911,902      cycles                    #    0.960 GHz",
"CPU8              633,287,437      cycles                    #    0.632 GHz",
"CPU9              984,033,173      cycles                    #    0.981 GHz",
"CPU10             956,848,491      cycles                    #    0.953 GHz",
"CPU11           1,694,728,428      cycles                    #    1.688 GHz",
"CPU12             953,638,415      cycles                    #    0.950 GHz",
"CPU13             959,744,981      cycles                    #    0.956 GHz",
"CPU14             965,937,976      cycles                    #    0.962 GHz",
"CPU15             958,248,108      cycles                    #    0.954 GHz",

    
]

rate_15 = 9004929

list_15 = [
    
"CPU0               40,196,095      cycles                    #    0.040 GHz",
"CPU1              908,971,981      cycles                    #    0.906 GHz",
"CPU2              960,774,617      cycles                    #    0.957 GHz",
"CPU3            1,101,864,314      cycles                    #    1.098 GHz",
"CPU4              956,312,264      cycles                    #    0.953 GHz",
"CPU5              973,834,927      cycles                    #    0.971 GHz",
"CPU6              964,352,591      cycles                    #    0.961 GHz",
"CPU7              954,546,283      cycles                    #    0.951 GHz",
"CPU8              663,932,204      cycles                    #    0.662 GHz",
"CPU9              982,591,505      cycles                    #    0.979 GHz",
"CPU10             960,442,907      cycles                    #    0.957 GHz",
"CPU11           1,714,607,751      cycles                    #    1.709 GHz",
"CPU12             957,322,505      cycles                    #    0.954 GHz",
"CPU13             973,768,599      cycles                    #    0.971 GHz",
"CPU14             960,565,709      cycles                    #    0.958 GHz",
"CPU15             953,911,704      cycles                    #    0.953 GHz",

]

# %%
list_5
# Out:
# ['CPU0               27,758,050      cycles                    #    0.028 GHz',
#  'CPU1              892,826,578      cycles                    #    0.890 GHz',
#  'CPU2              944,535,850      cycles                    #    0.942 GHz',
#  'CPU3            1,059,513,612      cycles                    #    1.057 GHz',
#  'CPU4              937,830,699      cycles                    #    0.935 GHz',
#  'CPU5              929,181,503      cycles                    #    0.927 GHz',
#  'CPU6              949,409,057      cycles                    #    0.947 GHz',
#  'CPU7              948,214,142      cycles                    #    0.945 GHz',
#  'CPU8              616,091,698      cycles                    #    0.614 GHz',
#  'CPU9              959,497,718      cycles                    #    0.956 GHz',
#  'CPU10             945,516,419      cycles                    #    0.943 GHz',
#  'CPU11           1,665,812,424      cycles                    #    1.660 GHz',
# ...

# %%
sum=0
num_cpu = 16 

for line in list_5:
    #print(line[16:30])
    index = 0 
    num_str=""
    for char in line:
        index+=1
        if index>10:
            if index < 30:
                if char.isdigit():
                    #print(char)
                    num_str+=char
    print(num_str)
    sum+=int(num_str)
    
avg=sum/num_cpu
print(sum, avg)
# Out:
# 27758050
# 892826578
# 944535850
# 1059513612
# 937830699
# 929181503
# 949409057
# 948214142
# 616091698
# 959497718
# 945516419
# 1665812424
# 936965821
# 930437518
# 948644529
# 952016114
# 14644251732 915265733.25

# %%
list_name = [list_0_01, list_0_5, list_1, list_1_5, list_2, list_2_5, list_2_75, list_3, 
             list_3_5, list_4, list_4_5, list_5, list_10, list_15]

send_rate = [rate_0_01, rate_0_5, rate_1, rate_1_5, rate_2, rate_2_5, rate_2_75, rate_3, 
             rate_3_5, rate_4, rate_4_5, rate_5, rate_10, rate_15]
cpu_avg = [] 

#change name of list to get the average from that list 

for list in list_name: 
    sum=0
    num_cpu = 16 

    for line in list:
        #print(line[16:30])
        index = 0 
        num_str=""
        for char in line:
            index+=1
            if index>10:
                if index < 30:
                    if char.isdigit():
                        #print(char)
                        num_str+=char
        #print(num_str)
        sum+=int(num_str)
    
    avg=sum/num_cpu
    #print(sum, avg)
    cpu_avg.append(avg)
    
print(cpu_avg)
# Out:
# [33954568.375, 105355669.875, 653450284.375, 853528458.75, 811078670.625, 884571050.4375, 876442327.6875, 958991530.75, 906832156.5625, 930416178.6875, 922184428.6875, 915265733.25, 932453988.3125, 939249747.25]

# %%
# SYN flood to measure CPU resource with SmartCookie 



sc_rate_0_1 = 5952
sc_list_0_1 = [
    
"CPU0                  670,276      cycles                    #    0.001 GHz",
"CPU1                  480,411      cycles                    #    0.000 GHz",
"CPU2                  464,165      cycles                    #    0.000 GHz",
"CPU3                1,301,577      cycles                    #    0.001 GHz",
"CPU4                  539,219      cycles                    #    0.001 GHz",
"CPU5                  134,850      cycles                    #    0.000 GHz",
"CPU6                  786,114      cycles                    #    0.001 GHz",
"CPU7                  336,765      cycles                    #    0.000 GHz",
"CPU8                  268,471      cycles                    #    0.000 GHz",
"CPU9                  157,009      cycles                    #    0.000 GHz",
"CPU10                 996,016      cycles                    #    0.001 GHz",
"CPU11                 368,466      cycles                    #    0.000 GHz",
"CPU12                 563,305      cycles                    #    0.001 GHz",
"CPU13                 117,056      cycles                    #    0.000 GHz",
"CPU14                 248,390      cycles                    #    0.000 GHz",
"CPU15                 478,170      cycles                    #    0.000 GHz",


    
]

sc_rate_1 = 594986
sc_list_1 = [
    
CPU0                  510,834      cycles                    #    0.001 GHz
CPU1                  987,206      cycles                    #    0.001 GHz
CPU2                  478,979      cycles                    #    0.000 GHz
CPU3                  551,649      cycles                    #    0.001 GHz
CPU4                  875,499      cycles                    #    0.001 GHz
CPU5                  133,903      cycles                    #    0.000 GHz
CPU6                  743,149      cycles                    #    0.001 GHz
CPU7                  535,115      cycles                    #    0.001 GHz
CPU8                  635,804      cycles                    #    0.001 GHz
CPU9                  283,657      cycles                    #    0.000 GHz
CPU10                 979,630      cycles                    #    0.001 GHz
CPU11                 900,346      cycles                    #    0.001 GHz
CPU12                 293,257      cycles                    #    0.000 GHz
CPU13                 114,553      cycles                    #    0.000 GHz
CPU14                 238,272      cycles                    #    0.000 GHz
CPU15                 740,534      cycles                    #    0.001 GHz
]

sc_rate_2_5 = 1485981
sc_list_2_5 = [
    
CPU0                  783,048      cycles                    #    0.001 GHz
CPU1                  549,229      cycles                    #    0.001 GHz
CPU2                  114,677      cycles                    #    0.000 GHz
CPU3                  502,813      cycles                    #    0.001 GHz
CPU4                  661,663      cycles                    #    0.001 GHz
CPU5                  346,790      cycles                    #    0.000 GHz
CPU6                1,141,701      cycles                    #    0.001 GHz
CPU7                  260,684      cycles                    #    0.000 GHz
CPU8                  266,379      cycles                    #    0.000 GHz
CPU9                  156,480      cycles                    #    0.000 GHz
CPU10                 166,589      cycles                    #    0.000 GHz
CPU11                 792,977      cycles                    #    0.001 GHz
CPU12                 241,691      cycles                    #    0.000 GHz
CPU13                 750,508      cycles                    #    0.001 GHz
CPU14                 327,236      cycles                    #    0.000 GHz
CPU15                 461,486      cycles                    #    0.000 GHz
    
]

sc_rate_5 = 2986359
sc_list_5 = [
    
CPU0                  250,823      cycles                    #    0.000 GHz
CPU1                  435,537      cycles                    #    0.000 GHz
CPU2                  244,413      cycles                    #    0.000 GHz
CPU3                  794,557      cycles                    #    0.001 GHz
CPU4                  537,201      cycles                    #    0.001 GHz
CPU5                  363,550      cycles                    #    0.000 GHz
CPU6                  969,940      cycles                    #    0.001 GHz
CPU7                  622,523      cycles                    #    0.001 GHz
CPU8                  218,483      cycles                    #    0.000 GHz
CPU9                  134,781      cycles                    #    0.000 GHz
CPU10                 396,000      cycles                    #    0.000 GHz
CPU11                 715,172      cycles                    #    0.001 GHz
CPU12                 711,004      cycles                    #    0.001 GHz
CPU13                 541,403      cycles                    #    0.001 GHz
CPU14                 763,413      cycles                    #    0.001 GHz
CPU15                 417,602      cycles                    #    0.000 GHz
    
    
]

sc_rate_10 = 5952
sc_list_10 = [
    
]

sc_rate_15 = 5952
sc_list_15 = [
    
]

sc_rate_20 = 5952
sc_list_20 = [
    
]

sc_rate_30 = 5952
sc_list_30 = [
    
]

sc_rate_50 = 5952
sc_list_50 = [
    
]

sc_rate_100 = 5952
sc_list_100 = [
    
]

# %%
#xdp_list_name = [xdp_list_1, xdp_list_2_5, xdp_list_5, xdp_list_10, xdp_list_15, xdp_list_20, 
                 #xdp_list_30, xdp_list_50, xdp_list_70, xdp_list_80, xdp_list_90, xdp_list_100]
#xdp_send_rate = [xdp_rate_1, xdp_rate_2_5, xdp_rate_5, xdp_rate_10, xdp_rate_15, xdp_rate_20, 
                 #xdp_rate_30, xdp_rate_50, xdp_rate_70, xdp_rate_80, xdp_rate_90, xdp_rate_100]

sc_list_name = [sc_list_0_1, sc_list_1, sc_list_2_5, sc_list_5, sc_list_10, sc_list_15, sc_list_20, 
                 sc_list_30, sc_list_50, sc_list_100]
sc_send_rate = [sc_rate_0_1, sc_rate_1, sc_rate_2_5, sc_rate_5, sc_rate_10, sc_rate_15, sc_rate_20, 
                 sc_rate_30, sc_rate_50, sc_rate_100]

sc_return_rate = [] 

#change name of list to get the average from that list 

for list in xdp_list_name: 
    sum = 0
    count = 0 
    for i in list:
        #print(i[3:10])
        sum += int(i[3:10])
        count+=1
    avg = sum/count
    xdp_return_rate.append(avg)
    #print(sum, count, avg)
print(xdp_return_rate)
# Out:
# [597795.84375, 1493303.3333333333, 2986240.7666666666, 5631993.958333333, 7145005.8965517245, 7431787.321428572, 7325465.6, 7302996.387096774, 7312107.6875]

# %%
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np



send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

cpu_avg_scaled = np.true_divide(cpu_avg, 1e9)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)

x_base = send_rate_scaled
y_base = cpu_avg_scaled

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio

figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("CPU Resources (billion cycles/sec)")

plt.plot(x_base, y_base, "-b", label="vanilla kernel cookies")
#plt.plot(x_xdp, y_xdp, "-g", label="xdp cookies")

plt.legend(loc="upper right")

plt.show()

# %%
## Zoomed in Plot 
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np



send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

cpu_avg_scaled = np.true_divide(cpu_avg, 1e9)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)

x_base = send_rate_scaled[0:11]
y_base = cpu_avg_scaled[0:11]

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio

figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("CPU Resources (billion cycles/sec)")

plt.plot(x_base, y_base, "-b", label="vanilla kernel cookies")
#plt.plot(x_xdp, y_xdp, "-g", label="xdp cookies")

plt.legend(loc="upper right")

plt.show()
