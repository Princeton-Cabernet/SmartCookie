# %%
### Baseline SYN Flood against Vanilla Server with SYN cookies enabled, jc4->synflood_assist on tofino->jc5 
# plot as ratio 

#x-axis: syn packets per second (million) 
#y-axis: syn-ack packets/cookies returned per second (million) 

rate_0_01 = 5952
list_0_01 = [
    
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5992 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5980 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5984 pkts/ on interface enp3s0f0",
"tx 5976 pkts/ on interface enp3s0f0",
    
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5984 pkts/ on interface enp3s0f0",
"rx 5984 pkts/ on interface enp3s0f0",
"rx 5978 pkts/ on interface enp3s0f0",
"rx 5968 pkts/ on interface enp3s0f0",
"rx 5984 pkts/ on interface enp3s0f0",
"rx 5984 pkts/ on interface enp3s0f0",
"rx 5984 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",
"rx 5976 pkts/ on interface enp3s0f0",

]

rate_0_5 = 297530
list_0_5 = [
    
"tx 299911 pkts/ on interface enp3s0f0",
"tx 299328 pkts/ on interface enp3s0f0",
"tx 299063 pkts/ on interface enp3s0f0",
"tx 299392 pkts/ on interface enp3s0f0",
"tx 299078 pkts/ on interface enp3s0f0",
"tx 299654 pkts/ on interface enp3s0f0",
"tx 299314 pkts/ on interface enp3s0f0",
"tx 299275 pkts/ on interface enp3s0f0",
"tx 299192 pkts/ on interface enp3s0f0",
"tx 298966 pkts/ on interface enp3s0f0",
"tx 299774 pkts/ on interface enp3s0f0",
"tx 299558 pkts/ on interface enp3s0f0",
    
"rx 299766 pkts/ on interface enp3s0f0",
"rx 298994 pkts/ on interface enp3s0f0",
"rx 299296 pkts/ on interface enp3s0f0",
"rx 299179 pkts/ on interface enp3s0f0",
"rx 299587 pkts/ on interface enp3s0f0",
"rx 299411 pkts/ on interface enp3s0f0",
"rx 299658 pkts/ on interface enp3s0f0",
"rx 299060 pkts/ on interface enp3s0f0",
"rx 298867 pkts/ on interface enp3s0f0",
"rx 299996 pkts/ on interface enp3s0f0",
"rx 299373 pkts/ on interface enp3s0f0",
"rx 299699 pkts/ on interface enp3s0f0",
"rx 299251 pkts/ on interface enp3s0f0",
"rx 299189 pkts/ on interface enp3s0f0",
"rx 299051 pkts/ on interface enp3s0f0",
    
]

rate_1 = 599717
list_1 = [
"tx 598792 pkts/ on interface enp3s0f0",
"tx 598710 pkts/ on interface enp3s0f0",
"tx 600197 pkts/ on interface enp3s0f0",
"tx 599326 pkts/ on interface enp3s0f0",
"tx 599331 pkts/ on interface enp3s0f0",
"tx 599153 pkts/ on interface enp3s0f0",
"tx 597977 pkts/ on interface enp3s0f0",
"tx 600311 pkts/ on interface enp3s0f0",
"tx 600152 pkts/ on interface enp3s0f0",
"tx 598954 pkts/ on interface enp3s0f0",
"tx 599927 pkts/ on interface enp3s0f0",
"tx 600452 pkts/ on interface enp3s0f0",
"tx 600243 pkts/ on interface enp3s0f0",
"tx 600104 pkts/ on interface enp3s0f0",
"tx 599513 pkts/ on interface enp3s0f0",

"rx 599795 pkts/ on interface enp3s0f0",
"rx 599586 pkts/ on interface enp3s0f0",
"rx 599466 pkts/ on interface enp3s0f0",
"rx 599743 pkts/ on interface enp3s0f0",
"rx 598764 pkts/ on interface enp3s0f0",
"rx 600540 pkts/ on interface enp3s0f0",
"rx 601033 pkts/ on interface enp3s0f0",
"rx 599557 pkts/ on interface enp3s0f0",
"rx 600318 pkts/ on interface enp3s0f0",
"rx 599328 pkts/ on interface enp3s0f0",
"rx 600252 pkts/ on interface enp3s0f0",
"rx 600277 pkts/ on interface enp3s0f0",
"rx 598270 pkts/ on interface enp3s0f0",
"rx 598903 pkts/ on interface enp3s0f0",
    
]

rate_1_5 = 892063

list_1_5 = [
    
"tx 899041 pkts/ on interface enp3s0f0",
"tx 897410 pkts/ on interface enp3s0f0",
"tx 900067 pkts/ on interface enp3s0f0",
"tx 898675 pkts/ on interface enp3s0f0",
"tx 898692 pkts/ on interface enp3s0f0",
"tx 900567 pkts/ on interface enp3s0f0",
"tx 899681 pkts/ on interface enp3s0f0",
"tx 901521 pkts/ on interface enp3s0f0",
"tx 898064 pkts/ on interface enp3s0f0",
"tx 901170 pkts/ on interface enp3s0f0",
"tx 899511 pkts/ on interface enp3s0f0",
"tx 899782 pkts/ on interface enp3s0f0",
"tx 903442 pkts/ on interface enp3s0f0",
"tx 898843 pkts/ on interface enp3s0f0",
"tx 899634 pkts/ on interface enp3s0f0",

"rx 901111 pkts/ on interface enp3s0f0",
"rx 899952 pkts/ on interface enp3s0f0",
"rx 899359 pkts/ on interface enp3s0f0",
"rx 903183 pkts/ on interface enp3s0f0",
"rx 898681 pkts/ on interface enp3s0f0",
"rx 899872 pkts/ on interface enp3s0f0",
"rx 899695 pkts/ on interface enp3s0f0",
"rx 900725 pkts/ on interface enp3s0f0",
"rx 900048 pkts/ on interface enp3s0f0",
"rx 900171 pkts/ on interface enp3s0f0",
"rx 899772 pkts/ on interface enp3s0f0",
"rx 902093 pkts/ on interface enp3s0f0",
"rx 902041 pkts/ on interface enp3s0f0",
"rx 899231 pkts/ on interface enp3s0f0",
"rx 899934 pkts/ on interface enp3s0f0",
"rx 899674 pkts/ on interface enp3s0f0",
"rx 899222 pkts/ on interface enp3s0f0",

    
]


rate_2 = 1189709

list_2 = [
    
"tx 1215991 pkts/ on interface enp3s0f0",
"tx 1206713 pkts/ on interface enp3s0f0",
"tx 1202227 pkts/ on interface enp3s0f0",
"tx 1198425 pkts/ on interface enp3s0f0",
"tx 1205856 pkts/ on interface enp3s0f0",
"tx 1203059 pkts/ on interface enp3s0f0",
"tx 1201837 pkts/ on interface enp3s0f0",
"tx 1201553 pkts/ on interface enp3s0f0",
"tx 1203814 pkts/ on interface enp3s0f0",
"tx 1201150 pkts/ on interface enp3s0f0",
"tx 1223306 pkts/ on interface enp3s0f0",
"tx 1202536 pkts/ on interface enp3s0f0",
"tx 1202056 pkts/ on interface enp3s0f0",
"tx 1195297 pkts/ on interface enp3s0f0",
"tx 1202847 pkts/ on interface enp3s0f0",
    
"rx 1202326 pkts/ on interface enp3s0f0",
"rx 1200711 pkts/ on interface enp3s0f0",
"rx 1197939 pkts/ on interface enp3s0f0",
"rx 1204649 pkts/ on interface enp3s0f0",
"rx 1201687 pkts/ on interface enp3s0f0",
"rx 1207864 pkts/ on interface enp3s0f0",
"rx 1199401 pkts/ on interface enp3s0f0",
"rx 1191871 pkts/ on interface enp3s0f0",
"rx 1210974 pkts/ on interface enp3s0f0",
"rx 1210431 pkts/ on interface enp3s0f0",
"rx 1200893 pkts/ on interface enp3s0f0",
"rx 1201655 pkts/ on interface enp3s0f0",
"rx 1204046 pkts/ on interface enp3s0f0",
"rx 1199343 pkts/ on interface enp3s0f0",
"rx 1200915 pkts/ on interface enp3s0f0",
"rx 1212604 pkts/ on interface enp3s0f0",
"rx 1201230 pkts/ on interface enp3s0f0",
"rx 1200409 pkts/ on interface enp3s0f0",
"rx 1200555 pkts/ on interface enp3s0f0",
"rx 1199918 pkts/ on interface enp3s0f0",
]

#linear scaling up to send rate 2.5 -> 1485973 

rate_2_5 = 1485973 

list_2_5 = [ 
"tx 1488342 pkts/ on interface enp3s0f0",
"tx 1498498 pkts/ on interface enp3s0f0",
"tx 1500517 pkts/ on interface enp3s0f0",
"tx 1503794 pkts/ on interface enp3s0f0",
"tx 1502355 pkts/ on interface enp3s0f0",
"tx 1464938 pkts/ on interface enp3s0f0",
"tx 1496145 pkts/ on interface enp3s0f0",
"tx 1497335 pkts/ on interface enp3s0f0",
"tx 1502293 pkts/ on interface enp3s0f0",
"tx 1497890 pkts/ on interface enp3s0f0",
"tx 1477124 pkts/ on interface enp3s0f0",
"tx 1469537 pkts/ on interface enp3s0f0",
"tx 1493274 pkts/ on interface enp3s0f0",
"tx 1483197 pkts/ on interface enp3s0f0",
"tx 1488400 pkts/ on interface enp3s0f0",
"tx 1460535 pkts/ on interface enp3s0f0",

"rx 1488077 pkts/ on interface enp3s0f0",
"rx 1504050 pkts/ on interface enp3s0f0",
"rx 1500774 pkts/ on interface enp3s0f0",
"rx 1497538 pkts/ on interface enp3s0f0",
"rx 1472181 pkts/ on interface enp3s0f0",
"rx 1495834 pkts/ on interface enp3s0f0",
"rx 1462068 pkts/ on interface enp3s0f0",
"rx 1481137 pkts/ on interface enp3s0f0",
"rx 1499799 pkts/ on interface enp3s0f0",
"rx 1453095 pkts/ on interface enp3s0f0",
"rx 1501745 pkts/ on interface enp3s0f0",
"rx 1504161 pkts/ on interface enp3s0f0",
"rx 1502110 pkts/ on interface enp3s0f0",
"rx 1502680 pkts/ on interface enp3s0f0",
"rx 1491537 pkts/ on interface enp3s0f0",



]


rate_2_75 = 1634483


list_2_75 = [
"tx 1539792 pkts/ on interface enp3s0f0",
"tx 1654782 pkts/ on interface enp3s0f0",
"tx 1601558 pkts/ on interface enp3s0f0",
"tx 1513173 pkts/ on interface enp3s0f0",
"tx 1473219 pkts/ on interface enp3s0f0",
"tx 1453540 pkts/ on interface enp3s0f0",
"tx 1503019 pkts/ on interface enp3s0f0",
"tx 1512536 pkts/ on interface enp3s0f0",
"tx 1461127 pkts/ on interface enp3s0f0",
"tx 1523124 pkts/ on interface enp3s0f0",
"tx 1463398 pkts/ on interface enp3s0f0",
"tx 1466212 pkts/ on interface enp3s0f0",
"tx 1488814 pkts/ on interface enp3s0f0",
"tx 1480196 pkts/ on interface enp3s0f0",
    
"rx 1515292 pkts/ on interface enp3s0f0",
"rx 1458677 pkts/ on interface enp3s0f0",
"rx 1525864 pkts/ on interface enp3s0f0",
"rx 1464947 pkts/ on interface enp3s0f0",
"rx 1462568 pkts/ on interface enp3s0f0",
"rx 1489610 pkts/ on interface enp3s0f0",
"rx 1476390 pkts/ on interface enp3s0f0",
"rx 1492173 pkts/ on interface enp3s0f0",
"rx 1511578 pkts/ on interface enp3s0f0",
"rx 1554031 pkts/ on interface enp3s0f0",
"rx 1472343 pkts/ on interface enp3s0f0",
"rx 1503586 pkts/ on interface enp3s0f0",
"rx 1470244 pkts/ on interface enp3s0f0",
"rx 1462809 pkts/ on interface enp3s0f0",
"rx 1401928 pkts/ on interface enp3s0f0",
"rx 1491042 pkts/ on interface enp3s0f0",

]

rate_3 = 1790658

list_3 = [
"tx 1537074 pkts/ on interface enp3s0f0",
"tx 1489018 pkts/ on interface enp3s0f0",
"tx 1586441 pkts/ on interface enp3s0f0",
"tx 1670690 pkts/ on interface enp3s0f0",
"tx 1745839 pkts/ on interface enp3s0f0",
"tx 1674145 pkts/ on interface enp3s0f0",
"tx 1562587 pkts/ on interface enp3s0f0",
"tx 1567744 pkts/ on interface enp3s0f0",
"tx 1580079 pkts/ on interface enp3s0f0",
"tx 1593837 pkts/ on interface enp3s0f0",
"tx 1541943 pkts/ on interface enp3s0f0",
"tx 1513025 pkts/ on interface enp3s0f0",
"tx 1552173 pkts/ on interface enp3s0f0",
"tx 1563464 pkts/ on interface enp3s0f0",
"tx 1585317 pkts/ on interface enp3s0f0",
"tx 1569579 pkts/ on interface enp3s0f0", 
    
"rx 1578170 pkts/ on interface enp3s0f0",
"rx 1592383 pkts/ on interface enp3s0f0",
"rx 1549383 pkts/ on interface enp3s0f0",
"rx 1510634 pkts/ on interface enp3s0f0",
"rx 1561407 pkts/ on interface enp3s0f0",
"rx 1572310 pkts/ on interface enp3s0f0",
"rx 1590616 pkts/ on interface enp3s0f0",
"rx 1565021 pkts/ on interface enp3s0f0",
"rx 1589571 pkts/ on interface enp3s0f0",
"rx 1740687 pkts/ on interface enp3s0f0",
"rx 1573044 pkts/ on interface enp3s0f0",
"rx 1575715 pkts/ on interface enp3s0f0",
"rx 1656329 pkts/ on interface enp3s0f0",
"rx 1599304 pkts/ on interface enp3s0f0",
"rx 1529611 pkts/ on interface enp3s0f0",
"rx 1525681 pkts/ on interface enp3s0f0",
"rx 1680846 pkts/ on interface enp3s0f0",
    
]


rate_3_5 = 2079866

list_3_5 = [
    
"tx 1505617 pkts/ on interface enp3s0f0",
"tx 1580790 pkts/ on interface enp3s0f0",
"tx 1554827 pkts/ on interface enp3s0f0",
"tx 1544947 pkts/ on interface enp3s0f0",
"tx 1621699 pkts/ on interface enp3s0f0",
"tx 1672168 pkts/ on interface enp3s0f0",
"tx 1606474 pkts/ on interface enp3s0f0",
"tx 1607596 pkts/ on interface enp3s0f0",
"tx 1635801 pkts/ on interface enp3s0f0",
"tx 1624268 pkts/ on interface enp3s0f0",
"tx 1583768 pkts/ on interface enp3s0f0",
"tx 1509323 pkts/ on interface enp3s0f0",
"tx 1586851 pkts/ on interface enp3s0f0",
"tx 1604535 pkts/ on interface enp3s0f0",
"tx 1635406 pkts/ on interface enp3s0f0",
"tx 1530805 pkts/ on interface enp3s0f0",
"tx 1561871 pkts/ on interface enp3s0f0",
    
"rx 1497888 pkts/ on interface enp3s0f0",
"rx 1591169 pkts/ on interface enp3s0f0",
"rx 1605397 pkts/ on interface enp3s0f0",
"rx 1634703 pkts/ on interface enp3s0f0",
"rx 1531502 pkts/ on interface enp3s0f0",
"rx 1555719 pkts/ on interface enp3s0f0",
"rx 1696045 pkts/ on interface enp3s0f0",
"rx 1517888 pkts/ on interface enp3s0f0",
"rx 1551459 pkts/ on interface enp3s0f0",
"rx 1592281 pkts/ on interface enp3s0f0",
"rx 1583071 pkts/ on interface enp3s0f0",
"rx 1649437 pkts/ on interface enp3s0f0",
"rx 1663366 pkts/ on interface enp3s0f0",
"rx 1566506 pkts/ on interface enp3s0f0",
"rx 1601243 pkts/ on interface enp3s0f0",
"rx 1553986 pkts/ on interface enp3s0f0",
"rx 1496561 pkts/ on interface enp3s0f0",
"rx 1527214 pkts/ on interface enp3s0f0",
"rx 1579792 pkts/ on interface enp3s0f0",
"rx 1712195 pkts/ on interface enp3s0f0",
    
]



rate_4 = 2375988

list_4 = [
    
"tx 1527907 pkts/ on interface enp3s0f0",
"tx 1553350 pkts/ on interface enp3s0f0",
"tx 1540121 pkts/ on interface enp3s0f0",
"tx 1617907 pkts/ on interface enp3s0f0",
"tx 1575855 pkts/ on interface enp3s0f0",
"tx 1541985 pkts/ on interface enp3s0f0",
"tx 1756803 pkts/ on interface enp3s0f0",
"tx 1621483 pkts/ on interface enp3s0f0",
"tx 1624328 pkts/ on interface enp3s0f0",
"tx 1611199 pkts/ on interface enp3s0f0",
"tx 1671592 pkts/ on interface enp3s0f0",
"tx 1504695 pkts/ on interface enp3s0f0",
"tx 1545861 pkts/ on interface enp3s0f0",
"tx 1616627 pkts/ on interface enp3s0f0",
"tx 1634862 pkts/ on interface enp3s0f0",

"rx 1598865 pkts/ on interface enp3s0f0",
"rx 1619174 pkts/ on interface enp3s0f0",
"rx 1626485 pkts/ on interface enp3s0f0",
"rx 1582743 pkts/ on interface enp3s0f0",
"rx 1536035 pkts/ on interface enp3s0f0",
"rx 1587726 pkts/ on interface enp3s0f0",
"rx 1595015 pkts/ on interface enp3s0f0",
"rx 1615276 pkts/ on interface enp3s0f0",
"rx 1500737 pkts/ on interface enp3s0f0",
"rx 1623059 pkts/ on interface enp3s0f0",
"rx 1528185 pkts/ on interface enp3s0f0",
"rx 1511151 pkts/ on interface enp3s0f0",
"rx 1546460 pkts/ on interface enp3s0f0",
"rx 1507595 pkts/ on interface enp3s0f0",
"rx 1555330 pkts/ on interface enp3s0f0",
]

rate_5 = 2969918

list_5 = [

"tx 1561719 pkts/ on interface enp3s0f0",
"tx 1508692 pkts/ on interface enp3s0f0",
"tx 1515529 pkts/ on interface enp3s0f0",
"tx 1616420 pkts/ on interface enp3s0f0",
"tx 1582226 pkts/ on interface enp3s0f0",
"tx 1512455 pkts/ on interface enp3s0f0",
"tx 1563605 pkts/ on interface enp3s0f0",
"tx 1606521 pkts/ on interface enp3s0f0",
"tx 1568691 pkts/ on interface enp3s0f0",
"tx 1617175 pkts/ on interface enp3s0f0",
"tx 1587715 pkts/ on interface enp3s0f0",
"tx 1617820 pkts/ on interface enp3s0f0",
"tx 1640971 pkts/ on interface enp3s0f0",
"tx 1535665 pkts/ on interface enp3s0f0",
"tx 1601454 pkts/ on interface enp3s0f0",
"tx 1466737 pkts/ on interface enp3s0f0",

"rx 1647118 pkts/ on interface enp3s0f0",
"rx 1592932 pkts/ on interface enp3s0f0",
"rx 1607330 pkts/ on interface enp3s0f0",
"rx 1576223 pkts/ on interface enp3s0f0",
"rx 1597832 pkts/ on interface enp3s0f0",
"rx 1562843 pkts/ on interface enp3s0f0",
"rx 1486465 pkts/ on interface enp3s0f0",
"rx 1531660 pkts/ on interface enp3s0f0",
"rx 1571729 pkts/ on interface enp3s0f0",
"rx 1626030 pkts/ on interface enp3s0f0",
"rx 1591308 pkts/ on interface enp3s0f0",
"rx 1567650 pkts/ on interface enp3s0f0",
"rx 1516941 pkts/ on interface enp3s0f0",
"rx 1548830 pkts/ on interface enp3s0f0",
"rx 1577531 pkts/ on interface enp3s0f0",

]

rate_7 = 4153547
list_7 = [
"tx 1534838 pkts/ on interface enp3s0f0",
"tx 1611843 pkts/ on interface enp3s0f0",
"tx 1583754 pkts/ on interface enp3s0f0",
"tx 1537020 pkts/ on interface enp3s0f0",
"tx 1526526 pkts/ on interface enp3s0f0",
"tx 1564312 pkts/ on interface enp3s0f0",
"tx 1563423 pkts/ on interface enp3s0f0",
"tx 1545521 pkts/ on interface enp3s0f0",
"tx 1506255 pkts/ on interface enp3s0f0",
"tx 1654570 pkts/ on interface enp3s0f0",
"tx 1585685 pkts/ on interface enp3s0f0",
"tx 1572917 pkts/ on interface enp3s0f0",
"tx 1557305 pkts/ on interface enp3s0f0",
"tx 1496675 pkts/ on interface enp3s0f0",
"tx 1560094 pkts/ on interface enp3s0f0",
"tx 1530163 pkts/ on interface enp3s0f0",
"tx 1562615 pkts/ on interface enp3s0f0",
"tx 1646420 pkts/ on interface enp3s0f0",
"rx 1577291 pkts/ on interface enp3s0f0",
"rx 1549906 pkts/ on interface enp3s0f0",
"rx 1561208 pkts/ on interface enp3s0f0",
"rx 1556936 pkts/ on interface enp3s0f0",
"rx 1549118 pkts/ on interface enp3s0f0",
"rx 1533738 pkts/ on interface enp3s0f0",
"rx 1548519 pkts/ on interface enp3s0f0",
"rx 1623426 pkts/ on interface enp3s0f0",
"rx 1581588 pkts/ on interface enp3s0f0",
"rx 1574742 pkts/ on interface enp3s0f0",
"rx 1524881 pkts/ on interface enp3s0f0",
"rx 1552293 pkts/ on interface enp3s0f0",
"rx 1567594 pkts/ on interface enp3s0f0",
"rx 1530662 pkts/ on interface enp3s0f0",
"rx 1573670 pkts/ on interface enp3s0f0",
"rx 1605604 pkts/ on interface enp3s0f0",
"rx 1436871 pkts/ on interface enp3s0f0",
"rx 1541673 pkts/ on interface enp3s0f0",
"rx 1572813 pkts/ on interface enp3s0f0",
"rx 1517433 pkts/ on interface enp3s0f0",
"rx 1535844 pkts/ on interface enp3s0f0",
"rx 1543754 pkts/ on interface enp3s0f0",
    
]

rate_10 = 5927632
list_10 = [

"tx 1597001 pkts/ on interface enp3s0f0",
"tx 1652569 pkts/ on interface enp3s0f0",
"tx 1503395 pkts/ on interface enp3s0f0",
"tx 1603730 pkts/ on interface enp3s0f0",
"tx 1560959 pkts/ on interface enp3s0f0",
"tx 1585489 pkts/ on interface enp3s0f0",
"tx 1545157 pkts/ on interface enp3s0f0",
"tx 1569116 pkts/ on interface enp3s0f0",
"tx 1542342 pkts/ on interface enp3s0f0",
"tx 1536767 pkts/ on interface enp3s0f0",
"tx 1623121 pkts/ on interface enp3s0f0",
"tx 1569482 pkts/ on interface enp3s0f0",
"tx 1568061 pkts/ on interface enp3s0f0",
"tx 1518863 pkts/ on interface enp3s0f0",
"tx 1544573 pkts/ on interface enp3s0f0",
"tx 1593646 pkts/ on interface enp3s0f0",
"tx 1531704 pkts/ on interface enp3s0f0",
"tx 1561860 pkts/ on interface enp3s0f0",
"tx 1496237 pkts/ on interface enp3s0f0",
"tx 1523319 pkts/ on interface enp3s0f0",

"rx 1533321 pkts/ on interface enp3s0f0",
"rx 1673814 pkts/ on interface enp3s0f0",
"rx 1557121 pkts/ on interface enp3s0f0",
"rx 1563462 pkts/ on interface enp3s0f0",
"rx 1648885 pkts/ on interface enp3s0f0",
"rx 1563094 pkts/ on interface enp3s0f0",
"rx 1572267 pkts/ on interface enp3s0f0",
"rx 1567846 pkts/ on interface enp3s0f0",
"rx 1518575 pkts/ on interface enp3s0f0",
"rx 1528617 pkts/ on interface enp3s0f0",
"rx 1634802 pkts/ on interface enp3s0f0",
"rx 1590900 pkts/ on interface enp3s0f0",
"rx 1562523 pkts/ on interface enp3s0f0",
"rx 1632285 pkts/ on interface enp3s0f0",
"rx 1564495 pkts/ on interface enp3s0f0",
"rx 1536067 pkts/ on interface enp3s0f0",
"rx 1524926 pkts/ on interface enp3s0f0",
"rx 1518604 pkts/ on interface enp3s0f0",
"rx 1546349 pkts/ on interface enp3s0f0",
"rx 1590728 pkts/ on interface enp3s0f0",
"rx 1586877 pkts/ on interface enp3s0f0",
]


rate_15 = 8864267

list_15 = [
    
"tx 1526536 pkts/ on interface enp3s0f0",
"tx 1618694 pkts/ on interface enp3s0f0",
"tx 1526633 pkts/ on interface enp3s0f0",
"tx 1561812 pkts/ on interface enp3s0f0",
"tx 1664943 pkts/ on interface enp3s0f0",
"tx 1594830 pkts/ on interface enp3s0f0",
"tx 1634342 pkts/ on interface enp3s0f0",
"tx 1507278 pkts/ on interface enp3s0f0",
"tx 1596329 pkts/ on interface enp3s0f0",
"tx 1580361 pkts/ on interface enp3s0f0",
"tx 1571105 pkts/ on interface enp3s0f0",
"tx 1557839 pkts/ on interface enp3s0f0",
"tx 1561501 pkts/ on interface enp3s0f0",
"tx 1571199 pkts/ on interface enp3s0f0",
"tx 1556406 pkts/ on interface enp3s0f0",
"tx 1553484 pkts/ on interface enp3s0f0",
"tx 1610077 pkts/ on interface enp3s0f0",
    
"rx 1608986 pkts/ on interface enp3s0f0",
"rx 1554779 pkts/ on interface enp3s0f0",
"rx 1542080 pkts/ on interface enp3s0f0",
"rx 1678862 pkts/ on interface enp3s0f0",
"rx 1518502 pkts/ on interface enp3s0f0",
"rx 1564100 pkts/ on interface enp3s0f0",
"rx 1541933 pkts/ on interface enp3s0f0",
"rx 1482491 pkts/ on interface enp3s0f0",
"rx 1606430 pkts/ on interface enp3s0f0",
"rx 1530662 pkts/ on interface enp3s0f0",
"rx 1519314 pkts/ on interface enp3s0f0",
"rx 1550231 pkts/ on interface enp3s0f0",
"rx 1548504 pkts/ on interface enp3s0f0",
"rx 1502529 pkts/ on interface enp3s0f0",
"rx 1593031 pkts/ on interface enp3s0f0",
"rx 1576349 pkts/ on interface enp3s0f0",
"rx 1565649 pkts/ on interface enp3s0f0",
"rx 1576866 pkts/ on interface enp3s0f0",
"rx 1642404 pkts/ on interface enp3s0f0",
    
]

rate_30 = 16114556
list_30 = [
    
"tx 1554139 pkts/ on interface enp3s0f0",
"tx 1594216 pkts/ on interface enp3s0f0",
"tx 1660988 pkts/ on interface enp3s0f0",
"tx 1585905 pkts/ on interface enp3s0f0",
"tx 1526305 pkts/ on interface enp3s0f0",
"tx 1637479 pkts/ on interface enp3s0f0",
"tx 1634506 pkts/ on interface enp3s0f0",
"tx 1553205 pkts/ on interface enp3s0f0",
"tx 1612375 pkts/ on interface enp3s0f0",
"tx 1567627 pkts/ on interface enp3s0f0",
"tx 1653396 pkts/ on interface enp3s0f0",
"tx 1591758 pkts/ on interface enp3s0f0",
"tx 1597478 pkts/ on interface enp3s0f0",
"tx 1570150 pkts/ on interface enp3s0f0",
"tx 1577292 pkts/ on interface enp3s0f0",
"tx 1558782 pkts/ on interface enp3s0f0",
"tx 1586917 pkts/ on interface enp3s0f0",
"tx 1562195 pkts/ on interface enp3s0f0",
"tx 1622177 pkts/ on interface enp3s0f0",
"tx 1585607 pkts/ on interface enp3s0f0",
"tx 1564935 pkts/ on interface enp3s0f0",
"tx 1502996 pkts/ on interface enp3s0f0",
"tx 1547970 pkts/ on interface enp3s0f0",
    
"rx 1574344 pkts/ on interface enp3s0f0",
"rx 1600545 pkts/ on interface enp3s0f0",
"rx 1565426 pkts/ on interface enp3s0f0",
"rx 1590006 pkts/ on interface enp3s0f0",
"rx 1629701 pkts/ on interface enp3s0f0",
"rx 1618269 pkts/ on interface enp3s0f0",
"rx 1542850 pkts/ on interface enp3s0f0",
"rx 1554164 pkts/ on interface enp3s0f0",
"rx 1601321 pkts/ on interface enp3s0f0",
"rx 1593698 pkts/ on interface enp3s0f0",
"rx 1606843 pkts/ on interface enp3s0f0",
"rx 1513382 pkts/ on interface enp3s0f0",
"rx 1588820 pkts/ on interface enp3s0f0",
"rx 1587454 pkts/ on interface enp3s0f0",
"rx 1574762 pkts/ on interface enp3s0f0",
"rx 1627695 pkts/ on interface enp3s0f0",
"rx 1576283 pkts/ on interface enp3s0f0",
"rx 1583328 pkts/ on interface enp3s0f0",
"rx 1597247 pkts/ on interface enp3s0f0",
"rx 1614645 pkts/ on interface enp3s0f0",
]

rate_40 = 16139066
list_40 = [
"tx 1552275 pkts/ on interface enp3s0f0",
"tx 1554194 pkts/ on interface enp3s0f0",
"tx 1563061 pkts/ on interface enp3s0f0",
"tx 1619619 pkts/ on interface enp3s0f0",
"tx 1532569 pkts/ on interface enp3s0f0",
"tx 1597163 pkts/ on interface enp3s0f0",
"tx 1596079 pkts/ on interface enp3s0f0",
"tx 1609515 pkts/ on interface enp3s0f0",
"tx 1586411 pkts/ on interface enp3s0f0",
"tx 1581570 pkts/ on interface enp3s0f0",
"tx 1518603 pkts/ on interface enp3s0f0",
"tx 1524915 pkts/ on interface enp3s0f0",
"tx 1632051 pkts/ on interface enp3s0f0",
"tx 1581017 pkts/ on interface enp3s0f0",
"tx 1605391 pkts/ on interface enp3s0f0",
"tx 1524082 pkts/ on interface enp3s0f0",
    
"rx 1593268 pkts/ on interface enp3s0f0",
"rx 1526137 pkts/ on interface enp3s0f0",
"rx 1613189 pkts/ on interface enp3s0f0",
"rx 1610948 pkts/ on interface enp3s0f0",
"rx 1597513 pkts/ on interface enp3s0f0",
"rx 1571557 pkts/ on interface enp3s0f0",
"rx 1570513 pkts/ on interface enp3s0f0",
"rx 1527645 pkts/ on interface enp3s0f0",
"rx 1541859 pkts/ on interface enp3s0f0",
"rx 1632630 pkts/ on interface enp3s0f0",
"rx 1647954 pkts/ on interface enp3s0f0",
"rx 1478965 pkts/ on interface enp3s0f0",
"rx 1548092 pkts/ on interface enp3s0f0",
"rx 1586765 pkts/ on interface enp3s0f0",
"rx 1611707 pkts/ on interface enp3s0f0",
"rx 1589535 pkts/ on interface enp3s0f0",
"rx 1482970 pkts/ on interface enp3s0f0",
"rx 1542865 pkts/ on interface enp3s0f0",
"rx 1568865 pkts/ on interface enp3s0f0",
"rx 1545469 pkts/ on interface enp3s0f0",
    
]

# %%
list_name = [list_0_5, list_1, list_1_5, list_2, list_2_5, list_2_75, list_3, list_3_5, list_4, list_5,
            list_7, list_10, list_15, list_30, list_40]
send_rate = [rate_0_5, rate_1, rate_1_5, rate_2, rate_2_5, rate_2_75, rate_3, rate_3_5, rate_4, rate_5,
            rate_7, rate_10, rate_15, rate_30, rate_40]
return_rate = [] 

#change name of list to get the average from that list 

for list in list_name: 
    sum = 0
    count = 0 
    for i in list:
        #print(i[3:10])
        sum += int(i[3:10])
        count+=1
    avg = sum/count
    return_rate.append(avg)
    #print(sum, count, avg)
print(return_rate)
# Out:
# [299366.0, 599619.7931034482, 900027.0, 1203316.8, 1489708.3870967743, 1496252.4, 1585565.6666666667, 1585788.3243243243, 1582613.7, 1571155.3870967743, 1557487.5, 1566901.1951219512, 1569363.0833333333, 1585794.9069767443, 1571304.4722222222]

# %%
# SYN flood to measure XDP cookie generation 



xdp_rate_1 = 595200
xdp_list_1 = [
    
"rx 597609 pkts/ on interface enp3s0f0",
"rx 598004 pkts/ on interface enp3s0f0",
"rx 597747 pkts/ on interface enp3s0f0",
"rx 597369 pkts/ on interface enp3s0f0",
"rx 597695 pkts/ on interface enp3s0f0",
"rx 597597 pkts/ on interface enp3s0f0",
"rx 598309 pkts/ on interface enp3s0f0",
"rx 597544 pkts/ on interface enp3s0f0",
"rx 597487 pkts/ on interface enp3s0f0",
"rx 597620 pkts/ on interface enp3s0f0",
"rx 597885 pkts/ on interface enp3s0f0",
"rx 597710 pkts/ on interface enp3s0f0",
"rx 598802 pkts/ on interface enp3s0f0",
"rx 597896 pkts/ on interface enp3s0f0",
"rx 598757 pkts/ on interface enp3s0f0",
"rx 597420 pkts/ on interface enp3s0f0",
    
"tx 598446 pkts/ on interface enp3s0f0",
"tx 597389 pkts/ on interface enp3s0f0",
"tx 597440 pkts/ on interface enp3s0f0",
"tx 597375 pkts/ on interface enp3s0f0",
"tx 597485 pkts/ on interface enp3s0f0",
"tx 597791 pkts/ on interface enp3s0f0",
"tx 597694 pkts/ on interface enp3s0f0",
"tx 597572 pkts/ on interface enp3s0f0",
"tx 599161 pkts/ on interface enp3s0f0",
"tx 598818 pkts/ on interface enp3s0f0",
"tx 597526 pkts/ on interface enp3s0f0",
"tx 597136 pkts/ on interface enp3s0f0",
"tx 597367 pkts/ on interface enp3s0f0",
"tx 597045 pkts/ on interface enp3s0f0",
"tx 597438 pkts/ on interface enp3s0f0",
"tx 598333 pkts/ on interface enp3s0f0",

    
]



xdp_rate_2_5 = 1485928
xdp_list_2_5 = [

"rx 1491899 pkts/ on interface enp3s0f0",
"rx 1491542 pkts/ on interface enp3s0f0",
"rx 1491828 pkts/ on interface enp3s0f0",
"rx 1495965 pkts/ on interface enp3s0f0",
"rx 1492512 pkts/ on interface enp3s0f0",
"rx 1492213 pkts/ on interface enp3s0f0",
"rx 1497259 pkts/ on interface enp3s0f0",
"rx 1493885 pkts/ on interface enp3s0f0",
"rx 1493789 pkts/ on interface enp3s0f0",
"rx 1492996 pkts/ on interface enp3s0f0",
"rx 1492376 pkts/ on interface enp3s0f0",
"rx 1493749 pkts/ on interface enp3s0f0",
"rx 1492508 pkts/ on interface enp3s0f0",
"rx 1493027 pkts/ on interface enp3s0f0",
"rx 1493900 pkts/ on interface enp3s0f0",
    
"tx 1492552 pkts/ on interface enp3s0f0",
"tx 1494563 pkts/ on interface enp3s0f0",
"tx 1493204 pkts/ on interface enp3s0f0",
"tx 1493053 pkts/ on interface enp3s0f0",
"tx 1494865 pkts/ on interface enp3s0f0",
"tx 1492187 pkts/ on interface enp3s0f0",
"tx 1492851 pkts/ on interface enp3s0f0",
"tx 1492415 pkts/ on interface enp3s0f0",
"tx 1492257 pkts/ on interface enp3s0f0",
"tx 1493106 pkts/ on interface enp3s0f0",
"tx 1495753 pkts/ on interface enp3s0f0",
"tx 1491521 pkts/ on interface enp3s0f0",
"tx 1494294 pkts/ on interface enp3s0f0",
"tx 1494499 pkts/ on interface enp3s0f0",
"tx 1492532 pkts/ on interface enp3s0f0",

    
]



xdp_rate_5 = 2969778
xdp_list_5 = [
    
"rx 2989455 pkts/ on interface enp3s0f0",
"rx 2984188 pkts/ on interface enp3s0f0",
"rx 2988955 pkts/ on interface enp3s0f0",
"rx 2985616 pkts/ on interface enp3s0f0",
"rx 2987066 pkts/ on interface enp3s0f0",
"rx 2983528 pkts/ on interface enp3s0f0",
"rx 2987013 pkts/ on interface enp3s0f0",
"rx 2981280 pkts/ on interface enp3s0f0",
"rx 2993237 pkts/ on interface enp3s0f0",
"rx 2983389 pkts/ on interface enp3s0f0",
"rx 2983322 pkts/ on interface enp3s0f0",
"rx 2985636 pkts/ on interface enp3s0f0",
"rx 2991294 pkts/ on interface enp3s0f0",
"rx 2985118 pkts/ on interface enp3s0f0",
    
"tx 2989222 pkts/ on interface enp3s0f0",
"tx 2987270 pkts/ on interface enp3s0f0",
"tx 2986816 pkts/ on interface enp3s0f0",
"tx 2980845 pkts/ on interface enp3s0f0",
"tx 2989022 pkts/ on interface enp3s0f0",
"tx 2984737 pkts/ on interface enp3s0f0",
"tx 2982803 pkts/ on interface enp3s0f0",
"tx 2985062 pkts/ on interface enp3s0f0",
"tx 2983487 pkts/ on interface enp3s0f0",
"tx 2981759 pkts/ on interface enp3s0f0",
"tx 2989835 pkts/ on interface enp3s0f0",
"tx 2992948 pkts/ on interface enp3s0f0",
"tx 2982905 pkts/ on interface enp3s0f0",
"tx 2986651 pkts/ on interface enp3s0f0",
"tx 2989942 pkts/ on interface enp3s0f0",
"tx 2984822 pkts/ on interface enp3s0f0",

]



xdp_rate_10 = 6022024
xdp_list_10 = [
    
"rx 5600701 pkts/ on interface enp3s0f0",
"rx 5616297 pkts/ on interface enp3s0f0",
"rx 5484930 pkts/ on interface enp3s0f0",
"rx 5578638 pkts/ on interface enp3s0f0",
"rx 5619841 pkts/ on interface enp3s0f0",
"rx 5695863 pkts/ on interface enp3s0f0",
"rx 5679993 pkts/ on interface enp3s0f0",
"rx 5648366 pkts/ on interface enp3s0f0",
"rx 5844314 pkts/ on interface enp3s0f0",
"rx 5634128 pkts/ on interface enp3s0f0",
"rx 5724672 pkts/ on interface enp3s0f0",
"rx 5572997 pkts/ on interface enp3s0f0",
"rx 5590257 pkts/ on interface enp3s0f0",

"tx 5695121 pkts/ on interface enp3s0f0",
"tx 5598749 pkts/ on interface enp3s0f0",
"tx 5704942 pkts/ on interface enp3s0f0",
"tx 5690312 pkts/ on interface enp3s0f0",
"tx 5584006 pkts/ on interface enp3s0f0",
"tx 5640345 pkts/ on interface enp3s0f0",
"tx 5585610 pkts/ on interface enp3s0f0",
"tx 5550356 pkts/ on interface enp3s0f0",
"tx 5614912 pkts/ on interface enp3s0f0",
"tx 5627775 pkts/ on interface enp3s0f0",
"tx 5584730 pkts/ on interface enp3s0f0",
]



xdp_rate_15 = 9004095
xdp_list_15 = [
    
"rx 6749819 pkts/ on interface enp3s0f0",
"rx 6906311 pkts/ on interface enp3s0f0",
"rx 6930686 pkts/ on interface enp3s0f0",
"rx 7383372 pkts/ on interface enp3s0f0",
"rx 6937214 pkts/ on interface enp3s0f0",
"rx 6693550 pkts/ on interface enp3s0f0",
"rx 7627911 pkts/ on interface enp3s0f0",
"rx 7062927 pkts/ on interface enp3s0f0",
"rx 7374680 pkts/ on interface enp3s0f0",
"rx 7016830 pkts/ on interface enp3s0f0",
"rx 7223054 pkts/ on interface enp3s0f0",
"rx 7321438 pkts/ on interface enp3s0f0",
"rx 6994324 pkts/ on interface enp3s0f0",
    
"tx 7394891 pkts/ on interface enp3s0f0",
"tx 6940084 pkts/ on interface enp3s0f0",
"tx 6710677 pkts/ on interface enp3s0f0",
"tx 7622251 pkts/ on interface enp3s0f0",
"tx 7080506 pkts/ on interface enp3s0f0",
"tx 7356826 pkts/ on interface enp3s0f0",
"tx 7020313 pkts/ on interface enp3s0f0",
"tx 7201517 pkts/ on interface enp3s0f0",
"tx 7306505 pkts/ on interface enp3s0f0",
"tx 6980279 pkts/ on interface enp3s0f0",
"tx 6938718 pkts/ on interface enp3s0f0",
"tx 7093006 pkts/ on interface enp3s0f0",
"tx 7165286 pkts/ on interface enp3s0f0",
"tx 7321004 pkts/ on interface enp3s0f0",
"tx 7318520 pkts/ on interface enp3s0f0",
"tx 7532672 pkts/ on interface enp3s0f0",
    
]





xdp_rate_20 = 11918423
xdp_list_20 = [
    
"rx 6936360 pkts/ on interface enp3s0f0",
"rx 7654614 pkts/ on interface enp3s0f0",
"rx 7388190 pkts/ on interface enp3s0f0",
"rx 8420262 pkts/ on interface enp3s0f0",
"rx 7194450 pkts/ on interface enp3s0f0",
"rx 7703238 pkts/ on interface enp3s0f0",
"rx 7425801 pkts/ on interface enp3s0f0",
"rx 7291147 pkts/ on interface enp3s0f0",
"rx 7143779 pkts/ on interface enp3s0f0",
"rx 7045176 pkts/ on interface enp3s0f0",
"rx 7129277 pkts/ on interface enp3s0f0",
"rx 7249576 pkts/ on interface enp3s0f0",
"rx 6770545 pkts/ on interface enp3s0f0",
"rx 7101211 pkts/ on interface enp3s0f0",

"tx 6988438 pkts/ on interface enp3s0f0",
"tx 7139885 pkts/ on interface enp3s0f0",
"tx 8632901 pkts/ on interface enp3s0f0",
"tx 7093222 pkts/ on interface enp3s0f0",
"tx 7507153 pkts/ on interface enp3s0f0",
"tx 7684054 pkts/ on interface enp3s0f0",
"tx 7722314 pkts/ on interface enp3s0f0",
"tx 8683048 pkts/ on interface enp3s0f0",
"tx 7171372 pkts/ on interface enp3s0f0",
"tx 7561928 pkts/ on interface enp3s0f0",
"tx 7376543 pkts/ on interface enp3s0f0",
"tx 7538354 pkts/ on interface enp3s0f0",
"tx 6942608 pkts/ on interface enp3s0f0",
"tx 7594599 pkts/ on interface enp3s0f0",
    
]



xdp_rate_30 = 16146866
xdp_list_30 = [
    
"rx 7302699 pkts/ on interface enp3s0f0",
"rx 6885803 pkts/ on interface enp3s0f0",
"rx 8312175 pkts/ on interface enp3s0f0",
"rx 7047225 pkts/ on interface enp3s0f0",
"rx 6511438 pkts/ on interface enp3s0f0",
"rx 7208180 pkts/ on interface enp3s0f0",
"rx 7046823 pkts/ on interface enp3s0f0",
"rx 7913469 pkts/ on interface enp3s0f0",
"rx 7012386 pkts/ on interface enp3s0f0",
"rx 7198946 pkts/ on interface enp3s0f0",
"rx 7855659 pkts/ on interface enp3s0f0",
"rx 7097045 pkts/ on interface enp3s0f0",
"rx 6896445 pkts/ on interface enp3s0f0",
"rx 6873356 pkts/ on interface enp3s0f0",
"rx 7642004 pkts/ on interface enp3s0f0",
    
"tx 7375221 pkts/ on interface enp3s0f0",
"tx 7775179 pkts/ on interface enp3s0f0",
"tx 7339840 pkts/ on interface enp3s0f0",
"tx 7415373 pkts/ on interface enp3s0f0",
"tx 8480788 pkts/ on interface enp3s0f0",
"tx 7245861 pkts/ on interface enp3s0f0",
"tx 7235207 pkts/ on interface enp3s0f0",
"tx 6835151 pkts/ on interface enp3s0f0",
"tx 7417391 pkts/ on interface enp3s0f0",
"tx 7428017 pkts/ on interface enp3s0f0",
"tx 6973997 pkts/ on interface enp3s0f0",
"tx 7173508 pkts/ on interface enp3s0f0",
"tx 7554487 pkts/ on interface enp3s0f0",
"tx 7102191 pkts/ on interface enp3s0f0",
"tx 7608104 pkts/ on interface enp3s0f0",
]



xdp_rate_50 = 16083654
xdp_list_50 = [
    
"rx 7989633 pkts/ on interface enp3s0f0",
"rx 7099972 pkts/ on interface enp3s0f0",
"rx 7302699 pkts/ on interface enp3s0f0",
"rx 6885803 pkts/ on interface enp3s0f0",
"rx 8312175 pkts/ on interface enp3s0f0",
"rx 7047225 pkts/ on interface enp3s0f0",
"rx 6511438 pkts/ on interface enp3s0f0",
"rx 7208180 pkts/ on interface enp3s0f0",
"rx 7046823 pkts/ on interface enp3s0f0",
"rx 7913469 pkts/ on interface enp3s0f0",
"rx 7012386 pkts/ on interface enp3s0f0",
"rx 7198946 pkts/ on interface enp3s0f0",
"rx 7855659 pkts/ on interface enp3s0f0",
"rx 7097045 pkts/ on interface enp3s0f0",
"rx 6896445 pkts/ on interface enp3s0f0",
"rx 6873356 pkts/ on interface enp3s0f0",
    
"tx 7059057 pkts/ on interface enp3s0f0",
"tx 7898029 pkts/ on interface enp3s0f0",
"tx 7018227 pkts/ on interface enp3s0f0",
"tx 7167296 pkts/ on interface enp3s0f0",
"tx 7853788 pkts/ on interface enp3s0f0",
"tx 7092204 pkts/ on interface enp3s0f0",
"tx 6937983 pkts/ on interface enp3s0f0",
"tx 6897462 pkts/ on interface enp3s0f0",
"tx 7619761 pkts/ on interface enp3s0f0",
"tx 7057793 pkts/ on interface enp3s0f0",
"tx 8380508 pkts/ on interface enp3s0f0",
"tx 7288150 pkts/ on interface enp3s0f0",
"tx 7085018 pkts/ on interface enp3s0f0",
"tx 7457658 pkts/ on interface enp3s0f0",
"tx 7328700 pkts/ on interface enp3s0f0",
]


xdp_rate_70 = 16081012
xdp_list_70 = [
    
"rx 6960574 pkts/ on interface enp3s0f0",
"rx 7249340 pkts/ on interface enp3s0f0",
"rx 7092387 pkts/ on interface enp3s0f0",
"rx 7155328 pkts/ on interface enp3s0f0",
"rx 7853090 pkts/ on interface enp3s0f0",
"rx 7063064 pkts/ on interface enp3s0f0",
"rx 7460043 pkts/ on interface enp3s0f0",
"rx 8020108 pkts/ on interface enp3s0f0",
"rx 7444919 pkts/ on interface enp3s0f0",
"rx 6971062 pkts/ on interface enp3s0f0",
"rx 8104480 pkts/ on interface enp3s0f0",
"rx 6768093 pkts/ on interface enp3s0f0",
"rx 7232191 pkts/ on interface enp3s0f0",

"tx 7843323 pkts/ on interface enp3s0f0",
"tx 7094758 pkts/ on interface enp3s0f0",
"tx 7470820 pkts/ on interface enp3s0f0",
"tx 8047826 pkts/ on interface enp3s0f0",
"tx 7417280 pkts/ on interface enp3s0f0",
"tx 6957908 pkts/ on interface enp3s0f0",
"tx 8091205 pkts/ on interface enp3s0f0",
"tx 6742630 pkts/ on interface enp3s0f0",
"tx 7199647 pkts/ on interface enp3s0f0",
"tx 8798818 pkts/ on interface enp3s0f0",
"tx 8386335 pkts/ on interface enp3s0f0",
"tx 8419319 pkts/ on interface enp3s0f0",
"tx 7014992 pkts/ on interface enp3s0f0",
"tx 6845096 pkts/ on interface enp3s0f0",
"tx 7362382 pkts/ on interface enp3s0f0",

    
]

#TODO add rate between 70 and 80 

xdp_rate_80 = 16309990
xdp_list_80 = [
"rx 8771310 pkts/ on interface enp3s0f0",
"rx 7172951 pkts/ on interface enp3s0f0",
"rx 8151994 pkts/ on interface enp3s0f0",
"rx 7931122 pkts/ on interface enp3s0f0",
"rx 7634031 pkts/ on interface enp3s0f0",
"rx 7299849 pkts/ on interface enp3s0f0",
"rx 8059641 pkts/ on interface enp3s0f0",
"rx 7191635 pkts/ on interface enp3s0f0",
"rx 7299799 pkts/ on interface enp3s0f0",
"rx 6923523 pkts/ on interface enp3s0f0",
"rx 7434034 pkts/ on interface enp3s0f0",
"rx 7134908 pkts/ on interface enp3s0f0",
"rx 7241472 pkts/ on interface enp3s0f0",
"rx 8063567 pkts/ on interface enp3s0f0",
"rx 6622130 pkts/ on interface enp3s0f0",
    
"tx 8117174 pkts/ on interface enp3s0f0",
"tx 7208381 pkts/ on interface enp3s0f0",
"tx 7308629 pkts/ on interface enp3s0f0",
"tx 6906170 pkts/ on interface enp3s0f0",
"tx 7429731 pkts/ on interface enp3s0f0",
"tx 7134274 pkts/ on interface enp3s0f0",
"tx 7238324 pkts/ on interface enp3s0f0",
"tx 8051687 pkts/ on interface enp3s0f0",
"tx 6616843 pkts/ on interface enp3s0f0",
"tx 7272777 pkts/ on interface enp3s0f0",
"tx 8086706 pkts/ on interface enp3s0f0",
"tx 7191148 pkts/ on interface enp3s0f0",
"tx 7024864 pkts/ on interface enp3s0f0",
"tx 7316099 pkts/ on interface enp3s0f0",
"tx 7427814 pkts/ on interface enp3s0f0",
"tx 8247348 pkts/ on interface enp3s0f0",
    
]


xdp_rate_90 = 16337447
xdp_list_90 = [

"rx 8103409 pkts/ on interface enp3s0f0",
"rx 7942637 pkts/ on interface enp3s0f0",
"rx 7063296 pkts/ on interface enp3s0f0",
"rx 7172751 pkts/ on interface enp3s0f0",
"rx 7234283 pkts/ on interface enp3s0f0",
"rx 6844994 pkts/ on interface enp3s0f0",
"rx 7661835 pkts/ on interface enp3s0f0",
"rx 8057774 pkts/ on interface enp3s0f0",
"rx 7968928 pkts/ on interface enp3s0f0",
"rx 7232062 pkts/ on interface enp3s0f0",
"rx 7296345 pkts/ on interface enp3s0f0",
"rx 7825878 pkts/ on interface enp3s0f0",
"rx 7359654 pkts/ on interface enp3s0f0",
"rx 7099450 pkts/ on interface enp3s0f0",
"rx 7815094 pkts/ on interface enp3s0f0",
    
"tx 7236134 pkts/ on interface enp3s0f0",
"tx 7301489 pkts/ on interface enp3s0f0",
"tx 7869785 pkts/ on interface enp3s0f0",
"tx 7371738 pkts/ on interface enp3s0f0",
"tx 7100206 pkts/ on interface enp3s0f0",
"tx 7817003 pkts/ on interface enp3s0f0",
"tx 7427935 pkts/ on interface enp3s0f0",
"tx 7067592 pkts/ on interface enp3s0f0",
"tx 8219733 pkts/ on interface enp3s0f0",
"tx 8028126 pkts/ on interface enp3s0f0",
"tx 7488610 pkts/ on interface enp3s0f0",
"tx 7248386 pkts/ on interface enp3s0f0",
"tx 7021218 pkts/ on interface enp3s0f0",
"tx 8791863 pkts/ on interface enp3s0f0",
    
]

xdp_rate_100 = 16079588
xdp_list_100 = [

"rx 7129969 pkts/ on interface enp3s0f0",
"rx 7009854 pkts/ on interface enp3s0f0",
"rx 7074609 pkts/ on interface enp3s0f0",
"rx 6699286 pkts/ on interface enp3s0f0",
"rx 7014620 pkts/ on interface enp3s0f0",
"rx 7734591 pkts/ on interface enp3s0f0",
"rx 7148943 pkts/ on interface enp3s0f0",
"rx 8967282 pkts/ on interface enp3s0f0",
"rx 7104064 pkts/ on interface enp3s0f0",
"rx 7130540 pkts/ on interface enp3s0f0",
"rx 7187141 pkts/ on interface enp3s0f0",
"rx 7798225 pkts/ on interface enp3s0f0",
"rx 7322718 pkts/ on interface enp3s0f0",
"rx 7409494 pkts/ on interface enp3s0f0",
"rx 7829988 pkts/ on interface enp3s0f0",
"rx 6732151 pkts/ on interface enp3s0f0",
"rx 7318384 pkts/ on interface enp3s0f0",
    
"tx 7224583 pkts/ on interface enp3s0f0",
"tx 7774074 pkts/ on interface enp3s0f0",
"tx 7319485 pkts/ on interface enp3s0f0",
"tx 7431131 pkts/ on interface enp3s0f0",
"tx 7846900 pkts/ on interface enp3s0f0",
"tx 6705684 pkts/ on interface enp3s0f0",
"tx 7324748 pkts/ on interface enp3s0f0",
"tx 6509651 pkts/ on interface enp3s0f0",
"tx 7328940 pkts/ on interface enp3s0f0",
"tx 6927865 pkts/ on interface enp3s0f0",
"tx 7131710 pkts/ on interface enp3s0f0",
"tx 7376397 pkts/ on interface enp3s0f0",
"tx 7140173 pkts/ on interface enp3s0f0",
"tx 7410980 pkts/ on interface enp3s0f0",
"tx 7923266 pkts/ on interface enp3s0f0",
    
]

# %%
#xdp_list_name = [xdp_list_1, xdp_list_2_5, xdp_list_5, xdp_list_10, xdp_list_15, xdp_list_20, 
                 #xdp_list_30, xdp_list_50, xdp_list_70, xdp_list_80, xdp_list_90, xdp_list_100]
#xdp_send_rate = [xdp_rate_1, xdp_rate_2_5, xdp_rate_5, xdp_rate_10, xdp_rate_15, xdp_rate_20, 
                 #xdp_rate_30, xdp_rate_50, xdp_rate_70, xdp_rate_80, xdp_rate_90, xdp_rate_100]

xdp_list_name = [xdp_list_1, xdp_list_2_5, xdp_list_5, xdp_list_10, xdp_list_15, xdp_list_20, 
                 xdp_list_30, xdp_list_50, xdp_list_100]
xdp_send_rate = [xdp_rate_1, xdp_rate_2_5, xdp_rate_5, xdp_rate_10, xdp_rate_15, xdp_rate_20, 
                 xdp_rate_30, xdp_rate_50, xdp_rate_100]

xdp_return_rate = [] 

#change name of list to get the average from that list 

for list in xdp_list_name: 
    sum = 0
    count = 0 
    for i in list:
        #print(i[3:10])
        sum += int(i[3:10])
        count+=1
    avg = sum/count
    xdp_return_rate.append(avg)
    #print(sum, count, avg)
print(xdp_return_rate)
# Out:
# [597795.84375, 1493303.3333333333, 2986240.7666666666, 5631993.958333333, 7145005.8965517245, 7431787.321428572, 7325465.6, 7302996.387096774, 7312107.6875]

# %%
# Baseline Vanilla Cookie
#jc4 send rate, single sender
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 



b_raw_data = [
    
#rate 1
"Pipe3| RX RATE    1.18Mpps     799Mbps| TX RATE    1.18Mpps     856Mbps"
    
#rate 10 
    
"Pipe3| RX RATE    7.46Mpps    5021Mbps| TX RATE    7.46Mpps    5591Mbps",
    
#rate 15 
    
"Pipe3| RX RATE   10.34Mpps    6951Mbps| TX RATE   10.34Mpps    7800Mbps",
    
#rate 20 
"Pipe3| RX RATE   13.27Mpps    8927Mbps| TX RATE   13.27Mpps   10061Mbps",     
#rate 25          
"Pipe3| RX RATE   14.94Mpps   10049Mbps| TX RATE   14.00Mpps   10617Mbps",
#rate 26          
"Pipe3| RX RATE   16.82Mpps   11308Mbps| TX RATE   14.55Mpps   11029Mbps",
    
#rate 27
"Pipe3| RX RATE   17.31Mpps   11637Mbps| TX RATE   14.49Mpps   10990Mbps",
#rate 28          
"Pipe3| RX RATE   17.89Mpps   12031Mbps| TX RATE   14.54Mpps   11024Mbps",
#rate 29          
"Pipe3| RX RATE   18.41Mpps   12375Mbps| TX RATE   14.52Mpps   11008Mbps",
#rate 30  
"Pipe3| RX RATE   18.72Mpps   12586Mbps| TX RATE   14.53Mpps   11016Mbps",
    
    
#rate 31

"Pipe3| RX RATE   18.74Mpps   12602Mbps| TX RATE   14.50Mpps   11000Mbps",
#rate 32
"Pipe3| RX RATE   18.84Mpps   12666Mbps| TX RATE   14.55Mpps   11038Mbps",
#rate 35
"Pipe3| RX RATE   18.87Mpps   12692Mbps| TX RATE   14.49Mpps   10992Mbps",
    
#rate 40
"Pipe3| RX RATE   19.06Mpps   12812Mbps| TX RATE   14.50Mpps   10997Mbps"
#rate 50
"Pipe3| RX RATE   19.38Mpps   13026Mbps| TX RATE   14.50Mpps   10994Mbps",
#rate 60
"Pipe3| RX RATE   19.72Mpps   13256Mbps| TX RATE   14.49Mpps   10987Mbps",
#rate 70
"Pipe3| RX RATE   20.08Mpps   13502Mbps| TX RATE   14.51Mpps   11005Mbps",
#rate 80
"Pipe3| RX RATE   20.40Mpps   13716Mbps| TX RATE   14.47Mpps   10978Mbps",
#rate 90
"Pipe3| RX RATE   20.87Mpps   14031Mbps| TX RATE   14.63Mpps   11085Mbps",
#rate 100
"Pipe3| RX RATE   21.08Mpps   14166Mbps| TX RATE   14.59Mpps   11054Mbps",
    
]

# %%
#Baseline Vanilla Kernel Cookie, rates in Mpps 
b_send_rate = [1]
b_rcv_rate = [1] 



for line in b_raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    b_send_rate.append(float(send_str))
    b_rcv_rate.append(float(rcv_str))
    
print(b_send_rate)
print(b_rcv_rate)
# Out:
# [1, 1.18, 10.34, 13.27, 14.94, 16.82, 17.31, 17.89, 18.41, 18.72, 18.74, 18.84, 18.87, 19.06, 19.72, 20.08, 20.4, 20.87, 21.08]
# [1, 1.18, 10.34, 13.27, 14.0, 14.55, 14.49, 14.54, 14.52, 14.53, 14.5, 14.55, 14.49, 14.5, 14.49, 14.51, 14.47, 14.63, 14.59]

# %%
# XDP Cookie
#jc4 send rate, single sender
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 



xdp_raw_data = [
    
#rate 10 
    
"Pipe3| RX RATE   11.64Mpps    8378Mbps| TX RATE   11.64Mpps    8948Mbps",
    
#rate 15 
    
"Pipe3| RX RATE   15.93Mpps   11392Mbps| TX RATE   15.93Mpps   12246Mbps",
    
#rate 20 
"Pipe3| RX RATE   18.71Mpps   13246Mbps| TX RATE   18.71Mpps   14381Mbps",     
#rate 22  
"Pipe3| RX RATE   19.97Mpps   14091Mbps| TX RATE   19.97Mpps   15337Mbps",
#rate 23  
"Pipe3| RX RATE   20.15Mpps   14176Mbps| TX RATE   19.59Mpps   15053Mbps", 
         
        
#rate 24  
"Pipe3| RX RATE   21.04Mpps   14804Mbps| TX RATE   19.92Mpps   15306Mbps",
#rate 25          
"Pipe3| RX RATE   21.43Mpps   15054Mbps| TX RATE   19.75Mpps   15172Mbps",
#rate 26          
"Pipe3| RX RATE   22.29Mpps   15655Mbps| TX RATE   20.00Mpps   15364Mbps",
    
#rate 27
"Pipe3| RX RATE   22.65Mpps   15876Mbps| TX RATE   19.81Mpps   15216Mbps",
#rate 28          
"Pipe3| RX RATE   23.21Mpps   16261Mbps| TX RATE   19.85Mpps   15252Mbps",
#rate 29          
"Pipe3| RX RATE   23.89Mpps   16729Mbps| TX RATE   19.98Mpps   15347Mbps",
#rate 30  
"Pipe3| RX RATE   24.21Mpps   16942Mbps| TX RATE   19.99Mpps   15356Mbps",
#rate 31
"Pipe3| RX RATE   24.20Mpps   16936Mbps| TX RATE   19.95Mpps   15325Mbps",
#rate 32
"Pipe3| RX RATE   24.17Mpps   16904Mbps| TX RATE   19.87Mpps   15263Mbps",
#rate 35
"Pipe3| RX RATE   24.33Mpps   17022Mbps| TX RATE   19.93Mpps   15310Mbps",
    
#rate 40
"Pipe3| RX RATE   24.41Mpps   17069Mbps| TX RATE   19.86Mpps   15256Mbps"
#rate 50
"Pipe3| RX RATE   24.67Mpps   17237Mbps| TX RATE   19.78Mpps   15195Mbps",
#rate 60
"Pipe3| RX RATE   25.19Mpps   17602Mbps| TX RATE   19.96Mpps   15332Mbps",
#rate 70
"Pipe3| RX RATE   25.34Mpps   17682Mbps| TX RATE   19.77Mpps   15186Mbps",
#rate 80
"Pipe3| RX RATE   26.06Mpps   18197Mbps| TX RATE   20.13Mpps   15461Mbps",
#rate 90
"Pipe3| RX RATE   26.07Mpps   18180Mbps| TX RATE   19.83Mpps   15233Mbps",
#rate 100
"Pipe3| RX RATE   26.45Mpps   18453Mbps| TX RATE   19.97Mpps   15343Mbps",
    
]

# %%
#XDP Cookie, rates in Mpps 
xdp_send_rate = [1]
xdp_rcv_rate = [1] 



for line in xdp_raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    xdp_send_rate.append(float(send_str))
    xdp_rcv_rate.append(float(rcv_str))
    
print(xdp_send_rate)
print(xdp_rcv_rate)
# Out:
# [1, 11.64, 15.93, 18.71, 19.97, 20.15, 21.04, 21.43, 22.29, 22.65, 23.21, 23.89, 24.21, 24.2, 24.17, 24.33, 24.41, 25.19, 25.34, 26.06, 26.07, 26.45]
# [1, 11.64, 15.93, 18.71, 19.97, 19.59, 19.92, 19.75, 20.0, 19.81, 19.85, 19.98, 19.99, 19.95, 19.87, 19.93, 19.86, 19.96, 19.77, 20.13, 19.83, 19.97]

# %%
# SmartCookie Raw Unoptimized 
#cab804 rate and cab801 rate
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 



raw_data = [
    
#rate 10 
    
"Pipe1| RX RATE   29.84Mpps   20058Mbps| TX RATE   29.84Mpps   20057Mbps",
    
#rate 15 
    
"Pipe1| RX RATE   44.76Mpps   30085Mbps| TX RATE   44.57Mpps   29963Mbps",
    
#rate 16     
    
"Pipe1| RX RATE   47.66Mpps   32031Mbps| TX RATE   47.66Mpps   32031Mbps", 
#rate 16.5
"Pipe1| RX RATE   49.25Mpps   33104Mbps| TX RATE   49.25Mpps   33104Mbps",
#rate 17     
"Pipe1| RX RATE   50.95Mpps   34248Mbps| TX RATE   50.95Mpps   34248Mbps",
    
#rate 18  
"Pipe1| RX RATE   53.44Mpps   35922Mbps| TX RATE   53.44Mpps   35921Mbps",
#rate 19 
"Pipe1| RX RATE   56.95Mpps   38275Mbps| TX RATE   52.96Mpps   35595Mbps",
#rate 20 
"Pipe1| RX RATE   60.05Mpps   40360Mbps| TX RATE   56.53Mpps   37992Mbps",
#rate 21  
"Pipe1| RX RATE   62.64Mpps   42099Mbps| TX RATE   57.44Mpps   38605Mbps",         
#rate 22  
"Pipe1| RX RATE   65.43Mpps   43976Mbps| TX RATE   56.60Mpps   38042Mbps",
#rate 23  
"Pipe1| RX RATE   68.52Mpps   46053Mbps| TX RATE   56.58Mpps   38030Mbps", 
         
        
#rate 24  
"Pipe1| RX RATE   71.87Mpps   48300Mbps| TX RATE   55.25Mpps   37138Mbps",
#rate 25          
"Pipe1| RX RATE   74.31Mpps   49942Mbps| TX RATE   54.40Mpps   36562Mbps",
#rate 26          
"Pipe1| RX RATE   78.31Mpps   52626Mbps| TX RATE   53.09Mpps   35681Mbps",
    
#rate 27
"Pipe1| RX RATE   81.20Mpps   54572Mbps| TX RATE   52.06Mpps   34992Mbps",
#rate 28          
"Pipe1| RX RATE   84.30Mpps   56658Mbps| TX RATE   51.03Mpps   34298Mbps",
#rate 29          
"Pipe1| RX RATE   87.66Mpps   58915Mbps| TX RATE   50.34Mpps   33834Mbps",
#rate 30  
"Pipe1| RX RATE   89.46Mpps   60125Mbps| TX RATE   50.10Mpps   33672Mbps"
#rate 70
"Pipe1| RX RATE  198.16Mpps  133172Mbps| TX RATE   35.45Mpps   23829Mbps",
#rate 90
"Pipe1| RX RATE  198.13Mpps  133153Mbps| TX RATE   35.46Mpps   23833Mbps",
#rate 100
"Pipe1| RX RATE  198.13Mpps  133150Mbps| TX RATE   35.45Mpps   23829Mbps",
]

# %%
#rates in Mpps 
sc_send_rate = [1]
sc_rcv_rate = [1] 



for line in raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_send_rate.append(float(send_str))
    sc_rcv_rate.append(float(rcv_str))
    
print(sc_send_rate)
print(sc_rcv_rate)
# Out:
# [1, 29.84, 44.76, 47.66, 49.25, 50.95, 53.44, 56.95, 60.05, 62.64, 65.43, 68.52, 71.87, 74.31, 78.31, 81.2, 84.3, 87.66, 89.46, 198.131, 198.131]
# [1, 29.84, 44.57, 47.66, 49.25, 50.95, 53.44, 52.96, 56.53, 57.44, 56.6, 56.58, 55.25, 54.4, 53.09, 52.06, 51.03, 50.34, 50.1, 35.46, 35.45]

# %%
# SmartCookie Improvement: Explitily Set Port
#cab804 rate and cab801 rate
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 

raw_data_set_port = [
    
#rate 10 
    
"Pipe1| RX RATE   29.84Mpps   20058Mbps| TX RATE   29.84Mpps   20058Mbps",
    
#rate 15 
    
"Pipe1| RX RATE   44.76Mpps   30084Mbps| TX RATE   44.76Mpps   30084Mbps",
    
#rate 16     
    
"Pipe1| RX RATE   47.65Mpps   32033Mbps| TX RATE   47.65Mpps   32033Mbps", 
 
#rate 17     
"Pipe1| RX RATE   50.98Mpps   34267Mbps| TX RATE   50.98Mpps   34267Mbps",
    
#rate 18  
"Pipe1| RX RATE   53.48Mpps   35947Mbps| TX RATE   53.48Mpps   35947Mbps",
#rate 19 
"Pipe1| RX RATE   56.94Mpps   38272Mbps| TX RATE   56.94Mpps   38272Mbps",
#rate 20 
"Pipe1| RX RATE   60.05Mpps   40358Mbps| TX RATE   60.05Mpps   40358Mbps",
#rate 21  
"Pipe1| RX RATE   62.65Mpps   42101Mbps| TX RATE   62.64Mpps   42099Mbps",         
#rate 22  
"Pipe1| RX RATE   65.44Mpps   43983Mbps| TX RATE   65.43Mpps   43975Mbps",
#rate 23  
"Pipe1| RX RATE   68.54Mpps   46061Mbps| TX RATE   68.52Mpps   46053Mbps", 
         
        
#rate 24  
"Pipe1| RX RATE   71.88Mpps   48311Mbps| TX RATE   71.87Mpps   48300Mbps",
#rate 25          
"Pipe1| RX RATE   74.32Mpps   49952Mbps| TX RATE   74.31Mpps   49942Mbps",
#rate 26          
"Pipe1| RX RATE   78.31Mpps   52635Mbps| TX RATE   78.31Mpps   52625Mbps",
    
#rate 27
"Pipe1| RX RATE   81.22Mpps   54583Mbps| TX RATE   81.20Mpps   54573Mbps",
#rate 28          
"Pipe1| RX RATE   84.32Mpps   56668Mbps| TX RATE   84.30Mpps   56658Mbps",
#rate 29          
"Pipe1| RX RATE   87.67Mpps   58925Mbps| TX RATE   87.67Mpps   58916Mbps",
#rate 30  
"Pipe1| RX RATE   89.48Mpps   60137Mbps| TX RATE   89.46Mpps   60126Mbps"
    
#rate 40
"Pipe1| RX RATE  121.70Mpps   81787Mbps| TX RATE  121.49Mpps   81645Mbps",
    
#rate 45
"Pipe1| RX RATE  136.93Mpps   92026Mbps| TX RATE  121.04Mpps   81346Mbps",
#rate 48
"Pipe1| RX RATE  146.03Mpps   98141Mbps| TX RATE  119.84Mpps   80540Mbps",
#rate 50
"Pipe1| RX RATE  151.02Mpps  101492Mbps| TX RATE  118.18Mpps   79428Mbps",
#rate 55
"Pipe1| RX RATE  168.46Mpps  113213Mbps| TX RATE  121.99Mpps   81980Mbps",
#rate 60
"Pipe1| RX RATE  182.46Mpps  122619Mbps| TX RATE  121.99Mpps   81980Mbps",
#rate 65
"Pipe1| RX RATE  199.00Mpps  133735Mbps| TX RATE  121.99Mpps   81983Mbps",
#rate 70
"Pipe1| RX RATE  204.48Mpps  137417Mbps| TX RATE  121.99Mpps   81979Mbps",
#rate 80
"Pipe1| RX RATE  208.80Mpps  140320Mbps| TX RATE  121.99Mpps   81980Mbps",
#rate 90
"Pipe1| RX RATE  208.80Mpps  140320Mbps| TX RATE  121.99Mpps   81980Mbps",
#rate 100
"Pipe1| RX RATE  208.86Mpps  140362Mbps| TX RATE  121.98Mpps   81979Mbps",
]

# %%
# SmartCookie Improvement: Explicitly Set Port 

#rates in Mpps 
sc_send_rate_set_port = [1]
sc_rcv_rate_set_port = [1] 



for line in raw_data_set_port:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_send_rate_set_port.append(float(send_str))
    sc_rcv_rate_set_port.append(float(rcv_str))
    
print(sc_send_rate_set_port)
print(sc_rcv_rate_set_port)
# Out:
# [1, 29.84, 44.76, 47.65, 50.98, 53.48, 56.94, 60.05, 62.65, 65.44, 68.54, 71.88, 74.32, 78.31, 81.22, 84.32, 87.67, 89.48, 136.93, 146.03, 151.021, 168.461, 182.461, 199.001, 204.481, 208.801, 208.801, 208.861]
# [1, 29.84, 44.76, 47.65, 50.98, 53.48, 56.94, 60.05, 62.64, 65.43, 68.52, 71.87, 74.31, 78.31, 81.2, 84.3, 87.67, 89.46, 121.04, 119.84, 118.18, 121.99, 121.99, 121.99, 121.99, 121.99, 121.99, 121.98]

# %%
# SmartCookie Improvement: Randomly Choose Port 
#cab804 rate and cab801 rate
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 

raw_data_rnd_port = [
    
#rate 10 
    
"Pipe1| RX RATE   28.35Mpps   19056Mbps| TX RATE   28.35Mpps   19056Mbps",
    
#rate 15 
    
"Pipe1| RX RATE   44.76Mpps   30085Mbps| TX RATE   44.76Mpps   30085Mbps",
    
#rate 16     
    
"Pipe1| RX RATE   47.66Mpps   32035Mbps| TX RATE   47.66Mpps   32034Mbps", 
 
#rate 17     
"Pipe1| RX RATE   50.99Mpps   34272Mbps| TX RATE   50.99Mpps   34273Mbps",
    
#rate 18  
"Pipe1| RX RATE   53.48Mpps   35947Mbps| TX RATE   53.48Mpps   35947Mbps",
#rate 19 
"Pipe1| RX RATE   56.94Mpps   38272Mbps| TX RATE   56.94Mpps   38272Mbps",
#rate 20 
"Pipe1| RX RATE   60.05Mpps   40358Mbps| TX RATE   60.05Mpps   40358Mbps",
#rate 21  
"Pipe1| RX RATE   62.65Mpps   42101Mbps| TX RATE   62.64Mpps   42099Mbps",         
#rate 22  
"Pipe1| RX RATE   65.44Mpps   43983Mbps| TX RATE   65.43Mpps   43975Mbps",
#rate 23  
"Pipe1| RX RATE   68.54Mpps   46061Mbps| TX RATE   68.52Mpps   46053Mbps", 
         
        
#rate 24  
"Pipe1| RX RATE   71.88Mpps   48311Mbps| TX RATE   71.87Mpps   48300Mbps",
#rate 25          
"Pipe1| RX RATE   74.32Mpps   49952Mbps| TX RATE   74.31Mpps   49942Mbps",
#rate 26          
"Pipe1| RX RATE   78.31Mpps   52635Mbps| TX RATE   78.31Mpps   52625Mbps",
    
#rate 27
"Pipe1| RX RATE   81.22Mpps   54583Mbps| TX RATE   81.20Mpps   54573Mbps",
#rate 28          
"Pipe1| RX RATE   84.32Mpps   56668Mbps| TX RATE   84.30Mpps   56658Mbps",
#rate 29          
"Pipe1| RX RATE   87.67Mpps   58925Mbps| TX RATE   87.67Mpps   58916Mbps",
#rate 30  
"Pipe1| RX RATE   89.48Mpps   60137Mbps| TX RATE   89.46Mpps   60126Mbps"
#rate 35
"Pipe1| RX RATE  104.38Mpps   70153Mbps| TX RATE  104.37Mpps   70143Mbps",
#rate 40
"Pipe1| RX RATE  121.71Mpps   81792Mbps| TX RATE  121.69Mpps   81782Mbps",
#rate 42
"Pipe1| RX RATE  125.24Mpps   84163Mbps| TX RATE  125.22Mpps   84152Mbps",
#rate 43 
"Pipe1| RX RATE  128.90Mpps   86622Mbps| TX RATE  128.88Mpps   86611Mbps",
#rate 44
"Pipe1| RX RATE  132.76Mpps   89220Mbps| TX RATE  132.74Mpps   89209Mbps"
#rate 45
"Pipe1| RX RATE  136.94Mpps   92031Mbps| TX RATE  134.77Mpps   90571Mbps",
#rate 46
"Pipe1| RX RATE  136.93Mpps   92027Mbps| TX RATE  134.77Mpps   90571Mbps",
#rate 47
"Pipe1| RX RATE  141.35Mpps   94990Mbps| TX RATE  133.04Mpps   89408Mbps",
#rate 48
"Pipe1| RX RATE  146.05Mpps   98151Mbps| TX RATE  131.10Mpps   88106Mbps",
#rate 50
"Pipe1| RX RATE  151.03Mpps  101502Mbps| TX RATE  129.36Mpps   86933Mbps",
#rate 55
"Pipe1| RX RATE  166.34Mpps  111786Mbps| TX RATE  124.38Mpps   83591Mbps",
#rate 60
"Pipe1| RX RATE  182.47Mpps  122623Mbps| TX RATE  120.50Mpps   80979Mbps",
#rate 65
"Pipe1| RX RATE  198.99Mpps  133732Mbps| TX RATE  116.75Mpps   78465Mbps",
#rate 70
"Pipe1| RX RATE  202.20Mpps  135882Mbps| TX RATE   34.93Mpps   23473Mbps",
#rate 80
"Pipe1| RX RATE  203.35Mpps  136653Mbps| TX RATE   34.79Mpps   23390Mbps",
#rate 90
"Pipe1| RX RATE  203.41Mpps  136700Mbps| TX RATE   34.79Mpps   23386Mbps",
#rate 100
"Pipe1| RX RATE  203.27Mpps  136599Mbps| TX RATE   34.80Mpps   23395Mbps",
]

# %%
# SmartCookie Improvement: Randomly Choose Port
#rates in Mpps 
sc_send_rate_rnd_port = [1]
sc_rcv_rate_rnd_port = [1] 



for line in raw_data_rnd_port:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_send_rate_rnd_port.append(float(send_str))
    sc_rcv_rate_rnd_port.append(float(rcv_str))
    
print(sc_send_rate_rnd_port)
print(sc_rcv_rate_rnd_port)
# Out:
# [1, 28.35, 44.76, 47.66, 50.99, 53.48, 56.94, 60.05, 62.65, 65.44, 68.54, 71.88, 74.32, 78.31, 81.22, 84.32, 87.67, 89.48, 121.71, 125.24, 128.9, 132.76, 136.93, 141.35, 146.05, 151.031, 166.341, 182.471, 198.991, 202.201, 203.351, 203.411, 203.271]
# [1, 28.35, 44.76, 47.66, 50.99, 53.48, 56.94, 60.05, 62.64, 65.43, 68.52, 71.87, 74.31, 78.31, 81.2, 84.3, 87.67, 89.46, 121.69, 125.22, 128.88, 132.74, 134.77, 133.04, 131.1, 129.36, 124.38, 120.5, 116.75, 34.93, 34.79, 34.79, 34.8]

# %%
b_send_rate
# Out:
# [1,
#  1.18,
#  10.34,
#  13.27,
#  14.94,
#  16.82,
#  17.31,
#  17.89,
#  18.41,
#  18.72,
#  18.74,
#  18.84,
#  18.87,
#  19.06,
#  19.72,
#  20.08,
#  20.4,
#  20.87,
#  21.08]

# %%
b_return_ratio
# Out:
# array([1.        , 1.        , 1.        , 1.        , 0.93708166,
#        0.89726335, 0.87461369, 0.85523481, 0.83633319, 0.82569186,
#        0.82438017, 0.8220935 , 0.81915331, 0.81360098, 0.79237793,
#        0.78018942, 0.7724482 , 0.76064442, 0.75500945])

# %%
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np


#collecting data with rx_pps.sh and tx_pps.sh

#x-axis
#send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

#y-axis
#return_ratio = np.divide(return_rate, send_rate)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)

#x_base = send_rate_scaled
#y_base = return_ratio

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio

b_return_ratio = np.divide(b_rcv_rate, b_send_rate)
xdp_return_ratio = np.divide(xdp_rcv_rate, xdp_send_rate)
sc_return_ratio = np.divide(sc_rcv_rate, sc_send_rate)
sc_return_ratio_set_port = np.divide(sc_rcv_rate_set_port, sc_send_rate_set_port)
sc_return_ratio_rnd_port = np.divide(sc_rcv_rate_rnd_port, sc_send_rate_rnd_port)





#second iteration of collection with jc4 and synfloodassist and xdp cookies 
x_base = b_send_rate #already in Mpps 
y_base = b_return_ratio 

x_xdp = xdp_send_rate #already in Mpps 
y_xdp = xdp_return_ratio 

x_sc = sc_send_rate #already in Mpps 
y_sc = sc_return_ratio 

x_sc_set_port = sc_send_rate_set_port #already in Mpps 
y_sc_set_port = sc_return_ratio_set_port

x_sc_rnd_port = sc_send_rate_rnd_port #already in Mpps 
y_sc_rnd_port = sc_return_ratio_rnd_port


figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("SYN-ACK Return Ratio (%)")

plt.plot(x_base, y_base, "-r", label="vanilla kernel cookies")
plt.plot(x_xdp, y_xdp, "-k", label="xdp cookies")
plt.plot(x_sc, y_sc, "-g", label="sc defense")
plt.plot(x_sc_set_port, y_sc_set_port, "-m", label="sc defense, set port")
plt.plot(x_sc_rnd_port, y_sc_rnd_port, "-b", label="sc defense, rnd port")




plt.legend(loc="upper right")

plt.show()

# %%
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np

#return_ratio = np.divide(return_rate, send_rate)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)
#send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

#x_base = send_rate_scaled
#y_base = return_ratio

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio



f,(ax,ax2) = plt.subplots(1,2, facecolor='w', sharey=True, figsize=(6, 5), dpi=200)

# plot the same data on both axes
ax.plot(x_base,y_base, "r", linestyle='dashed', label="Vanilla Kernel")
ax.plot(x_xdp, y_xdp, "k", linestyle='dotted', label="XDP")
ax.plot(x_sc,y_sc, "g", linestyle='dashdot')
ax.plot(x_sc_set_port, y_sc_set_port,"m", linestyle='dashed')
ax.plot(x_sc_rnd_port, y_sc_rnd_port,"b", linestyle='dotted')
#ax.legend(loc="upper left")


ax2.plot(x_xdp, y_xdp, "-k")
ax2.plot(x_sc, y_sc, "g", linestyle='dashdot', label="SmartCookie")
ax2.plot(x_sc_set_port, y_sc_set_port,"m", linestyle='dashed', label="SC+SetPort")
ax2.plot(x_sc_rnd_port, y_sc_rnd_port,"b", linestyle='dotted',label="SC+RndPort")
#ax2.legend()

ax.set_xlim(0,40)
ax2.set_xlim(40,250)

#ax.set_ylim(0.4,1)
#ax2.set_ylim(0.4,1)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
#ax.yaxis.tick_left()
ax2.tick_params(labelright='on')
ax2.yaxis.tick_right()

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax.tick_params(labelbottom=True) 
ax.xaxis.tick_bottom()
ax2.xaxis.tick_bottom()


d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)


d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

#x-axis
f.text(0.50, 0.04, 'SYN Flood Attack Rate (Mpps)', ha='center', fontsize='large')
#y-axis
f.text(0.04, 0.55, 'SYN-ACK Return Ratio (%)', va='center', rotation='vertical', fontsize='large')
plt.subplots_adjust(left=0.14, bottom=0.14)

handles_1, labels_1 = ax.get_legend_handles_labels()
f.legend(handles_1, labels_1, loc=(0.15, 0.865))
handles_2, labels_2 = ax2.get_legend_handles_labels()
f.legend(handles_2, labels_2, loc=(0.65, 0.865))

#fig.legend( lines, labels, loc = (0.5, 0), ncol=5 )

plt.savefig('throughput_total.pdf')  


plt.show()

# %% [markdown]
# ###### Plotting DDoS Rate vs. Return Rate
# from matplotlib import pyplot as plt
# import numpy as np
#
# x = send_rate
# y = return_rate
#
# plt.xlabel("SYN Flood Attack Rate (pps)")
# plt.ylabel("SYN-ACK Return Rate (pps) ")
#
# plt.plot(x, y, "-b", label="baseline")
#
# #plt.plot(x, y1, "-b", label="sine")
# #plt.plot(x, y2, "-r", label="cosine")
# plt.legend(loc="upper right")
# #plt.ylim(-1.5, 2.0)
# plt.show()
