# %%
# SMARTCOOKIE LATENCY EXPERIMENT - SYN FLOOD. Cabernet Testbed. 
# SYN flood attack rate for starting FPR of 5.4% with 16,500 injected flows. 
# 100% of attack packets are being processed (cookie checked) and stopped at switch agent. 
# Measure client curl latencies as attack increases. Typical latencies are ~ 7ms. 

sc_syn_flood_rates_cabernet = [

# Cabernet 804 port 1 DPDK attacker. 
    1466880, 
    7351552,
    15164800,
    16189376,
    17552512,
    18053056,
    19726208,
    22211392,
    26441984,
    32484352,
    36739648,   
    42853056,
    46096064,
    50604480,
    57946240,
    62599936,
    67979584,
    74270080,
    79545792,
    85330432,
    89029312,
    92800576,
    95695872,
    97961344,
    98856256,
    101223872,
    103190912,
# Add Cabernet 801 port 1 DPDK attacker. 
# Use set 1 rate 100 on cab804 and tune port 1 rate on cab801. 
    105620000,
    109840000,
    111520000,
    113380000,
    116150000,
    120050000,
    124490000,
    127750000,

# Start to notice some drops here 
    127520000,
    128900000,
    130430000,
    131260000,
    131350000,
    131960000,
    132050000,
    132600000,
    133530000,
    134780000,
    134900000,
    135170000,
    135210000,
    135330000,
    135550000,
    135740000,
    135940000,
    136070000,
    136470000,
    136520000,
    136730000,
    136960000,
    137050000,
    137220000,
    137600000,
    138040000,
    138170000,
    138290000,
    138360000,
    138450000,
    138720000,
    139200000,
    139290000,
    139470000,
    139920000,
    140060000,
    140430000,
    140800000,
    141310000,
    142250000,
    143710000,
    145510000,
    147390000,
    
    150110000,
### Note: the latency measurements figure should end with above measurements. 
### There are plenty of 1 second latencies even from before 140 Mpps. 

    
    167150000,
    212270000,
    
### My attackers maxed out at 212 Mpps. 
]

# %%
# SmartCookie. Some throughput numbers for above experiment. 
# Everything returned until what is listed here. 

Pipe1| RX RATE  127.52Mpps   85699Mbps| TX RATE  127.51Mpps   85693Mbps
Pipe1| RX RATE  128.97Mpps   86674Mbps| TX RATE  128.90Mpps   86629Mbps

Pipe1| RX RATE  130.43Mpps   87655Mbps| TX RATE  130.06Mpps   87408Mbps
Pipe1| RX RATE  131.26Mpps   88213Mbps| TX RATE  131.14Mpps   88138Mbps
Pipe1| RX RATE  131.35Mpps   88273Mbps| TX RATE  131.31Mpps   88245Mbps
Pipe1| RX RATE  131.96Mpps   88684Mbps| TX RATE  131.94Mpps   88668Mbps
Pipe1| RX RATE  132.05Mpps   88740Mbps| TX RATE  131.99Mpps   88705Mbps
Pipe1| RX RATE  132.60Mpps   89115Mbps| TX RATE  132.48Mpps   89031Mbps
Pipe1| RX RATE  133.53Mpps   89742Mbps| TX RATE  133.38Mpps   89636Mbps

Pipe1| RX RATE  134.78Mpps   90580Mbps| TX RATE  133.44Mpps   89673Mbps

Pipe1| RX RATE  134.90Mpps   90659Mbps| TX RATE  134.25Mpps   90224Mbps
Pipe1| RX RATE  135.17Mpps   90840Mbps| TX RATE  133.98Mpps   90042Mbps
Pipe1| RX RATE  135.21Mpps   90869Mbps| TX RATE  134.52Mpps   90405Mbps
Pipe1| RX RATE  135.33Mpps   90944Mbps| TX RATE  134.22Mpps   90207Mbps
Pipe1| RX RATE  135.55Mpps   91095Mbps| TX RATE  134.60Mpps   90456Mbps
Pipe1| RX RATE  156.22Mpps  104987Mbps| TX RATE  127.55Mpps   85717Mbps
Pipe1| RX RATE  157.27Mpps  105688Mbps| TX RATE  127.14Mpps   85445Mbps
Pipe1| RX RATE  159.26Mpps  107030Mbps| TX RATE  126.34Mpps   84908Mbps
Pipe1| RX RATE  160.42Mpps  107812Mbps| TX RATE  125.88Mpps   84599Mbps
Pipe1| RX RATE  161.68Mpps  108656Mbps| TX RATE  125.54Mpps   84369Mbps
Pipe1| RX RATE  164.31Mpps  110423Mbps| TX RATE  124.82Mpps   83886Mbps
Pipe1| RX RATE  165.72Mpps  111371Mbps| TX RATE  124.49Mpps   83658Mbps
Pipe1| RX RATE  167.15Mpps  112333Mbps| TX RATE  124.27Mpps   83515Mbps
Pipe1| RX RATE  168.85Mpps  113479Mbps| TX RATE  123.83Mpps   83219Mbps
Pipe1| RX RATE  170.38Mpps  114503Mbps| TX RATE  123.55Mpps   83031Mbps
Pipe1| RX RATE  172.18Mpps  115714Mbps| TX RATE  123.03Mpps   82684Mbps
Pipe1| RX RATE  174.00Mpps  116931Mbps| TX RATE  122.58Mpps   82374Mbps
Pipe1| RX RATE  176.03Mpps  118295Mbps| TX RATE  122.02Mpps   82004Mbps
Pipe1| RX RATE  178.09Mpps  119679Mbps| TX RATE  121.58Mpps   81713Mbps
Pipe1| RX RATE  180.23Mpps  121119Mbps| TX RATE  121.17Mpps   81438Mbps
Pipe1| RX RATE  182.41Mpps  122587Mbps| TX RATE  120.63Mpps   81074Mbps
Pipe1| RX RATE  185.19Mpps  124454Mbps| TX RATE  119.99Mpps   80635Mbps
Pipe1| RX RATE  187.92Mpps  126284Mbps| TX RATE  119.26Mpps   80152Mbps
Pipe1| RX RATE  190.62Mpps  128106Mbps| TX RATE  118.70Mpps   79767Mbps
Pipe1| RX RATE  193.84Mpps  130261Mbps| TX RATE  117.89Mpps   79230Mbps
Pipe1| RX RATE  197.20Mpps  132528Mbps| TX RATE  117.16Mpps   78744Mbps
Pipe1| RX RATE  200.92Mpps  135026Mbps| TX RATE  116.30Mpps   78163Mbps
Pipe1| RX RATE  203.83Mpps  136979Mbps| TX RATE  115.66Mpps   77729Mbps
Pipe1| RX RATE  204.79Mpps  137626Mbps| TX RATE  115.45Mpps   77589Mbps
Pipe1| RX RATE  207.58Mpps  139502Mbps| TX RATE  114.84Mpps   77176Mbps
Pipe1| RX RATE  209.16Mpps  140562Mbps| TX RATE  114.50Mpps   76949Mbps
Pipe1| RX RATE  212.27Mpps  142656Mbps| TX RATE  113.84Mpps   76504Mbps
# Out:
#   Cell In [22], line 4
#     Pipe1| RX RATE  127.52Mpps   85699Mbps| TX RATE  127.51Mpps   85693Mbps
#                          ^
# SyntaxError: invalid decimal literal

# %%
# SMARTCOOKIE LATENCY EXPERIMENT - SYN FLOOD. Lucid Testbed. 
# SYN flood attack rate for starting FPR of ~5.2% with ~16,000 injected flows. 
# 100% of attack packets are being processed (cookie checked) and stopped at switch agent. 
# Measure client curl latencies as attack increases. Typical latencies are 4-5ms. 

sc_syn_flood_rates_lucid = [

    600192,
    1488384,
    2082880,
    3026240,
    4464000,
    5427648,
    6556608,
    7755200,
    8944225,
    9559680,
    10183447,
    11333504,
    12497472,
    13721700,
    14889727,
    15613492,
    16662336,
    17756510,
    18158399,
    19710000,
    20870000,
    21866821,
    22382912,
    23325829,
    24944072,
    25779765,
    26400242,
    27234660,
    28560653,
    29771895,
    30894443,
    31800886,
    32922685,
    33312901,
    34551177,
    35996098,
    36340467,
    37296674,
    
    
]

# %%
# SMARTCOOKIE LATENCY EXPERIMENT - ACK FLOOD. Lucid Testbed. 
# SYN flood attack rate for starting FPR of ~5.3% with ~14,000 injected flows. 
# 100% of attack packets are being processed (cookie checked) and stopped at switch agent. 
# Measure client curl latencies as attack increases. Typical latencies are start at 2ms... 7ms. 

sc_ack_flood_rates_lucid = [
    
    #jc4 DPDK port 0 
    
    595072,
    1195078,
    1680960,
    2380800,
    2721920,
    # latencies are 3-4 ms 
    3025920,
    3348416,
    4232256,
    4761536,
    5363712,
    5956864,
    6556551,
    7142848,
    7755136,
    8260952,
    8952858,
    9523156,
    10143680,
    10772996,
    11333184,
    11905055,
    # more steadily 4 ms 
    12696842,
    13194014,
    13928718,
    14337931,
    15188123,
    15552448,
    16085902,
    16640705,
    17280617,
    17922363,
    18534543,
    19042782,
    19712863,
    20283526,
    20970496,
    21588379,
    22016867,
    22756454,
    23297589,
    23921928,
    24553115,
    25389184,
    26371816,
    26880864,
    27437620,
    27989769,
    28953497,
    29267228,
    30256444,
    31103847,
    32170419,
    33445645,
    34132439,
    34793146,
    35416737,
    35981070,
    36412971,
    37308845,
    37812694,
    38870384,
    39423419,
    40414663,
    41801592,
    42401666,
    42594701,
    43337758,
    
    
]

# %%
# JAQEN LATENCY EXPERIMENT - SYN FLOOD. Lucid Testbed. 
# SYN flood attack rate for starting FPR of ~5.1% with 25K injected flows. 
# Some SYN packets are cookie checked at switch, others are FPs and get processed by server.
# Measure client curl latencies as attack increases. Typical latencies are ~ 14ms - 16ms. 

jaqen_syn_flood_rates_lucid = [
    0,
    59328,
    600192,
    1058304,
    1806848,
    2316544,
    2409408,
    3585124,
    3854571,
    4216384,
    4818220,
    
    ## collect these again?? 
    5427648,
    5956288,
    6374383,
    6630912,
    7255872,
    7785664,
    8430848,
    8928384,
    9507840,
    9998504,
    # up to 19-25 ms 
    10303242,
    10725553,
    
    
    ## reset FPR to ~5.5% 
    11327936,
    11906752,
    12641495,
    12817392,
    13243943,
    13716056,
    14483776,
    14881082,
    
    # things start to break down around here, at 15.55 Mpps attack sent, 0.9 Mpps attack received by server 
    15327872,
    15798212,
    16143344,
    16922816,
    17346329,
    17929088,
    
    # attack rate 18.14 Mpps sent, 1.09 Mpps received by server 
    18145020,
    18822953,
    19009131,
    19988139,
    # tx 20.88 Mpps, rx 1.27 Mpps => see cookie breakdown at 1.3 Mpps for vanilla server
    20881088,
    # tx 21.6 Mpps, rx 1.32 Mpps
    21613464,
    # tx 22.75 Mpps, rx 1.39 Mpps 
    22753133,
    # tx 23.32 Mpps, rx 1.43 Mpps 
    23325099, 
]

# %%
rx = 1.43
tx = 23.32

fpr = rx/tx
fpr
