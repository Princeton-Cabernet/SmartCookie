# %%
# Jaqen Proxy Mode 1. SYN Flood. On Cabernet Testbed 

syn_flood_jaqen1 = [
    
# Some additional data points 
"Pipe1| RX RATE   2.35Mpps   19056Mbps| TX RATE   2.35Mpps   19056Mbps",

"Pipe1| RX RATE   7.35Mpps   19056Mbps| TX RATE   7.35Mpps   19056Mbps",

"Pipe1| RX RATE   12.35Mpps   19056Mbps| TX RATE   12.35Mpps   19056Mbps",

# "Pipe1| RX RATE   17.35Mpps   19056Mbps| TX RATE   17.35Mpps   19056Mbps",
"Pipe1| RX RATE   22.35Mpps   19056Mbps| TX RATE   22.35Mpps   19056Mbps",
"Pipe1| RX RATE   27.35Mpps   19056Mbps| TX RATE   27.35Mpps   19056Mbps",
    
        
# "Pipe1| RX RATE   28.35Mpps   19056Mbps| TX RATE   28.35Mpps   19056Mbps",
    
#rate 15 
    
"Pipe1| RX RATE   44.76Mpps   30085Mbps| TX RATE   44.76Mpps   30085Mbps",
    
#rate 16     
    
#"Pipe1| RX RATE   47.66Mpps   32035Mbps| TX RATE   47.66Mpps   32034Mbps", 
 
#rate 17     
#"Pipe1| RX RATE   50.99Mpps   34272Mbps| TX RATE   50.99Mpps   34273Mbps",
    
#rate 18  
#"Pipe1| RX RATE   53.48Mpps   35947Mbps| TX RATE   53.48Mpps   35947Mbps",
#rate 19 
#"Pipe1| RX RATE   56.94Mpps   38272Mbps| TX RATE   56.94Mpps   38272Mbps",
#rate 20 
"Pipe1| RX RATE   60.05Mpps   40358Mbps| TX RATE   60.05Mpps   40358Mbps",
    
# The return ratio is 100% up until this point 
    "Pipe1| RX RATE   31.34Mpps   21062Mbps| TX RATE   31.34Mpps   21063Mbps",
    
#     "Pipe1| RX RATE   32.75Mpps   22009Mbps| TX RATE   32.74Mpps   22004Mbps",
    
#     "Pipe1| RX RATE   34.28Mpps   23039Mbps| TX RATE   34.27Mpps   23034Mbps",
    
    "Pipe1| RX RATE   44.77Mpps   30088Mbps| TX RATE   44.76Mpps   30082Mbps",
    
    "Pipe1| RX RATE   52.23Mpps   35100Mbps| TX RATE   52.22Mpps   35096Mbps",
    
    "Pipe1| RX RATE   60.92Mpps   40939Mbps| TX RATE   60.91Mpps   40934Mbps", 
    
#     "Pipe1| RX RATE   68.43Mpps   45985Mbps| TX RATE   68.42Mpps   45983Mbps",
    
    "Pipe1| RX RATE   75.59Mpps   50797Mbps| TX RATE   75.58Mpps   50792Mbps",
    
    "Pipe1| RX RATE   82.39Mpps   55368Mbps| TX RATE   82.38Mpps   55366Mbps",
    
    "Pipe1| RX RATE   91.35Mpps   61388Mbps| TX RATE   91.34Mpps   61383Mbps",
    
#     "Pipe1| RX RATE   99.63Mpps   66952Mbps| TX RATE   99.62Mpps   66947Mbps",
    
    "Pipe1| RX RATE  104.37Mpps   70137Mbps| TX RATE  104.36Mpps   70131Mbps",
    
#     "Pipe1| RX RATE  109.71Mpps   73728Mbps| TX RATE  109.70Mpps   73724Mbps",
    
    "Pipe1| RX RATE  111.26Mpps   74773Mbps| TX RATE  111.25Mpps   74770Mbps",
    
#     "Pipe1| RX RATE  117.06Mpps   78673Mbps| TX RATE  117.06Mpps   78668Mbps",
    
    "Pipe1| RX RATE  124.68Mpps   83794Mbps| TX RATE  124.67Mpps   83789Mbps",
    
    "Pipe1| RX RATE  132.05Mpps   88743Mbps| TX RATE  132.04Mpps   88737Mbps",
    
#     "Pipe1| RX RATE  138.04Mpps   92773Mbps| TX RATE  138.04Mpps   92769Mbps",
    
    "Pipe1| RX RATE  147.43Mpps   99082Mbps| TX RATE  147.43Mpps   99079Mbps",
    
#     "Pipe1| RX RATE  154.14Mpps  103590Mbps| TX RATE  154.14Mpps  103587Mbps",
    
    "Pipe1| RX RATE  160.29Mpps  107726Mbps| TX RATE  160.29Mpps  107723Mbps",
    
    "Pipe1| RX RATE  170.71Mpps  114729Mbps| TX RATE  170.71Mpps  114723Mbps",
    "Pipe1| RX RATE  184.32Mpps  123870Mbps| TX RATE  184.32Mpps  123865Mbps",
    
#     "Pipe1| RX RATE  187.37Mpps  125925Mbps| TX RATE  186.27Mpps  125180Mbps",
#     "Pipe1| RX RATE  187.58Mpps  126064Mbps| TX RATE  186.18Mpps  125119Mbps",
#     "Pipe1| RX RATE  188.15Mpps  126450Mbps| TX RATE  186.00Mpps  124999Mbps",
    "Pipe1| RX RATE  188.55Mpps  126720Mbps| TX RATE  185.92Mpps  124949Mbps",
    
#     "Pipe1| RX RATE  189.59Mpps  127422Mbps| TX RATE  185.46Mpps  124641Mbps",
    "Pipe1| RX RATE  190.60Mpps  128092Mbps| TX RATE  185.07Mpps  124370Mbps",
#     "Pipe1| RX RATE  191.68Mpps  128825Mbps| TX RATE  184.64Mpps  124080Mbps",
#     "Pipe1| RX RATE  193.24Mpps  129871Mbps| TX RATE  184.65Mpps  124090Mbps",
    
    "Pipe1| RX RATE  194.29Mpps  130574Mbps| TX RATE  184.22Mpps  123798Mbps",
#     "Pipe1| RX RATE  195.37Mpps  131300Mbps| TX RATE  183.85Mpps  123558Mbps",
#     "Pipe1| RX RATE  196.42Mpps  132011Mbps| TX RATE  183.27Mpps  123169Mbps",
    
#     "Pipe1| RX RATE  197.84Mpps  132967Mbps| TX RATE  183.30Mpps  123186Mbps",
    "Pipe1| RX RATE  199.18Mpps  133853Mbps| TX RATE  183.11Mpps  123055Mbps",
#     "Pipe1| RX RATE  199.97Mpps  134393Mbps| TX RATE  182.45Mpps  122611Mbps",
    "Pipe1| RX RATE  202.25Mpps  135930Mbps| TX RATE  181.59Mpps  122036Mbps",
#     "Pipe1| RX RATE  204.33Mpps  137318Mbps| TX RATE  180.69Mpps  121433Mbps",
    "Pipe1| RX RATE  207.11Mpps  139190Mbps| TX RATE  179.25Mpps  120458Mbps",
#     "Pipe1| RX RATE  212.53Mpps  142840Mbps| TX RATE  179.65Mpps  120731Mbps",
#     "Pipe1| RX RATE  217.99Mpps  146504Mbps| TX RATE  176.77Mpps  118796Mbps",
    "Pipe1| RX RATE  218.08Mpps  146564Mbps| TX RATE  176.77Mpps  118800Mbps",
]

# %%
# Jaqen Proxy Mode 1. SYN Flood. On Cabernet Testbed 
#rates in Mpps 
jaqen_send_rate = [1]
jaqen_rcv_rate = [1] 



for line in syn_flood_jaqen1:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    jaqen_send_rate.append(float(send_str))
    jaqen_rcv_rate.append(float(rcv_str))
    
print(jaqen_send_rate)
print(jaqen_rcv_rate)
# Out:
# [1, 2.351, 7.351, 12.35, 22.35, 27.35, 44.76, 60.05, 31.34, 44.77, 52.23, 60.92, 75.59, 82.39, 91.35, 104.37, 111.26, 124.68, 132.05, 147.43, 160.291, 170.711, 184.321, 188.551, 190.601, 194.291, 199.181, 202.251, 207.111, 218.081]
# [1, 2.35, 7.35, 12.35, 22.35, 27.35, 44.76, 60.05, 31.34, 44.76, 52.22, 60.91, 75.58, 82.38, 91.34, 104.36, 111.25, 124.67, 132.04, 147.43, 160.29, 170.71, 184.32, 185.92, 185.07, 184.22, 183.11, 181.59, 179.25, 176.77]

# %%
# SmartCookie-AES. SYN Flood. On Cabernet Testbed 

sc_aes_data = [
    
"Pipe1| RX RATE    0.14Mpps      99Mbps| TX RATE    0.14Mpps      99Mbps", 
"Pipe1| RX RATE    0.88Mpps     666Mbps| TX RATE    0.88Mpps     666Mbps", 
"Pipe1| RX RATE   22.38Mpps   15045Mbps| TX RATE   22.38Mpps   15045Mbps", 
"Pipe1| RX RATE   30.79Mpps   20763Mbps| TX RATE   30.79Mpps   20763Mbps", 
"Pipe1| RX RATE   32.75Mpps   22008Mbps| TX RATE   32.74Mpps   22003Mbps", 
"Pipe1| RX RATE   34.28Mpps   23039Mbps| TX RATE   34.27Mpps   23034Mbps", 
"Pipe1| RX RATE   37.19Mpps   24992Mbps| TX RATE   37.18Mpps   24985Mbps", 
"Pipe1| RX RATE   40.63Mpps   27304Mbps| TX RATE   40.61Mpps   27292Mbps", 
# "Pipe1| RX RATE   42.19Mpps   28352Mbps| TX RATE   42.18Mpps   28346Mbps", 
"Pipe1| RX RATE   44.77Mpps   30088Mbps| TX RATE   44.76Mpps   30081Mbps", 
# "Pipe1| RX RATE   46.67Mpps   31362Mbps| TX RATE   46.59Mpps   31313Mbps",
#"Pipe1| RX RATE   47.68Mpps   32043Mbps| TX RATE   41.52Mpps   27904Mbps", 
"Pipe1| RX RATE   48.74Mpps   32758Mbps| TX RATE   48.72Mpps   32745Mbps", 
"Pipe1| RX RATE   49.85Mpps   33503Mbps| TX RATE   49.65Mpps   33369Mbps", 
"Pipe1| RX RATE   51.01Mpps   34282Mbps| TX RATE   50.35Mpps   33837Mbps", 

# Start to notice some breakdown around 52 Mpps. 

"Pipe1| RX RATE   52.23Mpps   35099Mbps| TX RATE   50.00Mpps   33602Mbps", 
"Pipe1| RX RATE   53.50Mpps   35952Mbps| TX RATE   49.39Mpps   33192Mbps",   
"Pipe1| RX RATE   56.23Mpps   37792Mbps| TX RATE   48.06Mpps   32301Mbps", 
"Pipe1| RX RATE   57.72Mpps   38789Mbps| TX RATE   47.43Mpps   31876Mbps", 
# "Pipe1| RX RATE   59.28Mpps   39838Mbps| TX RATE   46.66Mpps   31358Mbps", 
"Pipe1| RX RATE   60.91Mpps   40935Mbps| TX RATE   46.02Mpps   30931Mbps", 
"Pipe1| RX RATE   68.52Mpps   46050Mbps| TX RATE   42.56Mpps   28602Mbps", 
"Pipe1| RX RATE   65.80Mpps   44219Mbps| TX RATE   43.94Mpps   29529Mbps", 
"Pipe1| RX RATE   78.30Mpps   52623Mbps| TX RATE   38.32Mpps   25754Mbps",
"Pipe1| RX RATE   84.32Mpps   56666Mbps| TX RATE   36.28Mpps   24386Mbps", 
"Pipe1| RX RATE   87.64Mpps   58897Mbps| TX RATE   34.92Mpps   23467Mbps", 
"Pipe1| RX RATE   95.31Mpps   64054Mbps| TX RATE   32.03Mpps   21530Mbps", 
"Pipe1| RX RATE   99.64Mpps   66961Mbps| TX RATE   30.62Mpps   20578Mbps", 
"Pipe1| RX RATE  104.36Mpps   70132Mbps| TX RATE   29.21Mpps   19634Mbps", 
"Pipe1| RX RATE  109.56Mpps   73626Mbps| TX RATE   27.69Mpps   18613Mbps", 
"Pipe1| RX RATE  121.52Mpps   81667Mbps| TX RATE   25.32Mpps   17022Mbps", 
"Pipe1| RX RATE  137.07Mpps   92114Mbps| TX RATE   21.95Mpps   14757Mbps", 
"Pipe1| RX RATE  169.21Mpps  113715Mbps| TX RATE   16.35Mpps   10997Mbps", 
]

# %%
## With 100 Gbps 
pkt_size_bits = 74*8
port_bw_gbps = 100 # in Gbps 
port_bw_converted = port_bw_gbps * (1024^3) 

n = (port_bw_converted)/(pkt_size_bits)

recirc_throughput = n/4 #divide by num recirc = 4 
recirc_throughput
# Out:
# 43.369932432432435

# %%
## With 200 Gbps 
pkt_size_bits = 74*8
port_bw_gbps = 200 # in Gbps 
port_bw_converted = port_bw_gbps * (1024^3) 

n = (port_bw_converted)/(pkt_size_bits)

recirc_throughput = n/4 #divide by num recirc = 4 
recirc_throughput
# Out:
# 86.73986486486487

# %%
# SmartCookie-AES. SYN Flood. On Cabernet Testbed 
#rates in Mpps 
sc_aes_send_rate = [1]
sc_aes_rcv_rate = [1] 



for line in sc_aes_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_aes_send_rate.append(float(send_str))
    sc_aes_rcv_rate.append(float(rcv_str))
    
print(sc_aes_send_rate)
print(sc_aes_rcv_rate)
# Out:
# [1, 0.14, 0.88, 22.38, 30.79, 32.75, 34.28, 37.19, 40.63, 44.77, 48.74, 49.85, 51.01, 52.23, 53.5, 56.23, 57.72, 60.91, 68.52, 65.8, 78.3, 84.32, 87.64, 95.31, 99.64, 104.36, 109.56, 121.52, 137.07, 169.211]
# [1, 0.14, 0.88, 22.38, 30.79, 32.74, 34.27, 37.18, 40.61, 44.76, 48.72, 49.65, 50.35, 50.0, 49.39, 48.06, 47.43, 46.02, 42.56, 43.94, 38.32, 36.28, 34.92, 32.03, 30.62, 29.21, 27.69, 25.32, 21.95, 16.35]

# %%
# SmartCookie-CRC. SYN Flood. On Cabernet Testbed 
#rates in Mpps 

sc_crc_data = [

]


# SmartCookie-CRC. SYN Flood. On Cabernet Testbed 
#rates in Mpps 
sc_crc_send_rate = [1,5,10,15,20,30,40,50, 75, 100, 150, 200, 220]
sc_crc_rcv_rate =  [1,5,10,15,20,30,40,50, 75, 100, 150, 200, 220]



for line in sc_crc_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_crc_send_rate.append(float(send_str))
    sc_crc_rcv_rate.append(float(rcv_str))
    
print(sc_crc_send_rate)
print(sc_crc_rcv_rate)
# Out:
# [1, 5, 10, 15, 20, 30, 40, 50, 75, 100, 150, 200, 220]
# [1, 5, 10, 15, 20, 30, 40, 50, 75, 100, 150, 200, 220]

# %%
# Baseline Vanilla Cookie
#jc4 send rate, single sender
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 



b_raw_data = [
    
#rate 1
"2/0  |22/0|136|3/ 8|40G    |UP |   0.59|   0.59|   399.84|   399.83|  0%|  0%"
    
#rate 2       
"2/0  |22/0|136|3/ 8|40G    |UP |   1.18|   1.19|   799.57|   800.06|  1%|  2%",
#rate 3        
"2/0  |22/0|136|3/ 8|40G    |UP |   1.78|   1.56|  1198.67|  1051.74|  2%|  2%",
#rate 4  
"2/0  |22/0|136|3/ 8|40G    |UP |   2.37|   1.48|  1597.24|   999.41|  3%|  2%",
    
#rate 5 
    
"2/0  |22/0|136|3/ 8|40G    |UP |   2.97|   1.52|  1997.10|  1025.86|  4%|  2%",
    
#rate 6 
"2/0  |22/0|136|3/ 8|40G    |UP |   3.56|   1.57|  2394.82|  1057.25|  5%|  2%",     
#rate 7         
"2/0  |22/0|136|3/ 8|40G    |UP |   4.15|   1.59|  2792.87|  1070.25|  6%|  2%",
#rate 8        
"2/0  |22/0|136|3/ 8|40G    |UP |   4.74|   1.54|  3189.62|  1039.33|  7%|  2%",
    
#rate 9
"2/0  |22/0|136|3/ 8|40G    |UP |   5.34|   1.56|  3592.10|  1054.39|  8%|  2%",
    
#rate 10 
    
"2/0  |22/0|136|3/ 8|40G    |UP |   5.93|   1.55|  3987.25|  1046.41|  9%|  2%",    

#rate 11
"2/0  |22/0|136|3/ 8|40G    |UP |   6.52|   1.48|  4385.22|   997.61| 10%|  2%",
    
#rate 15
    
"2/0  |22/0|136|3/ 8|40G    |UP |   8.88|   1.59|  5971.40|  1070.87| 14%|  2%",
 
#rate 20
"2/0  |22/0|136|3/ 8|40G    |UP |  11.81|   1.56|  7940.63|  1051.27| 19%|  2%",
    
#rate 22
    
"2/0  |22/0|136|3/ 8|40G    |UP |  13.02|   1.42|  8750.76|   960.50| 21%|  2%",

#rate 22
    
"2/0  |22/0|136|3/ 8|40G    |UP |  13.02|   1.42|  8750.76|   960.50| 21%|  2%",
    
    
]

# %%
b_send_rate = [1]
b_rcv_rate = [1] 



for line in b_raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>30:
            if index < 40:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 50:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    print(send_str)
    print(rcv_str)
# Out:
# 0.59
# 0.59
# 1.78
# 1.56
# 2.37
# 1.48
# 2.97
# 1.52
# 3.56
# 1.57
# 4.15
# 1.59
# 4.74
# 1.54
# 5.34
# 1.56
# 5.93
# 1.55
# 6.52
# 1.48
# 8.88
# 1.59
# 11.81
# 1.56
# 13.02
# 1.42
# 13.02
# 1.42

# %%
#Baseline Vanilla Kernel Cookie, rates in Mpps 
b_send_rate = [1]
b_rcv_rate = [1] 



for line in b_raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>30:
            if index < 40:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 50:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    b_send_rate.append(float(send_str))
    b_rcv_rate.append(float(rcv_str))
    
print(b_send_rate)
print(b_rcv_rate)
# Out:
# [1, 0.59, 1.78, 2.37, 2.97, 3.56, 4.15, 4.74, 5.34, 5.93, 6.52, 8.88, 11.81, 13.02, 13.02]
# [1, 0.59, 1.56, 1.48, 1.52, 1.57, 1.59, 1.54, 1.56, 1.55, 1.48, 1.59, 1.56, 1.42, 1.42]

# %%
# XDP Cookie - SECOND RUN with server jc5 accepting/returning traffic on two ports 
#jc4 send rate, single sender
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 


#actually use this data! 

xdp_raw_data_run2 = [
    
#rate 1
    
"2/0  |22/0|136|3/ 8|40G    |UP |   0.59|   0.59|   399.98|   399.98|  0%|  0%",

    
#rate 5
    
"2/0  |22/0|136|3/ 8|40G    |UP |   2.97|   2.97|  2001.39|  2001.42|  5%|  5%",
    
#rate 7
    
"2/0  |22/0|136|3/ 8|40G    |UP |   4.16|   4.16|  2799.30|  2799.34|  6%|  6%",
    
#rate 9
#"2/0  |22/0|136|3/ 8|40G    |UP |   5.36|   5.36|  3603.71|  3603.92|  9%|  9%",     
#rate 10
"2/0  |22/0|136|3/ 8|40G    |UP |   5.95|   5.95|  3999.75|  3999.82|  9%|  9%",
#rate 11
#"2/0  |22/0|136|3/ 8|40G    |UP |   6.55|   6.55|  4404.97|  4405.29| 11%| 11%", 
         
        
#rate 12
#"2/0  |22/0|136|3/ 8|40G    |UP |   7.13|   7.13|  4795.81|  4795.85| 11%| 11%",
#rate 13
#"2/0  |22/0|136|3/ 8|40G    |UP |   7.74|   7.74|  5203.97|  5204.04| 13%| 13%",
#rate 14          
#"2/0  |22/0|136|3/ 8|40G    |UP |   8.32|   7.50|  5591.43|  5043.74| 13%| 12%",
    
#rate 15
"2/0  |22/0|136|3/ 8|40G    |UP |   9.47|   7.40|  6364.82|  4974.24| 15%| 12%",
#rate 16          
#"2/0  |22/0|136|3/ 8|40G    |UP |   9.47|   7.46|  6364.51|  5019.67| 15%| 12%",
#rate 17          
"2/0  |22/0|136|3/ 8|40G    |UP |  10.06|   7.40|  6766.42|  4974.35| 16%| 12%",
    
    
#rate 18  
#"2/0  |22/0|136|3/ 8|40G    |UP |  10.65|   7.36|  7158.71|  4948.90| 17%| 12%",
#rate 19
#"2/0  |22/0|136|3/ 8|40G    |UP |  11.24|   7.33|  7559.83|  4926.08| 18%| 12%",
#rate 20
"2/0  |22/0|136|3/ 8|40G    |UP |  11.81|   7.39|  7942.49|  4970.87| 19%| 12%",

#rate 21
#"2/0  |22/0|136|3/ 8|40G    |UP |  12.40|   7.38|  8334.83|  4964.93| 20%| 12%",
    
#rate 22
"2/0  |22/0|136|3/ 8|40G    |UP |  13.12|   7.42|  8817.43|  4992.63| 22%| 12%",

#rate 23
"2/0  |22/0|136|3/ 8|40G    |UP |  13.57|   7.33|  9122.17|  4927.20| 22%| 12%",
#rate 24
#"2/0  |22/0|136|3/ 8|40G    |UP |  14.13|   7.24|  9497.49|  4865.48| 23%| 12%",
#rate 24.5
#"2/0  |22/0|136|3/ 8|40G    |UP |  14.41|   7.31|  9689.27|  4916.15| 24%| 12%",
#rate 25
"2/0  |22/0|136|3/ 8|40G    |UP |  14.70|   7.30|  9882.23|  4908.06| 24%| 12%",
#rate 26
#"2/0  |22/0|136|3/ 8|40G    |UP |  15.54|   7.51| 10447.57|  5048.11| 26%| 12%",
    
#rate 27
#"2/0  |22/0|136|3/ 8|40G    |UP |  16.06|   7.57| 10795.00|  5092.74| 26%| 12%",
#rate 28
#"2/0  |22/0|136|3/ 8|40G    |UP |  16.63|   7.74| 11182.07|  5207.20| 27%| 13%",
#rate 29
#"2/0  |22/0|136|3/ 8|40G    |UP |  17.26|   7.62| 11604.86|  5121.81| 29%| 12%",  

#rate 31
"2/0  |22/0|136|3/ 8|40G    |UP |  18.50|   7.67| 12436.15|  5155.35| 31%| 12%",

#rate 35
"2/0  |22/0|136|3/ 8|40G    |UP |  20.86|   7.41| 14019.85|  4984.16| 35%| 12%",
    
#rate 40
#"2/0  |22/0|136|3/ 8|40G    |UP |  23.87|   7.41| 16045.21|  4984.97| 40%| 12%",
    
#rate 45 
"2/0  |22/0|136|3/ 8|40G    |UP |  26.87|   7.37| 18061.17|  4958.83| 45%| 12%",

#rate 50
"2/0  |22/0|136|3/ 8|40G    |UP |  29.72|   7.24| 19976.83|  4871.08| 49%| 12%",
]

# %%
#XDP Cookie, rates in Mpps 
xdp_send_rate = [1]
xdp_rcv_rate = [1] 


xdp_raw_data = xdp_raw_data_run2
for line in xdp_raw_data:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>30:
            if index < 40:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 50:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    xdp_send_rate.append(float(send_str))
    xdp_rcv_rate.append(float(rcv_str))
    
print(xdp_send_rate)
print(xdp_rcv_rate)
# Out:
# [1, 0.59, 2.97, 4.16, 5.95, 9.47, 10.06, 11.81, 13.12, 13.57, 14.7, 18.5, 20.86, 26.87, 29.72]
# [1, 0.59, 2.97, 4.16, 5.95, 7.4, 7.4, 7.39, 7.42, 7.33, 7.3, 7.67, 7.41, 7.37, 7.24]

# %%
# SmartCookie Improvement: Randomly Choose Port 
#cab804 rate and cab801 rate
#RX rate at switch is send rate of attackers 
#TX rate at switch is response rate of proxy 

raw_data_rnd_port = [

    
# Some additional data points 
"Pipe1| RX RATE   1.35Mpps   19056Mbps| TX RATE   1.35Mpps   19056Mbps",

"Pipe1| RX RATE   5.35Mpps   19056Mbps| TX RATE   5.35Mpps   19056Mbps",

"Pipe1| RX RATE   10.35Mpps   19056Mbps| TX RATE   10.35Mpps   19056Mbps",

"Pipe1| RX RATE   15.35Mpps   19056Mbps| TX RATE   15.35Mpps   19056Mbps",
"Pipe1| RX RATE   20.35Mpps   19056Mbps| TX RATE   20.35Mpps   19056Mbps",
"Pipe1| RX RATE   25.35Mpps   19056Mbps| TX RATE   25.35Mpps   19056Mbps",
    
#rate 10 
    
"Pipe1| RX RATE   28.35Mpps   19056Mbps| TX RATE   28.35Mpps   19056Mbps",
"Pipe1| RX RATE   30.35Mpps   19056Mbps| TX RATE   30.35Mpps   19056Mbps",

"Pipe1| RX RATE   31.35Mpps   19056Mbps| TX RATE   31.35Mpps   19056Mbps",

"Pipe1| RX RATE   32.35Mpps   19056Mbps| TX RATE   32.35Mpps   19056Mbps",
"Pipe1| RX RATE   32.35Mpps   19056Mbps| TX RATE   32.35Mpps   19056Mbps",

"Pipe1| RX RATE   34.35Mpps   19056Mbps| TX RATE   34.35Mpps   19056Mbps",

#rate 15 
    
"Pipe1| RX RATE   44.76Mpps   30085Mbps| TX RATE   44.76Mpps   30085Mbps",
    
#rate 16     
    
#"Pipe1| RX RATE   47.66Mpps   32035Mbps| TX RATE   47.66Mpps   32034Mbps", 
 
#rate 17     
#"Pipe1| RX RATE   50.99Mpps   34272Mbps| TX RATE   50.99Mpps   34273Mbps",
    
#rate 18  
#"Pipe1| RX RATE   53.48Mpps   35947Mbps| TX RATE   53.48Mpps   35947Mbps",
#rate 19 
#"Pipe1| RX RATE   56.94Mpps   38272Mbps| TX RATE   56.94Mpps   38272Mbps",
#rate 20 
"Pipe1| RX RATE   60.05Mpps   40358Mbps| TX RATE   60.05Mpps   40358Mbps",
#rate 21  
#"Pipe1| RX RATE   62.65Mpps   42101Mbps| TX RATE   62.64Mpps   42099Mbps",         
#rate 22  
#"Pipe1| RX RATE   65.44Mpps   43983Mbps| TX RATE   65.43Mpps   43975Mbps",
#rate 23  
#"Pipe1| RX RATE   68.54Mpps   46061Mbps| TX RATE   68.52Mpps   46053Mbps", 
         
        
#rate 24  
#"Pipe1| RX RATE   71.88Mpps   48311Mbps| TX RATE   71.87Mpps   48300Mbps",
#rate 25          
"Pipe1| RX RATE   74.32Mpps   49952Mbps| TX RATE   74.31Mpps   49942Mbps",
#rate 26          
#"Pipe1| RX RATE   78.31Mpps   52635Mbps| TX RATE   78.31Mpps   52625Mbps",
    
#rate 27
#"Pipe1| RX RATE   81.22Mpps   54583Mbps| TX RATE   81.20Mpps   54573Mbps",
#rate 28          
#"Pipe1| RX RATE   84.32Mpps   56668Mbps| TX RATE   84.30Mpps   56658Mbps",
#rate 29          
#"Pipe1| RX RATE   87.67Mpps   58925Mbps| TX RATE   87.67Mpps   58916Mbps",
#rate 30  
"Pipe1| RX RATE   89.48Mpps   60137Mbps| TX RATE   89.46Mpps   60126Mbps"
#rate 35
"Pipe1| RX RATE  104.38Mpps   70153Mbps| TX RATE  104.37Mpps   70143Mbps",
#rate 40
"Pipe1| RX RATE  121.71Mpps   81792Mbps| TX RATE  121.69Mpps   81782Mbps",
#rate 42
#"Pipe1| RX RATE  125.24Mpps   84163Mbps| TX RATE  125.22Mpps   84152Mbps",
#rate 43 
#"Pipe1| RX RATE  128.90Mpps   86622Mbps| TX RATE  128.88Mpps   86611Mbps",
#rate 44
#"Pipe1| RX RATE  132.76Mpps   89220Mbps| TX RATE  132.74Mpps   89209Mbps",
#rate 45
"Pipe1| RX RATE  136.94Mpps   92031Mbps| TX RATE  134.77Mpps   90571Mbps",
#rate 46
"Pipe1| RX RATE  136.93Mpps   92027Mbps| TX RATE  134.77Mpps   90571Mbps",
#rate 47
"Pipe1| RX RATE  141.35Mpps   94990Mbps| TX RATE  133.04Mpps   89408Mbps",
#rate 48
"Pipe1| RX RATE  146.05Mpps   98151Mbps| TX RATE  131.10Mpps   88106Mbps",
#rate 50
"Pipe1| RX RATE  151.03Mpps  101502Mbps| TX RATE  129.36Mpps   86933Mbps",
    
    
#rate 55
"Pipe1| RX RATE  166.34Mpps  111786Mbps| TX RATE  124.38Mpps   83591Mbps",
#rate 60
"Pipe1| RX RATE  182.47Mpps  122623Mbps| TX RATE  120.50Mpps   80979Mbps",
#rate 65
"Pipe1| RX RATE  198.99Mpps  133732Mbps| TX RATE  116.75Mpps   78465Mbps",
#rate 70
"Pipe1| RX RATE  204.26Mpps  137267Mbps| TX RATE  115.61Mpps   77697Mbps",
#rate 80
"Pipe1| RX RATE  208.56Mpps  140157Mbps| TX RATE  114.66Mpps   77056Mbps",
#rate 90
"Pipe1| RX RATE  208.85Mpps  140360Mbps| TX RATE  114.60Mpps   77018Mbps",
#rate 100
"Pipe1| RX RATE  208.98Mpps  140440Mbps| TX RATE  114.57Mpps   76996Mbps",
]

# %%
# SmartCookie Improvement: Randomly Choose Port
#rates in Mpps 
sc_send_rate_rnd_port = [1]
sc_rcv_rate_rnd_port = [1] 



for line in raw_data_rnd_port:
    #print(line[16:30])
    index = 0 
    send_str=""
    rcv_str=""

    for char in line:
        index+=1
        #get send rate 
        if index>10:
            if index < 30:
                if char.isdigit() or char==".":
                    #print(char)
                    send_str+=char
        #get receive rate 
        if index>40:
            if index < 60:
                if char.isdigit() or char==".":
                    #print(char)
                    rcv_str+=char

    sc_send_rate_rnd_port.append(float(send_str))
    sc_rcv_rate_rnd_port.append(float(rcv_str))
    
print(sc_send_rate_rnd_port)
print(sc_rcv_rate_rnd_port)
# Out:
# [1, 1.351, 5.351, 10.35, 15.35, 20.35, 25.35, 28.35, 30.35, 31.35, 32.35, 32.35, 34.35, 44.76, 60.05, 74.32, 89.48, 121.71, 136.94, 136.93, 141.35, 146.05, 151.031, 166.341, 182.471, 198.991, 204.261, 208.561, 208.851, 208.981]
# [1, 1.35, 5.35, 10.35, 15.35, 20.35, 25.35, 28.35, 30.35, 31.35, 32.35, 32.35, 34.35, 44.76, 60.05, 74.31, 89.46, 121.69, 134.77, 134.77, 133.04, 131.1, 129.36, 124.38, 120.5, 116.75, 115.61, 114.66, 114.6, 114.57]

# %%
## Plotting Direct Send versus Receive 
from matplotlib import pyplot as plt 

from matplotlib.pyplot import figure
import numpy as np



#second iteration of collection with jc4 and synfloodassist and xdp cookies 
x_base = b_send_rate #already in Mpps 
y_base = b_rcv_rate 

x_xdp = xdp_send_rate #already in Mpps 
y_xdp = xdp_rcv_rate

x_sc = sc_send_rate #already in Mpps 
y_sc = sc_rcv_rate

x_sc_set_port = sc_send_rate_set_port #already in Mpps 
y_sc_set_port = sc_rcv_rate_set_port

x_sc_rnd_port = sc_send_rate_rnd_port #already in Mpps 
y_sc_rnd_port = sc_rcv_rate_rnd_port


figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("SYN-ACK Return Ratio (%)")

plt.plot(x_base, y_base, "-r", label="vanilla kernel cookies")
plt.plot(x_xdp, y_xdp, "-k", label="xdp cookies")
plt.plot(x_sc, y_sc, "-b", label="sc defense")
plt.plot(x_sc_set_port, y_sc_set_port, "-m", label="sc defense, set port")
plt.plot(x_sc_rnd_port, y_sc_rnd_port, "-g", label="sc defense, rnd port")




plt.legend(loc="upper left")

plt.show()
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# Cell In [162], line 16
#      13 x_xdp = xdp_send_rate #already in Mpps
#      14 y_xdp = xdp_rcv_rate
# ---> 16 x_sc = sc_send_rate #already in Mpps
#      17 y_sc = sc_rcv_rate
#      19 x_sc_set_port = sc_send_rate_set_port #already in Mpps
#
# NameError: name 'sc_send_rate' is not defined

# %%
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np



#x-axis
#send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

#y-axis
#return_ratio = np.divide(return_rate, send_rate)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)

#x_base = send_rate_scaled
#y_base = return_ratio

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio

b_return_ratio = np.divide(b_rcv_rate, b_send_rate)
xdp_return_ratio = np.divide(xdp_rcv_rate, xdp_send_rate)

sc_return_ratio = np.divide(sc_rcv_rate, sc_send_rate)
sc_return_ratio_set_port = np.divide(sc_rcv_rate_set_port, sc_send_rate_set_port)
sc_return_ratio_rnd_port = np.divide(sc_rcv_rate_rnd_port, sc_send_rate_rnd_port)

jaqen_return_ratio = np.divide(jaqen_rcv_rate, jaqen_send_rate)

sc_aes_return_ratio = np.divide(sc_aes_rcv_rate, sc_aes_send_rate)




#second iteration of collection with jc4 and synfloodassist and xdp cookies 
x_base = b_send_rate #already in Mpps 
y_base = b_return_ratio 

x_xdp = xdp_send_rate #already in Mpps 
y_xdp = xdp_return_ratio 

x_sc = sc_send_rate #already in Mpps 
y_sc = sc_return_ratio 

x_sc_set_port = sc_send_rate_set_port #already in Mpps 
y_sc_set_port = sc_return_ratio_set_port

x_sc_rnd_port = sc_send_rate_rnd_port #already in Mpps 
y_sc_rnd_port = sc_return_ratio_rnd_port

x_jaqen = jaqen_send_rate #already in Mpps 
y_jaqen = jaqen_return_ratio 

x_aes = sc_aes_send_rate #already in Mpps 
y_aes = sc_aes_return_ratio 

figure(figsize = (10, 6), dpi = 100)

plt.xlabel("SYN Flood Attack Rate (Mpps)")
plt.ylabel("SYN-ACK Return Ratio (%)")

plt.plot(x_base, y_base, "-y", label="vanilla kernel cookies")
plt.plot(x_xdp, y_xdp, "-k", label="xdp cookies")
plt.plot(x_sc, y_sc, "-b", label="sc defense")
plt.plot(x_jaqen, y_jaqen, "-r", label="jaqen defense")
plt.plot(x_sc_set_port, y_sc_set_port, "-m", label="sc defense, set port")
plt.plot(x_sc_rnd_port, y_sc_rnd_port, "-g", label="sc defense, rnd port")




plt.legend(loc="upper right")

plt.show()

# %%
## Plotting DDoS Rate vs. Return Ratio 
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np

#return_ratio = np.divide(return_rate, send_rate)
#xdp_return_ratio = np.divide(xdp_return_rate, xdp_send_rate)
#send_rate_scaled = np.true_divide(send_rate,1e6)
#xdp_send_rate_scaled = np.true_divide(xdp_send_rate,1e6)

#x_base = send_rate_scaled
#y_base = return_ratio

#x_xdp = xdp_send_rate_scaled
#y_xdp = xdp_return_ratio



f,(ax,ax2) = plt.subplots(1,2, facecolor='w', sharey=True, figsize=(6, 5), dpi=200)

# plot the same data on both axes
#use dashes/dots
#ax.plot(x_base,y_base, "y", linestyle='dashed', label="Vanilla Kernel")
#ax.plot(x_xdp, y_xdp, "b", linestyle='dotted', label="XDP")
ax.plot(x_base,y_base, "y", marker='x', label="Vanilla-SipHash")
ax.plot(x_xdp, y_xdp, "b",  marker='s', label="XDP-SipHash")
#ax.plot(x_sc,y_sc, "g", linestyle='dashdot')
#ax.plot(x_sc_set_port, y_sc_set_port,"m", linestyle='dashed')

#Only plot the best result, smartcookie with random recirculation port 
#use dashes/dots
#ax.plot(x_sc_rnd_port, y_sc_rnd_port,"g", linestyle='dotted',label="SmartCookie")
ax.plot(x_aes, y_aes, "m",  marker='d', label="SC-AES")
ax.plot(x_sc_rnd_port, y_sc_rnd_port,"g",  marker='.', label="SC-SipHash")
ax.plot(x_jaqen, y_jaqen, "r",  marker='*', label="Jaqen-CRC")

#ax.legend(loc="upper left")

#use dashes/dots
#ax2.plot(x_xdp, y_xdp, "b", linestyle='dotted')
ax2.plot(x_xdp, y_xdp,  "b", marker='.')
#ax2.plot(x_sc, y_sc, "g", linestyle='dashdot', label="SmartCookie Unoptimized")
#ax2.plot(x_sc_set_port, y_sc_set_port,"m", linestyle='dashed', label="SC+SetPort")

#use dashes/dots
#ax2.plot(x_sc_rnd_port, y_sc_rnd_port,"g", linestyle='dotted',label="SC+RndPort")
ax2.plot(x_aes, y_aes, "m",  marker='d', label="SC-AES")
ax2.plot(x_sc_rnd_port, y_sc_rnd_port,"g",  marker='.', label="SC-SipHash")
ax2.plot(x_jaqen, y_jaqen, "r",  marker='*', label="Jaqen-CRC")


#ax2.legend()

ax.set_xlim(0,35)
ax2.set_xlim(33,250)

#ax.set_ylim(0.4,1)
#ax2.set_ylim(0.4,1)

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
#ax.yaxis.tick_left()
#ax2.tick_params(labelright=False)
ax2.yaxis.tick_right()
ax2.tick_params(labelright=False)


# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax.tick_params(labelbottom=True) 
ax.xaxis.tick_bottom()
ax2.xaxis.tick_bottom()


d = .015 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)


d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
#ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
#ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
#ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
#ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

#x-axis
f.text(0.50, 0.04, 'SYN Flood Attack Rate (Mpps)', ha='center', fontsize='large')
#y-axis
f.text(0.04, 0.55, 'SYN-ACK Return Ratio (%)', va='center', rotation='vertical', fontsize='large')
plt.subplots_adjust(left=0.14, bottom=0.14)

handles_1, labels_1 = ax.get_legend_handles_labels()
f.legend(handles_1, labels_1, loc=(0.33, 0.65), fontsize='small')
#handles_2, labels_2 = ax2.get_legend_handles_labels()
#f.legend(handles_2, labels_2, loc=(0.65, 0.865))

#add reference lines 
#l1=ax.axhline(0.5,color='black',ls=':')
#l1.set_label('l1')
#l1=ax2.axhline(0.5,color='black',ls=':')
#l1.set_label('l1')

plt.savefig('throughput_total.pdf')  


plt.show()

# %%
length=len(x_xdp)
length

# %%
b_return_ratio = np.divide(b_rcv_rate, b_send_rate)
xdp_return_ratio = np.divide(xdp_rcv_rate, xdp_send_rate)

sc_return_ratio = np.divide(sc_rcv_rate, sc_send_rate)
sc_return_ratio_set_port = np.divide(sc_rcv_rate_set_port, sc_send_rate_set_port)
sc_return_ratio_rnd_port = np.divide(sc_rcv_rate_rnd_port, sc_send_rate_rnd_port)

jaqen_return_ratio = np.divide(jaqen_rcv_rate, jaqen_send_rate)

sc_aes_return_ratio = np.divide(sc_aes_rcv_rate, sc_aes_send_rate)
sc_crc_return_ratio = np.divide(sc_crc_rcv_rate, sc_crc_send_rate)
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# Cell In [163], line 4
#       1 b_return_ratio = np.divide(b_rcv_rate, b_send_rate)
#       2 xdp_return_ratio = np.divide(xdp_rcv_rate, xdp_send_rate)
# ----> 4 sc_return_ratio = np.divide(sc_rcv_rate, sc_send_rate)
#       5 sc_return_ratio_set_port = np.divide(sc_rcv_rate_set_port, sc_send_rate_set_port)
#       6 sc_return_ratio_rnd_port = np.divide(sc_rcv_rate_rnd_port, sc_send_rate_rnd_port)
#
# NameError: name 'sc_rcv_rate' is not defined

# %%
# Bar plot. 

import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.75
fig = plt.subplots(figsize =(6, 5),dpi=200)
 

# y-axis is max attack rate for 100% throughput 
# x axis is a bar plot for the defense with that rate 
max_rps = [1.3, 8, 52, 136, 2380, 2380] 
defenses=["V-SH", "XDP-SH", "SC-AES", "SC-SH", "J-CRC", "SC-CRC"]
X_AXIS = np.arange(len(defenses))
 
c = ['black', 'blue', '#7F00FF', '#00D100', 'red', 'cyan']
 
plt.bar(X_AXIS, height = max_rps, color = c, width = barWidth,  edgecolor='black')
 
# plt.bar(X_AXIS-0.36, y_base, color ='k', width = barWidth, edgecolor='black', label ='Vanilla-SipHash')
# plt.bar(X_AXIS-0.21, y_xdp, color ='b', width = barWidth, edgecolor='black', label ='XDP-SipHash')
# plt.bar(X_AXIS-0.06, y_aes, color ='#7F00FF', width = barWidth, edgecolor='black',  label ='SC-AES')
# plt.bar(X_AXIS+0.09, y_sc_rnd_port, color ='#00D100', width = barWidth, edgecolor='black', label ='SC-SipHash')
# plt.bar(X_AXIS+0.24, y_jaqen, color ='r', width = barWidth, edgecolor='black', label ='Jaqen-CRC')
# plt.bar(X_AXIS+0.39, y_crc, color ='c', width = barWidth, edgecolor='black',  label ='SC-CRC')

# Adding Xticks
plt.xlabel('Defenses at Maximum SYN-ACK Return Ratio', fontweight ='bold', fontsize = 'large')
plt.ylabel('Maximum SYN Flood Attack Rate (Mpps)', fontweight ='bold', fontsize = 'large')
plt.xticks(X_AXIS, defenses, fontsize='large')
plt.yticks(fontsize='large')

#full labels 
# colors = {'V-SH: Vanilla-SipHash':'k', 'XDP-SH: XDP-SipHash':'b', 'SC-AES: SmartCookie-AES':'#7F00FF', 
#           'SC-SH: SmartCookie-SipHash':'#00D100', 'J-CRC: Jaqen-CRC':'r', 'SC-CRC: SmartCookie-CRC':'c'}         
colors = {'Vanilla-SipHash':'k', 'XDP-SipHash':'b', 'SmartCookie-AES':'#7F00FF', 
          'SmartCookie-SipHash':'#00D100', 'Jaqen-CRC':'r', 'SmartCookie-CRC':'c'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.ylim(0,200)
# plt.legend(fontsize=19, loc='best', mode='expand', ncol=6)
plt.savefig('throughput_total.pdf')  

plt.show()

# %%
# Bar plot. 
import matplotlib.patches as mpatches

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"]=12

# set width of bar
barWidth = 0.75


fig, (ax1,ax2) = plt.subplots(2,1, sharex=True, figsize=(5.8,3.3), dpi=200, gridspec_kw={'height_ratios' : [20,80]}) 

ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()


# y-axis is max attack rate for 100% throughput 
# x axis is a bar plot for the defense with that rate 
max_rps = [1.3, 7.7, 52, 136, 2380, 2380] 
defenses=["K-SH", "XDP-SH", "SC-AES", "SC-SH", "J-CRC", "SC-CRC"]
X_AXIS = np.arange(len(defenses))


c = ['k', '#FA8072', '#CF9FFF', '#5599FF', '#FFE088', '#89F0A9']
h = ['.O', '.O', '+', '*', '/', 'xx'] 
bs = 150
ts = 1000

ax2.set_ylim(0,bs)
ax1.set_ylim(ts,3000)

bars1 = ax1.bar(defenses, height=max_rps, color = c, hatch=h, alpha=.99)
bars2 = ax2.bar(defenses, height=max_rps, color = c, hatch=h, alpha=.99)


for tick in ax2.get_xticklabels():
    tick.set_rotation(0)
d = .015  
kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
ax1.plot((-d, +d), (-d, +d), **kwargs)      
ax1.plot((1 - d, 1 + d), (-d, +d), **kwargs)
kwargs.update(transform=ax2.transAxes)  
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

handles = [] 

for b1, b2 in zip(bars1, bars2):
    posx = b2.get_x() + b2.get_width()/2.
    if b2.get_height() > bs:
        ax2.plot((posx-3*d, posx+3*d), (1 - d, 1 + d), color='k', clip_on=False,
                 transform=ax2.get_xaxis_transform())
    if b1.get_height() > ts:
        ax1.plot((posx-3*d, posx+3*d), (- d, + d), color='k', clip_on=False,
                 transform=ax1.get_xaxis_transform())

        
#x-axis
# fig.text(0.50, 0.04, 'Defenses at Maximum SYN-ACK Return Ratio', ha='center', fontweight ='bold', fontsize='large')
#y-axis
#fig.text(0.02, 0.50, 'Max Attack Rate (Mpps)', va='center', rotation='vertical', fontweight ='bold', fontsize='large')
plt.subplots_adjust(left=0.14, bottom=0.14)
plt.xticks(X_AXIS, defenses, fontweight ='bold',fontsize=11)

plt.ylabel('       Max Attack Rate (Mpps)', fontsize=12,  fontweight ='bold')

ax1.set_yticks([2380], labels=["  Line Rate\n2380"])    
    
# plot_line("vanilla_synflood/", "k", "-x", "Kernel, SYN Flood")

# plot_line("jaqen_synflood/",  "#FFC000", '-s', "Jaqen Mode 1, SYN Flood")
# plot_line("jaqen2_synflood/",  "#00CC00", "--d", "Jaqen Mode 2, SYN Flood")

# plot_line("sc_ackflood/", "b", "-*", "SmartCookie, ACK Flood")
# plot_line("sc_synflood/", "r", "--o", "SmartCookie, SYN Flood")

# c = ['k', '#FA8072', '#CF9FFF', '#5599FF', '#FFE088', '#89F0A9']
# hatches = ['.O', '.O', '+', '*', '/', 'xx'] 

styling = {'Kernel-SipHash':['k', '.O'], 'XDP-SipHash':['#FA8072','.O'], 'SmartCookie-AES':['#CF9FFF','+'], 
          'SmartCookie-SipHash':['#5599FF','*'], 'Jaqen-CRC':['#FFE088','/'], 'SmartCookie-CRC':['#89F0A9','xx']}         
labels = list(styling.keys())

#handles = [plt.Rectangle((0,0),1,1, color=styling[label][0], hatch="/") for label in labels]

 
fig.legend(bars1, labels, loc=(0.22, 0.52), fontsize=10)
plt.tight_layout()

plt.savefig('throughput_total.pdf')

# %%
line_rate = 16*148.8
line_rate

# %%
136/2380
